# %%
import pandas as pd
import nltk
from random import shuffle
from gensim.models import Word2Vec
from sklearn.manifold import TSNE
import numpy as np
import matplotlib.pyplot as plt
import plotly.graph_objs as go
from sklearn.cluster import KMeans
import mpld3

data = pd.read_csv("cleanedData.csv")

data['courses'] = data[['code_module', 'code_presentation']].apply('-'.join, axis=1)
data = data.replace(' ', '_', regex=True)

# keep only relevant columns in our dataset
data = data[['courses', 'id_student','gender','region','imd_band',
        'studied_credits', 'final_result']]


tokenized_data = []


aaa_2013j_90_100_ = ' '
aaa_2013j_20_30_ = ' '
aaa_2013j_30_40_ = ' '
aaa_2013j_50_60_ = ' '
aaa_2013j_80_90_ = ' '
aaa_2013j_70_80_ = ' '
aaa_2013j_29_39_ = ' '
aaa_2013j_60_70_ = ' '
aaa_2013j_40_50_ = ' '
aaa_2013j_41_51_ = ' '
aaa_2013j_10_20_ = ' '
aaa_2013j_0_10_ = ' '
aaa_2013j_33_43_ = ' '
aaa_2013j_59_69_ = ' '
aaa_2013j_45_55_ = ' '
aaa_2013j_46_56_ = ' '
aaa_2014j_90_100_ = ' '
aaa_2014j_20_30_ = ' '
aaa_2014j_30_40_ = ' '
aaa_2014j_50_60_ = ' '
aaa_2014j_80_90_ = ' '
aaa_2014j_70_80_ = ' '
aaa_2014j_29_39_ = ' '
aaa_2014j_60_70_ = ' '
aaa_2014j_40_50_ = ' '
aaa_2014j_41_51_ = ' '
aaa_2014j_10_20_ = ' '
aaa_2014j_0_10_ = ' '
aaa_2014j_33_43_ = ' '
aaa_2014j_59_69_ = ' '
aaa_2014j_45_55_ = ' '
aaa_2014j_46_56_ = ' '
bbb_2013b_90_100_ = ' '
bbb_2013b_20_30_ = ' '
bbb_2013b_30_40_ = ' '
bbb_2013b_50_60_ = ' '
bbb_2013b_80_90_ = ' '
bbb_2013b_70_80_ = ' '
bbb_2013b_29_39_ = ' '
bbb_2013b_60_70_ = ' '
bbb_2013b_40_50_ = ' '
bbb_2013b_41_51_ = ' '
bbb_2013b_10_20_ = ' '
bbb_2013b_0_10_ = ' '
bbb_2013b_33_43_ = ' '
bbb_2013b_59_69_ = ' '
bbb_2013b_45_55_ = ' '
bbb_2013b_46_56_ = ' '
bbb_2013j_90_100_ = ' '
bbb_2013j_20_30_ = ' '
bbb_2013j_30_40_ = ' '
bbb_2013j_50_60_ = ' '
bbb_2013j_80_90_ = ' '
bbb_2013j_70_80_ = ' '
bbb_2013j_29_39_ = ' '
bbb_2013j_60_70_ = ' '
bbb_2013j_40_50_ = ' '
bbb_2013j_41_51_ = ' '
bbb_2013j_10_20_ = ' '
bbb_2013j_0_10_ = ' '
bbb_2013j_33_43_ = ' '
bbb_2013j_59_69_ = ' '
bbb_2013j_45_55_ = ' '
bbb_2013j_46_56_ = ' '
bbb_2014b_90_100_ = ' '
bbb_2014b_20_30_ = ' '
bbb_2014b_30_40_ = ' '
bbb_2014b_50_60_ = ' '
bbb_2014b_80_90_ = ' '
bbb_2014b_70_80_ = ' '
bbb_2014b_29_39_ = ' '
bbb_2014b_60_70_ = ' '
bbb_2014b_40_50_ = ' '
bbb_2014b_41_51_ = ' '
bbb_2014b_10_20_ = ' '
bbb_2014b_0_10_ = ' '
bbb_2014b_33_43_ = ' '
bbb_2014b_59_69_ = ' '
bbb_2014b_45_55_ = ' '
bbb_2014b_46_56_ = ' '
bbb_2014j_90_100_ = ' '
bbb_2014j_20_30_ = ' '
bbb_2014j_30_40_ = ' '
bbb_2014j_50_60_ = ' '
bbb_2014j_80_90_ = ' '
bbb_2014j_70_80_ = ' '
bbb_2014j_29_39_ = ' '
bbb_2014j_60_70_ = ' '
bbb_2014j_40_50_ = ' '
bbb_2014j_41_51_ = ' '
bbb_2014j_10_20_ = ' '
bbb_2014j_0_10_ = ' '
bbb_2014j_33_43_ = ' '
bbb_2014j_59_69_ = ' '
bbb_2014j_45_55_ = ' '
bbb_2014j_46_56_ = ' '
ccc_2014b_90_100_ = ' '
ccc_2014b_20_30_ = ' '
ccc_2014b_30_40_ = ' '
ccc_2014b_50_60_ = ' '
ccc_2014b_80_90_ = ' '
ccc_2014b_70_80_ = ' '
ccc_2014b_29_39_ = ' '
ccc_2014b_60_70_ = ' '
ccc_2014b_40_50_ = ' '
ccc_2014b_41_51_ = ' '
ccc_2014b_10_20_ = ' '
ccc_2014b_0_10_ = ' '
ccc_2014b_33_43_ = ' '
ccc_2014b_59_69_ = ' '
ccc_2014b_45_55_ = ' '
ccc_2014b_46_56_ = ' '
ccc_2014j_90_100_ = ' '
ccc_2014j_20_30_ = ' '
ccc_2014j_30_40_ = ' '
ccc_2014j_50_60_ = ' '
ccc_2014j_80_90_ = ' '
ccc_2014j_70_80_ = ' '
ccc_2014j_29_39_ = ' '
ccc_2014j_60_70_ = ' '
ccc_2014j_40_50_ = ' '
ccc_2014j_41_51_ = ' '
ccc_2014j_10_20_ = ' '
ccc_2014j_0_10_ = ' '
ccc_2014j_33_43_ = ' '
ccc_2014j_59_69_ = ' '
ccc_2014j_45_55_ = ' '
ccc_2014j_46_56_ = ' '
ddd_2013b_90_100_ = ' '
ddd_2013b_20_30_ = ' '
ddd_2013b_30_40_ = ' '
ddd_2013b_50_60_ = ' '
ddd_2013b_80_90_ = ' '
ddd_2013b_70_80_ = ' '
ddd_2013b_29_39_ = ' '
ddd_2013b_60_70_ = ' '
ddd_2013b_40_50_ = ' '
ddd_2013b_41_51_ = ' '
ddd_2013b_10_20_ = ' '
ddd_2013b_0_10_ = ' '
ddd_2013b_33_43_ = ' '
ddd_2013b_59_69_ = ' '
ddd_2013b_45_55_ = ' '
ddd_2013b_46_56_ = ' '
ddd_2013j_90_100_ = ' '
ddd_2013j_20_30_ = ' '
ddd_2013j_30_40_ = ' '
ddd_2013j_50_60_ = ' '
ddd_2013j_80_90_ = ' '
ddd_2013j_70_80_ = ' '
ddd_2013j_29_39_ = ' '
ddd_2013j_60_70_ = ' '
ddd_2013j_40_50_ = ' '
ddd_2013j_41_51_ = ' '
ddd_2013j_10_20_ = ' '
ddd_2013j_0_10_ = ' '
ddd_2013j_33_43_ = ' '
ddd_2013j_59_69_ = ' '
ddd_2013j_45_55_ = ' '
ddd_2013j_46_56_ = ' '
ddd_2014b_90_100_ = ' '
ddd_2014b_20_30_ = ' '
ddd_2014b_30_40_ = ' '
ddd_2014b_50_60_ = ' '
ddd_2014b_80_90_ = ' '
ddd_2014b_70_80_ = ' '
ddd_2014b_29_39_ = ' '
ddd_2014b_60_70_ = ' '
ddd_2014b_40_50_ = ' '
ddd_2014b_41_51_ = ' '
ddd_2014b_10_20_ = ' '
ddd_2014b_0_10_ = ' '
ddd_2014b_33_43_ = ' '
ddd_2014b_59_69_ = ' '
ddd_2014b_45_55_ = ' '
ddd_2014b_46_56_ = ' '
ddd_2014j_90_100_ = ' '
ddd_2014j_20_30_ = ' '
ddd_2014j_30_40_ = ' '
ddd_2014j_50_60_ = ' '
ddd_2014j_80_90_ = ' '
ddd_2014j_70_80_ = ' '
ddd_2014j_29_39_ = ' '
ddd_2014j_60_70_ = ' '
ddd_2014j_40_50_ = ' '
ddd_2014j_41_51_ = ' '
ddd_2014j_10_20_ = ' '
ddd_2014j_0_10_ = ' '
ddd_2014j_33_43_ = ' '
ddd_2014j_59_69_ = ' '
ddd_2014j_45_55_ = ' '
ddd_2014j_46_56_ = ' '
eee_2013j_90_100_ = ' '
eee_2013j_20_30_ = ' '
eee_2013j_30_40_ = ' '
eee_2013j_50_60_ = ' '
eee_2013j_80_90_ = ' '
eee_2013j_70_80_ = ' '
eee_2013j_29_39_ = ' '
eee_2013j_60_70_ = ' '
eee_2013j_40_50_ = ' '
eee_2013j_41_51_ = ' '
eee_2013j_10_20_ = ' '
eee_2013j_0_10_ = ' '
eee_2013j_33_43_ = ' '
eee_2013j_59_69_ = ' '
eee_2013j_45_55_ = ' '
eee_2013j_46_56_ = ' '
eee_2014b_90_100_ = ' '
eee_2014b_20_30_ = ' '
eee_2014b_30_40_ = ' '
eee_2014b_50_60_ = ' '
eee_2014b_80_90_ = ' '
eee_2014b_70_80_ = ' '
eee_2014b_29_39_ = ' '
eee_2014b_60_70_ = ' '
eee_2014b_40_50_ = ' '
eee_2014b_41_51_ = ' '
eee_2014b_10_20_ = ' '
eee_2014b_0_10_ = ' '
eee_2014b_33_43_ = ' '
eee_2014b_59_69_ = ' '
eee_2014b_45_55_ = ' '
eee_2014b_46_56_ = ' '
eee_2014j_90_100_ = ' '
eee_2014j_20_30_ = ' '
eee_2014j_30_40_ = ' '
eee_2014j_50_60_ = ' '
eee_2014j_80_90_ = ' '
eee_2014j_70_80_ = ' '
eee_2014j_29_39_ = ' '
eee_2014j_60_70_ = ' '
eee_2014j_40_50_ = ' '
eee_2014j_41_51_ = ' '
eee_2014j_10_20_ = ' '
eee_2014j_0_10_ = ' '
eee_2014j_33_43_ = ' '
eee_2014j_59_69_ = ' '
eee_2014j_45_55_ = ' '
eee_2014j_46_56_ = ' '
fff_2013b_90_100_ = ' '
fff_2013b_20_30_ = ' '
fff_2013b_30_40_ = ' '
fff_2013b_50_60_ = ' '
fff_2013b_80_90_ = ' '
fff_2013b_70_80_ = ' '
fff_2013b_29_39_ = ' '
fff_2013b_60_70_ = ' '
fff_2013b_40_50_ = ' '
fff_2013b_41_51_ = ' '
fff_2013b_10_20_ = ' '
fff_2013b_0_10_ = ' '
fff_2013b_33_43_ = ' '
fff_2013b_59_69_ = ' '
fff_2013b_45_55_ = ' '
fff_2013b_46_56_ = ' '
fff_2013j_90_100_ = ' '
fff_2013j_20_30_ = ' '
fff_2013j_30_40_ = ' '
fff_2013j_50_60_ = ' '
fff_2013j_80_90_ = ' '
fff_2013j_70_80_ = ' '
fff_2013j_29_39_ = ' '
fff_2013j_60_70_ = ' '
fff_2013j_40_50_ = ' '
fff_2013j_41_51_ = ' '
fff_2013j_10_20_ = ' '
fff_2013j_0_10_ = ' '
fff_2013j_33_43_ = ' '
fff_2013j_59_69_ = ' '
fff_2013j_45_55_ = ' '
fff_2013j_46_56_ = ' '
fff_2014b_90_100_ = ' '
fff_2014b_20_30_ = ' '
fff_2014b_30_40_ = ' '
fff_2014b_50_60_ = ' '
fff_2014b_80_90_ = ' '
fff_2014b_70_80_ = ' '
fff_2014b_29_39_ = ' '
fff_2014b_60_70_ = ' '
fff_2014b_40_50_ = ' '
fff_2014b_41_51_ = ' '
fff_2014b_10_20_ = ' '
fff_2014b_0_10_ = ' '
fff_2014b_33_43_ = ' '
fff_2014b_59_69_ = ' '
fff_2014b_45_55_ = ' '
fff_2014b_46_56_ = ' '
fff_2014j_90_100_ = ' '
fff_2014j_20_30_ = ' '
fff_2014j_30_40_ = ' '
fff_2014j_50_60_ = ' '
fff_2014j_80_90_ = ' '
fff_2014j_70_80_ = ' '
fff_2014j_29_39_ = ' '
fff_2014j_60_70_ = ' '
fff_2014j_40_50_ = ' '
fff_2014j_41_51_ = ' '
fff_2014j_10_20_ = ' '
fff_2014j_0_10_ = ' '
fff_2014j_33_43_ = ' '
fff_2014j_59_69_ = ' '
fff_2014j_45_55_ = ' '
fff_2014j_46_56_ = ' '
ggg_2013j_90_100_ = ' '
ggg_2013j_20_30_ = ' '
ggg_2013j_30_40_ = ' '
ggg_2013j_50_60_ = ' '
ggg_2013j_80_90_ = ' '
ggg_2013j_70_80_ = ' '
ggg_2013j_29_39_ = ' '
ggg_2013j_60_70_ = ' '
ggg_2013j_40_50_ = ' '
ggg_2013j_41_51_ = ' '
ggg_2013j_10_20_ = ' '
ggg_2013j_0_10_ = ' '
ggg_2013j_33_43_ = ' '
ggg_2013j_59_69_ = ' '
ggg_2013j_45_55_ = ' '
ggg_2013j_46_56_ = ' '
ggg_2014b_90_100_ = ' '
ggg_2014b_20_30_ = ' '
ggg_2014b_30_40_ = ' '
ggg_2014b_50_60_ = ' '
ggg_2014b_80_90_ = ' '
ggg_2014b_70_80_ = ' '
ggg_2014b_29_39_ = ' '
ggg_2014b_60_70_ = ' '
ggg_2014b_40_50_ = ' '
ggg_2014b_41_51_ = ' '
ggg_2014b_10_20_ = ' '
ggg_2014b_0_10_ = ' '
ggg_2014b_33_43_ = ' '
ggg_2014b_59_69_ = ' '
ggg_2014b_45_55_ = ' '
ggg_2014b_46_56_ = ' '
ggg_2014j_90_100_ = ' '
ggg_2014j_20_30_ = ' '
ggg_2014j_30_40_ = ' '
ggg_2014j_50_60_ = ' '
ggg_2014j_80_90_ = ' '
ggg_2014j_70_80_ = ' '
ggg_2014j_29_39_ = ' '
ggg_2014j_60_70_ = ' '
ggg_2014j_40_50_ = ' '
ggg_2014j_41_51_ = ' '
ggg_2014j_10_20_ = ' '
ggg_2014j_0_10_ = ' '
ggg_2014j_33_43_ = ' '
ggg_2014j_59_69_ = ' '
ggg_2014j_45_55_ = ' '
ggg_2014j_46_56_ = ' '
concatenatedAaa2013j_90_100_ = ' '
concatenatedAaa2013j_20_30_ = ' '
concatenatedAaa2013j_30_40_ = ' '
concatenatedAaa2013j_50_60_ = ' '
concatenatedAaa2013j_80_90_ = ' '
concatenatedAaa2013j_70_80_ = ' '
concatenatedAaa2013j_29_39_ = ' '
concatenatedAaa2013j_60_70_ = ' '
concatenatedAaa2013j_40_50_ = ' '
concatenatedAaa2013j_41_51_ = ' '
concatenatedAaa2013j_10_20_ = ' '
concatenatedAaa2013j_0_10_ = ' '
concatenatedAaa2013j_33_43_ = ' '
concatenatedAaa2013j_59_69_ = ' '
concatenatedAaa2013j_45_55_ = ' '
concatenatedAaa2013j_46_56_ = ' '
concatenatedAaa2014j_90_100_ = ' '
concatenatedAaa2014j_20_30_ = ' '
concatenatedAaa2014j_30_40_ = ' '
concatenatedAaa2014j_50_60_ = ' '
concatenatedAaa2014j_80_90_ = ' '
concatenatedAaa2014j_70_80_ = ' '
concatenatedAaa2014j_29_39_ = ' '
concatenatedAaa2014j_60_70_ = ' '
concatenatedAaa2014j_40_50_ = ' '
concatenatedAaa2014j_41_51_ = ' '
concatenatedAaa2014j_10_20_ = ' '
concatenatedAaa2014j_0_10_ = ' '
concatenatedAaa2014j_33_43_ = ' '
concatenatedAaa2014j_59_69_ = ' '
concatenatedAaa2014j_45_55_ = ' '
concatenatedAaa2014j_46_56_ = ' '
concatenatedBbb2013b_90_100_ = ' '
concatenatedBbb2013b_20_30_ = ' '
concatenatedBbb2013b_30_40_ = ' '
concatenatedBbb2013b_50_60_ = ' '
concatenatedBbb2013b_80_90_ = ' '
concatenatedBbb2013b_70_80_ = ' '
concatenatedBbb2013b_29_39_ = ' '
concatenatedBbb2013b_60_70_ = ' '
concatenatedBbb2013b_40_50_ = ' '
concatenatedBbb2013b_41_51_ = ' '
concatenatedBbb2013b_10_20_ = ' '
concatenatedBbb2013b_0_10_ = ' '
concatenatedBbb2013b_33_43_ = ' '
concatenatedBbb2013b_59_69_ = ' '
concatenatedBbb2013b_45_55_ = ' '
concatenatedBbb2013b_46_56_ = ' '
concatenatedBbb2013j_90_100_ = ' '
concatenatedBbb2013j_20_30_ = ' '
concatenatedBbb2013j_30_40_ = ' '
concatenatedBbb2013j_50_60_ = ' '
concatenatedBbb2013j_80_90_ = ' '
concatenatedBbb2013j_70_80_ = ' '
concatenatedBbb2013j_29_39_ = ' '
concatenatedBbb2013j_60_70_ = ' '
concatenatedBbb2013j_40_50_ = ' '
concatenatedBbb2013j_41_51_ = ' '
concatenatedBbb2013j_10_20_ = ' '
concatenatedBbb2013j_0_10_ = ' '
concatenatedBbb2013j_33_43_ = ' '
concatenatedBbb2013j_59_69_ = ' '
concatenatedBbb2013j_45_55_ = ' '
concatenatedBbb2013j_46_56_ = ' '
concatenatedBbb2014b_90_100_ = ' '
concatenatedBbb2014b_20_30_ = ' '
concatenatedBbb2014b_30_40_ = ' '
concatenatedBbb2014b_50_60_ = ' '
concatenatedBbb2014b_80_90_ = ' '
concatenatedBbb2014b_70_80_ = ' '
concatenatedBbb2014b_29_39_ = ' '
concatenatedBbb2014b_60_70_ = ' '
concatenatedBbb2014b_40_50_ = ' '
concatenatedBbb2014b_41_51_ = ' '
concatenatedBbb2014b_10_20_ = ' '
concatenatedBbb2014b_0_10_ = ' '
concatenatedBbb2014b_33_43_ = ' '
concatenatedBbb2014b_59_69_ = ' '
concatenatedBbb2014b_45_55_ = ' '
concatenatedBbb2014b_46_56_ = ' '
concatenatedBbb2014j_90_100_ = ' '
concatenatedBbb2014j_20_30_ = ' '
concatenatedBbb2014j_30_40_ = ' '
concatenatedBbb2014j_50_60_ = ' '
concatenatedBbb2014j_80_90_ = ' '
concatenatedBbb2014j_70_80_ = ' '
concatenatedBbb2014j_29_39_ = ' '
concatenatedBbb2014j_60_70_ = ' '
concatenatedBbb2014j_40_50_ = ' '
concatenatedBbb2014j_41_51_ = ' '
concatenatedBbb2014j_10_20_ = ' '
concatenatedBbb2014j_0_10_ = ' '
concatenatedBbb2014j_33_43_ = ' '
concatenatedBbb2014j_59_69_ = ' '
concatenatedBbb2014j_45_55_ = ' '
concatenatedBbb2014j_46_56_ = ' '
concatenatedCcc2014b_90_100_ = ' '
concatenatedCcc2014b_20_30_ = ' '
concatenatedCcc2014b_30_40_ = ' '
concatenatedCcc2014b_50_60_ = ' '
concatenatedCcc2014b_80_90_ = ' '
concatenatedCcc2014b_70_80_ = ' '
concatenatedCcc2014b_29_39_ = ' '
concatenatedCcc2014b_60_70_ = ' '
concatenatedCcc2014b_40_50_ = ' '
concatenatedCcc2014b_41_51_ = ' '
concatenatedCcc2014b_10_20_ = ' '
concatenatedCcc2014b_0_10_ = ' '
concatenatedCcc2014b_33_43_ = ' '
concatenatedCcc2014b_59_69_ = ' '
concatenatedCcc2014b_45_55_ = ' '
concatenatedCcc2014b_46_56_ = ' '
concatenatedCcc2014j_90_100_ = ' '
concatenatedCcc2014j_20_30_ = ' '
concatenatedCcc2014j_30_40_ = ' '
concatenatedCcc2014j_50_60_ = ' '
concatenatedCcc2014j_80_90_ = ' '
concatenatedCcc2014j_70_80_ = ' '
concatenatedCcc2014j_29_39_ = ' '
concatenatedCcc2014j_60_70_ = ' '
concatenatedCcc2014j_40_50_ = ' '
concatenatedCcc2014j_41_51_ = ' '
concatenatedCcc2014j_10_20_ = ' '
concatenatedCcc2014j_0_10_ = ' '
concatenatedCcc2014j_33_43_ = ' '
concatenatedCcc2014j_59_69_ = ' '
concatenatedCcc2014j_45_55_ = ' '
concatenatedCcc2014j_46_56_ = ' '
concatenatedDdd2013b_90_100_ = ' '
concatenatedDdd2013b_20_30_ = ' '
concatenatedDdd2013b_30_40_ = ' '
concatenatedDdd2013b_50_60_ = ' '
concatenatedDdd2013b_80_90_ = ' '
concatenatedDdd2013b_70_80_ = ' '
concatenatedDdd2013b_29_39_ = ' '
concatenatedDdd2013b_60_70_ = ' '
concatenatedDdd2013b_40_50_ = ' '
concatenatedDdd2013b_41_51_ = ' '
concatenatedDdd2013b_10_20_ = ' '
concatenatedDdd2013b_0_10_ = ' '
concatenatedDdd2013b_33_43_ = ' '
concatenatedDdd2013b_59_69_ = ' '
concatenatedDdd2013b_45_55_ = ' '
concatenatedDdd2013b_46_56_ = ' '
concatenatedDdd2013j_90_100_ = ' '
concatenatedDdd2013j_20_30_ = ' '
concatenatedDdd2013j_30_40_ = ' '
concatenatedDdd2013j_50_60_ = ' '
concatenatedDdd2013j_80_90_ = ' '
concatenatedDdd2013j_70_80_ = ' '
concatenatedDdd2013j_29_39_ = ' '
concatenatedDdd2013j_60_70_ = ' '
concatenatedDdd2013j_40_50_ = ' '
concatenatedDdd2013j_41_51_ = ' '
concatenatedDdd2013j_10_20_ = ' '
concatenatedDdd2013j_0_10_ = ' '
concatenatedDdd2013j_33_43_ = ' '
concatenatedDdd2013j_59_69_ = ' '
concatenatedDdd2013j_45_55_ = ' '
concatenatedDdd2013j_46_56_ = ' '
concatenatedDdd2014b_90_100_ = ' '
concatenatedDdd2014b_20_30_ = ' '
concatenatedDdd2014b_30_40_ = ' '
concatenatedDdd2014b_50_60_ = ' '
concatenatedDdd2014b_80_90_ = ' '
concatenatedDdd2014b_70_80_ = ' '
concatenatedDdd2014b_29_39_ = ' '
concatenatedDdd2014b_60_70_ = ' '
concatenatedDdd2014b_40_50_ = ' '
concatenatedDdd2014b_41_51_ = ' '
concatenatedDdd2014b_10_20_ = ' '
concatenatedDdd2014b_0_10_ = ' '
concatenatedDdd2014b_33_43_ = ' '
concatenatedDdd2014b_59_69_ = ' '
concatenatedDdd2014b_45_55_ = ' '
concatenatedDdd2014b_46_56_ = ' '
concatenatedDdd2014j_90_100_ = ' '
concatenatedDdd2014j_20_30_ = ' '
concatenatedDdd2014j_30_40_ = ' '
concatenatedDdd2014j_50_60_ = ' '
concatenatedDdd2014j_80_90_ = ' '
concatenatedDdd2014j_70_80_ = ' '
concatenatedDdd2014j_29_39_ = ' '
concatenatedDdd2014j_60_70_ = ' '
concatenatedDdd2014j_40_50_ = ' '
concatenatedDdd2014j_41_51_ = ' '
concatenatedDdd2014j_10_20_ = ' '
concatenatedDdd2014j_0_10_ = ' '
concatenatedDdd2014j_33_43_ = ' '
concatenatedDdd2014j_59_69_ = ' '
concatenatedDdd2014j_45_55_ = ' '
concatenatedDdd2014j_46_56_ = ' '
concatenatedEee2013j_90_100_ = ' '
concatenatedEee2013j_20_30_ = ' '
concatenatedEee2013j_30_40_ = ' '
concatenatedEee2013j_50_60_ = ' '
concatenatedEee2013j_80_90_ = ' '
concatenatedEee2013j_70_80_ = ' '
concatenatedEee2013j_29_39_ = ' '
concatenatedEee2013j_60_70_ = ' '
concatenatedEee2013j_40_50_ = ' '
concatenatedEee2013j_41_51_ = ' '
concatenatedEee2013j_10_20_ = ' '
concatenatedEee2013j_0_10_ = ' '
concatenatedEee2013j_33_43_ = ' '
concatenatedEee2013j_59_69_ = ' '
concatenatedEee2013j_45_55_ = ' '
concatenatedEee2013j_46_56_ = ' '
concatenatedEee2014b_90_100_ = ' '
concatenatedEee2014b_20_30_ = ' '
concatenatedEee2014b_30_40_ = ' '
concatenatedEee2014b_50_60_ = ' '
concatenatedEee2014b_80_90_ = ' '
concatenatedEee2014b_70_80_ = ' '
concatenatedEee2014b_29_39_ = ' '
concatenatedEee2014b_60_70_ = ' '
concatenatedEee2014b_40_50_ = ' '
concatenatedEee2014b_41_51_ = ' '
concatenatedEee2014b_10_20_ = ' '
concatenatedEee2014b_0_10_ = ' '
concatenatedEee2014b_33_43_ = ' '
concatenatedEee2014b_59_69_ = ' '
concatenatedEee2014b_45_55_ = ' '
concatenatedEee2014b_46_56_ = ' '
concatenatedEee2014j_90_100_ = ' '
concatenatedEee2014j_20_30_ = ' '
concatenatedEee2014j_30_40_ = ' '
concatenatedEee2014j_50_60_ = ' '
concatenatedEee2014j_80_90_ = ' '
concatenatedEee2014j_70_80_ = ' '
concatenatedEee2014j_29_39_ = ' '
concatenatedEee2014j_60_70_ = ' '
concatenatedEee2014j_40_50_ = ' '
concatenatedEee2014j_41_51_ = ' '
concatenatedEee2014j_10_20_ = ' '
concatenatedEee2014j_0_10_ = ' '
concatenatedEee2014j_33_43_ = ' '
concatenatedEee2014j_59_69_ = ' '
concatenatedEee2014j_45_55_ = ' '
concatenatedEee2014j_46_56_ = ' '
concatenatedFff2013b_90_100_ = ' '
concatenatedFff2013b_20_30_ = ' '
concatenatedFff2013b_30_40_ = ' '
concatenatedFff2013b_50_60_ = ' '
concatenatedFff2013b_80_90_ = ' '
concatenatedFff2013b_70_80_ = ' '
concatenatedFff2013b_29_39_ = ' '
concatenatedFff2013b_60_70_ = ' '
concatenatedFff2013b_40_50_ = ' '
concatenatedFff2013b_41_51_ = ' '
concatenatedFff2013b_10_20_ = ' '
concatenatedFff2013b_0_10_ = ' '
concatenatedFff2013b_33_43_ = ' '
concatenatedFff2013b_59_69_ = ' '
concatenatedFff2013b_45_55_ = ' '
concatenatedFff2013b_46_56_ = ' '
concatenatedFff2013j_90_100_ = ' '
concatenatedFff2013j_20_30_ = ' '
concatenatedFff2013j_30_40_ = ' '
concatenatedFff2013j_50_60_ = ' '
concatenatedFff2013j_80_90_ = ' '
concatenatedFff2013j_70_80_ = ' '
concatenatedFff2013j_29_39_ = ' '
concatenatedFff2013j_60_70_ = ' '
concatenatedFff2013j_40_50_ = ' '
concatenatedFff2013j_41_51_ = ' '
concatenatedFff2013j_10_20_ = ' '
concatenatedFff2013j_0_10_ = ' '
concatenatedFff2013j_33_43_ = ' '
concatenatedFff2013j_59_69_ = ' '
concatenatedFff2013j_45_55_ = ' '
concatenatedFff2013j_46_56_ = ' '
concatenatedFff2014b_90_100_ = ' '
concatenatedFff2014b_20_30_ = ' '
concatenatedFff2014b_30_40_ = ' '
concatenatedFff2014b_50_60_ = ' '
concatenatedFff2014b_80_90_ = ' '
concatenatedFff2014b_70_80_ = ' '
concatenatedFff2014b_29_39_ = ' '
concatenatedFff2014b_60_70_ = ' '
concatenatedFff2014b_40_50_ = ' '
concatenatedFff2014b_41_51_ = ' '
concatenatedFff2014b_10_20_ = ' '
concatenatedFff2014b_0_10_ = ' '
concatenatedFff2014b_33_43_ = ' '
concatenatedFff2014b_59_69_ = ' '
concatenatedFff2014b_45_55_ = ' '
concatenatedFff2014b_46_56_ = ' '
concatenatedFff2014j_90_100_ = ' '
concatenatedFff2014j_20_30_ = ' '
concatenatedFff2014j_30_40_ = ' '
concatenatedFff2014j_50_60_ = ' '
concatenatedFff2014j_80_90_ = ' '
concatenatedFff2014j_70_80_ = ' '
concatenatedFff2014j_29_39_ = ' '
concatenatedFff2014j_60_70_ = ' '
concatenatedFff2014j_40_50_ = ' '
concatenatedFff2014j_41_51_ = ' '
concatenatedFff2014j_10_20_ = ' '
concatenatedFff2014j_0_10_ = ' '
concatenatedFff2014j_33_43_ = ' '
concatenatedFff2014j_59_69_ = ' '
concatenatedFff2014j_45_55_ = ' '
concatenatedFff2014j_46_56_ = ' '
concatenatedGgg2013j_90_100_ = ' '
concatenatedGgg2013j_20_30_ = ' '
concatenatedGgg2013j_30_40_ = ' '
concatenatedGgg2013j_50_60_ = ' '
concatenatedGgg2013j_80_90_ = ' '
concatenatedGgg2013j_70_80_ = ' '
concatenatedGgg2013j_29_39_ = ' '
concatenatedGgg2013j_60_70_ = ' '
concatenatedGgg2013j_40_50_ = ' '
concatenatedGgg2013j_41_51_ = ' '
concatenatedGgg2013j_10_20_ = ' '
concatenatedGgg2013j_0_10_ = ' '
concatenatedGgg2013j_33_43_ = ' '
concatenatedGgg2013j_59_69_ = ' '
concatenatedGgg2013j_45_55_ = ' '
concatenatedGgg2013j_46_56_ = ' '
concatenatedGgg2014b_90_100_ = ' '
concatenatedGgg2014b_20_30_ = ' '
concatenatedGgg2014b_30_40_ = ' '
concatenatedGgg2014b_50_60_ = ' '
concatenatedGgg2014b_80_90_ = ' '
concatenatedGgg2014b_70_80_ = ' '
concatenatedGgg2014b_29_39_ = ' '
concatenatedGgg2014b_60_70_ = ' '
concatenatedGgg2014b_40_50_ = ' '
concatenatedGgg2014b_41_51_ = ' '
concatenatedGgg2014b_10_20_ = ' '
concatenatedGgg2014b_0_10_ = ' '
concatenatedGgg2014b_33_43_ = ' '
concatenatedGgg2014b_59_69_ = ' '
concatenatedGgg2014b_45_55_ = ' '
concatenatedGgg2014b_46_56_ = ' '
concatenatedGgg2014j_90_100_ = ' '
concatenatedGgg2014j_20_30_ = ' '
concatenatedGgg2014j_30_40_ = ' '
concatenatedGgg2014j_50_60_ = ' '
concatenatedGgg2014j_80_90_ = ' '
concatenatedGgg2014j_70_80_ = ' '
concatenatedGgg2014j_29_39_ = ' '
concatenatedGgg2014j_60_70_ = ' '
concatenatedGgg2014j_40_50_ = ' '
concatenatedGgg2014j_41_51_ = ' '
concatenatedGgg2014j_10_20_ = ' '
concatenatedGgg2014j_0_10_ = ' '
concatenatedGgg2014j_33_43_ = ' '
concatenatedGgg2014j_59_69_ = ' '
concatenatedGgg2014j_45_55_ = ' '
concatenatedGgg2014j_46_56_ = ' '
for i in data.index:
        
 
        if data['courses'][i] == 'AAA-2013J':
                
                if data['imd_band'][i] == '90_100_':
                        
                        aaa_2013j_90_100_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ') + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        aaa_2013j_90_100_ = aaa_2013j_90_100_.lower()
                        split = aaa_2013j_90_100_.split()
                        shuffle(split)
                        aaa_2013j_90_100_ = ' '.join(split) # Turn the list back into a string
                        concatenatedAaa2013j_90_100_ =' ' + aaa_2013j_90_100_ + concatenatedAaa2013j_90_100_
                elif data['imd_band'][i] == '20_30_':
                        aaa_2013j_20_30_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ') + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        aaa_2013j_20_30_ = aaa_2013j_20_30_.lower()
                        split = aaa_2013j_20_30_.split()
                        shuffle(split)
                        aaa_2013j_20_30_ = ' '.join(split) # Turn the list back into a string
                        concatenatedAaa2013j_20_30_ =' ' + aaa_2013j_20_30_ + concatenatedAaa2013j_20_30_
                elif data['imd_band'][i] == '30_40_':
                        aaa_2013j_30_40_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ') + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        aaa_2013j_30_40_ = aaa_2013j_30_40_.lower()
                        split = aaa_2013j_30_40_.split()
                        shuffle(split)
                        aaa_2013j_30_40_ = ' '.join(split) # Turn the list back into a string
                        concatenatedAaa2013j_30_40_ =' ' + aaa_2013j_30_40_ + concatenatedAaa2013j_30_40_
                elif data['imd_band'][i] == '50_60_':
                        aaa_2013j_50_60_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ') + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        aaa_2013j_50_60_ = aaa_2013j_50_60_.lower()
                        split = aaa_2013j_50_60_.split()
                        shuffle(split)
                        aaa_2013j_50_60_ = ' '.join(split) # Turn the list back into a string
                        concatenatedAaa2013j_50_60_ =' ' + aaa_2013j_50_60_ + concatenatedAaa2013j_50_60_
                elif data['imd_band'][i] == '80_90_':
                        aaa_2013j_80_90_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ') + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        aaa_2013j_80_90_ = aaa_2013j_80_90_.lower()
                        split = aaa_2013j_80_90_.split()
                        shuffle(split)
                        aaa_2013j_80_90_ = ' '.join(split) # Turn the list back into a string
                        concatenatedAaa2013j_80_90_ =' ' + aaa_2013j_80_90_ + concatenatedAaa2013j_80_90_
                elif data['imd_band'][i] == '70_80_':
                        aaa_2013j_70_80_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ') + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        aaa_2013j_70_80_ = aaa_2013j_70_80_.lower()
                        split = aaa_2013j_70_80_.split()
                        shuffle(split)
                        aaa_2013j_70_80_ = ' '.join(split) # Turn the list back into a string
                        concatenatedAaa2013j_70_80_ =' ' + aaa_2013j_70_80_ + concatenatedAaa2013j_70_80_       
                elif data['imd_band'][i] == '29_39_':
                        aaa_2013j_29_39_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ') + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        aaa_2013j_29_39_ = aaa_2013j_29_39_.lower()
                        split = aaa_2013j_29_39_.split()
                        shuffle(split)
                        aaa_2013j_29_39_ = ' '.join(split) # Turn the list back into a string
                        concatenatedAaa2013j_29_39_ =' ' + aaa_2013j_29_39_ + concatenatedAaa2013j_29_39_
                elif data['imd_band'][i] == '60_70_':
                        aaa_2013j_60_70_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ') + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        aaa_2013j_60_70_ = aaa_2013j_60_70_.lower()
                        split = aaa_2013j_60_70_.split()
                        shuffle(split)
                        aaa_2013j_60_70_ = ' '.join(split) # Turn the list back into a string
                        concatenatedAaa2013j_60_70_ = ' ' + aaa_2013j_60_70_ + concatenatedAaa2013j_60_70_
                elif data['imd_band'][i] == '40_50_':
                        aaa_2013j_40_50_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ') + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        aaa_2013j_40_50_ = aaa_2013j_40_50_.lower()
                        split = aaa_2013j_40_50_.split()
                        shuffle(split)
                        aaa_2013j_40_50_ = ' '.join(split) # Turn the list back into a string
                        concatenatedAaa2013j_40_50_ = ' ' + aaa_2013j_40_50_ + concatenatedAaa2013j_40_50_
                elif data['imd_band'][i] == '41_51_':
                       
                        aaa_2013j_41_51_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ') + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        aaa_2013j_41_51_ = aaa_2013j_41_51_.lower()  
                        split = aaa_2013j_41_51_.split()
                        shuffle(split)
                        aaa_2013j_41_51_ = ' '.join(split) # Turn the list back into a string
                        concatenatedAaa2013j_41_51_ = ' ' + aaa_2013j_41_51_ + concatenatedAaa2013j_41_51_
                elif data['imd_band'][i] == '10_20_':
                        aaa_2013j_10_20_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ') + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        aaa_2013j_10_20_ = aaa_2013j_10_20_.lower()
                        split = aaa_2013j_10_20_.split()
                        shuffle(split)
                        aaa_2013j_10_20_ = ' '.join(split) # Turn the list back into a string
                        concatenatedAaa2013j_10_20_ = ' ' + aaa_2013j_10_20_ + concatenatedAaa2013j_10_20_
                elif data['imd_band'][i] == '0_10_':
                        aaa_2013j_0_10_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ') + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        aaa_2013j_0_10_ = aaa_2013j_0_10_.lower()
                        split = aaa_2013j_0_10_.split()
                        shuffle(split)
                        aaa_2013j_0_10_ = ' '.join(split) # Turn the list back into a string
                        concatenatedAaa2013j_0_10_ = ' ' + aaa_2013j_0_10_ + concatenatedAaa2013j_0_10_
                elif data['imd_band'][i] == '33_43_':
                        aaa_2013j_33_43_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ') + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        aaa_2013j_33_43_ = aaa_2013j_33_43_.lower()
                        split = aaa_2013j_33_43_.split()
                        shuffle(split)
                        aaa_2013j_33_43_ = ' '.join(split) # Turn the list back into a string
                        concatenatedAaa2013j_33_43_ = ' ' + aaa_2013j_33_43_ + concatenatedAaa2013j_33_43_
                elif data['imd_band'][i] == '59_69_':
                        aaa_2013j_59_69_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ') + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        aaa_2013j_59_69_ = aaa_2013j_59_69_.lower()
                        split = aaa_2013j_59_69_.split()
                        shuffle(split)
                        aaa_2013j_59_69_ = ' '.join(split) # Turn the list back into a string
                        concatenatedAaa2013j_59_69_ = ' ' + aaa_2013j_59_69_ + concatenatedAaa2013j_59_69_
                elif data['imd_band'][i] == '45_55_':
                        aaa_2013j_45_55_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ') + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        aaa_2013j_45_55_ = aaa_2013j_45_55_.lower()
                        split = aaa_2013j_45_55_.split()
                        shuffle(split)
                        aaa_2013j_45_55_ = ' '.join(split) # Turn the list back into a string
                        concatenatedAaa2013j_45_55_ = ' ' + aaa_2013j_45_55_ + concatenatedAaa2013j_45_55_
                elif data['imd_band'][i] == '46_56_':
                        aaa_2013j_46_56_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ') + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        aaa_2013j_46_56_ = aaa_2013j_46_56_.lower()
                        split = aaa_2013j_46_56_.split()
                        shuffle(split)
                        aaa_2013j_46_56_ = ' '.join(split) # Turn the list back into a string
                        concatenatedAaa2013j_46_56_ = ' ' + aaa_2013j_46_56_ + concatenatedAaa2013j_46_56_
        elif data['courses'][i] == 'AAA-2014J':
                if data['imd_band'][i] == '90_100_':
                        aaa_2014j_90_100_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ') + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        aaa_2014j_90_100_ = aaa_2014j_90_100_.lower()
                        split = aaa_2014j_90_100_.split()
                        shuffle(split)
                        aaa_2014j_90_100_ = ' '.join(split) # Turn the list back into a string
                        concatenatedAaa2014j_90_100_ =' ' + aaa_2014j_90_100_ + concatenatedAaa2014j_90_100_        
                elif data['imd_band'][i] == '20_30_':
                       aaa_2014j_20_30_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ') + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                       aaa_2014j_20_30_ = aaa_2014j_20_30_.lower()
                       split = aaa_2014j_20_30_.split()
                       shuffle(split)
                       aaa_2014j_20_30_ = ' '.join(split) # Turn the list back into a string
                       concatenatedAaa2014j_20_30_ =' ' + aaa_2014j_20_30_ + concatenatedAaa2014j_20_30_
                elif data['imd_band'][i] == '30_40_':
                        aaa_2014j_30_40_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ') + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        aaa_2014j_30_40_ = aaa_2014j_30_40_.lower()
                        split = aaa_2014j_30_40_.split()
                        shuffle(split)
                        aaa_2014j_30_40_ = ' '.join(split) # Turn the list back into a string
                        concatenatedAaa2014j_30_40_ =' ' + aaa_2014j_30_40_ + concatenatedAaa2014j_30_40_
                elif data['imd_band'][i] == '50_60_':
                        aaa_2014j_50_60_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ') + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        aaa_2014j_50_60_ = aaa_2014j_50_60_.lower()
                        split = aaa_2014j_50_60_.split()
                        shuffle(split)
                        aaa_2014j_50_60_ = ' '.join(split) # Turn the list back into a string
                        concatenatedAaa2014j_50_60_ =' ' + aaa_2014j_50_60_ + concatenatedAaa2014j_50_60_
                elif data['imd_band'][i] == '80_90_':
                        aaa_2014j_80_90_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ') + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        aaa_2014j_80_90_ = aaa_2014j_80_90_.lower()
                        split = aaa_2014j_80_90_.split()
                        shuffle(split)
                        aaa_2014j_80_90_ = ' '.join(split) # Turn the list back into a string
                        concatenatedAaa2014j_80_90_ =' ' + aaa_2014j_80_90_ + concatenatedAaa2014j_80_90_
                elif data['imd_band'][i] == '70_80_':
                        aaa_2014j_70_80_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ') + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        aaa_2014j_70_80_ = aaa_2014j_70_80_.lower()
                        split = aaa_2014j_70_80_.split()
                        shuffle(split)
                        aaa_2014j_70_80_ = ' '.join(split) # Turn the list back into a string
                        concatenatedAaa2014j_70_80_ =' ' + aaa_2014j_70_80_ + concatenatedAaa2014j_70_80_
                elif data['imd_band'][i] == '29_39_':
                        aaa_2014j_29_39_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ') + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ') 
                        aaa_2014j_29_39_ = aaa_2014j_29_39_.lower()
                        split = aaa_2014j_29_39_.split()
                        shuffle(split)
                        aaa_2014j_29_39_ = ' '.join(split) # Turn the list back into a string
                        concatenatedAaa2014j_29_39_ =' ' + aaa_2014j_29_39_ + concatenatedAaa2014j_29_39_
                
                elif data['imd_band'][i] == '60_70_':
                        aaa_2014j_60_70_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ') + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ') 
                        aaa_2014j_60_70_ = aaa_2014j_60_70_.lower()
                        split = aaa_2014j_60_70_.split()
                        shuffle(split)
                        aaa_2014j_60_70_ = ' '.join(split) # Turn the list back into a string
                        concatenatedAaa2014j_60_70_ =' ' + aaa_2014j_60_70_ + concatenatedAaa2014j_60_70_
                
                elif data['imd_band'][i] == '40_50_':
                        aaa_2014j_40_50_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ') + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ') 
                        aaa_2014j_40_50_ = aaa_2014j_40_50_.lower()
                        split = aaa_2014j_40_50_.split()
                        shuffle(split)
                        aaa_2014j_40_50_ = ' '.join(split) # Turn the list back into a string
                        concatenatedAaa2014j_40_50_ =' ' + aaa_2014j_40_50_ + concatenatedAaa2014j_40_50_ 
                elif data['imd_band'][i] == '41_51_':
                        aaa_2014j_41_51_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ') + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ') 
                        aaa_2014j_41_51_ = aaa_2014j_41_51_.lower()     
                        split = aaa_2014j_41_51_.split()
                        shuffle(split)
                        aaa_2014j_41_51_ = ' '.join(split) # Turn the list back into a string
                        concatenatedAaa2014j_41_51_ =' ' + aaa_2014j_41_51_ + concatenatedAaa2014j_41_51_
                elif data['imd_band'][i] == '10_20_':
                        aaa_2014j_10_20_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ') + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ') 
                        aaa_2014j_10_20_ = aaa_2014j_10_20_.lower()
                        split = aaa_2014j_10_20_.split()
                        shuffle(split)
                        aaa_2014j_10_20_ = ' '.join(split) # Turn the list back into a string
                        concatenatedAaa2014j_10_20_ =' ' + aaa_2014j_10_20_ + concatenatedAaa2014j_10_20_
                elif data['imd_band'][i] == '0_10_':
                        aaa_2014j_0_10_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ') + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ') 
                        aaa_2014j_0_10_ = aaa_2014j_0_10_.lower()
                        split = aaa_2014j_0_10_.split()
                        shuffle(split)
                        aaa_2014j_0_10_ = ' '.join(split) # Turn the list back into a string
                        concatenatedAaa2014j_0_10_ =' ' + aaa_2014j_0_10_ + concatenatedAaa2014j_0_10_
                elif data['imd_band'][i] == '33_43_':
                        aaa_2014j_33_43_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ') + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ') 
                        aaa_2014j_33_43_ = aaa_2014j_33_43_.lower()
                        split = aaa_2014j_33_43_.split()
                        shuffle(split)
                        aaa_2014j_33_43_ = ' '.join(split) # Turn the list back into a string
                        concatenatedAaa2014j_33_43_ =' ' + aaa_2014j_33_43_ + concatenatedAaa2014j_33_43_
                
                elif data['imd_band'][i] == '59_69_':
                        aaa_2014j_59_69_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ') + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ') 
                        aaa_2014j_59_69_ = aaa_2014j_59_69_.lower()
                        split = aaa_2014j_59_69_.split()
                        shuffle(split)
                        aaa_2014j_59_69_ = ' '.join(split) # Turn the list back into a string
                        concatenatedAaa2014j_59_69_ =' ' + aaa_2014j_59_69_ + concatenatedAaa2014j_59_69_
                

                elif data['imd_band'][i] == '45_55_':
                        aaa_2014j_45_55_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ') + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ') 
                        aaa_2014j_45_55_ = aaa_2014j_45_55_.lower()
                        split = aaa_2014j_45_55_.split()
                        shuffle(split)
                        aaa_2014j_45_55_ = ' '.join(split) # Turn the list back into a string
                        concatenatedAaa2014j_45_55_ =' ' + aaa_2014j_45_55_ + concatenatedAaa2014j_45_55_
                elif data['imd_band'][i] == '46_56_':
                        aaa_2014j_46_56_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ') + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ') 
                        aaa_2014j_46_56_ = aaa_2014j_46_56_.lower()
                        split = aaa_2014j_46_56_.split()
                        shuffle(split)
                        aaa_2014j_46_56_ = ' '.join(split) # Turn the list back into a string
                        concatenatedAaa2014j_46_56_ =' ' + aaa_2014j_46_56_ + concatenatedAaa2014j_46_56_
        elif data['courses'][i] == 'BBB-2013B':
                if data['imd_band'][i] == '90_100_':
                        bbb_2013b_90_100_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ') + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        bbb_2013b_90_100_ = bbb_2013b_90_100_.lower()
                        split = bbb_2013b_90_100_.split()
                        shuffle(split)
                        bbb_2013b_90_100_ = ' '.join(split) # Turn the list back into a string
                        concatenatedBbb2013b_90_100_ =' ' + bbb_2013b_90_100_ + concatenatedBbb2013b_90_100_
                elif data['imd_band'][i] == '20_30_':
                        bbb_2013b_20_30_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ') + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        bbb_2013b_20_30_ = bbb_2013b_20_30_.lower()
                        split = bbb_2013b_20_30_.split()
                        shuffle(split)
                        bbb_2013b_20_30_ = ' '.join(split) # Turn the list back into a string
                        concatenatedBbb2013b_20_30_ =' ' + bbb_2013b_20_30_ + concatenatedBbb2013b_20_30_
                
                elif data['imd_band'][i] == '30_40_':
                        bbb_2013b_30_40_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ') + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        bbb_2013b_30_40_ = bbb_2013b_30_40_.lower()
                        split = bbb_2013b_30_40_.split()
                        shuffle(split)
                        bbb_2013b_30_40_ = ' '.join(split) # Turn the list back into a string
                        concatenatedBbb2013b_30_40_ =' ' + bbb_2013b_30_40_ + concatenatedBbb2013b_30_40_
                elif data['imd_band'][i] == '50_60_':
                        bbb_2013b_50_60_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ') + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        bbb_2013b_50_60_ = bbb_2013b_50_60_.lower()
                        split = bbb_2013b_50_60_.split()
                        shuffle(split)
                        bbb_2013b_50_60_ = ' '.join(split) # Turn the list back into a string
                        concatenatedBbb2013b_50_60_ =' ' + bbb_2013b_50_60_ + concatenatedBbb2013b_50_60_
                elif data['imd_band'][i] == '80_90_':
                        bbb_2013b_80_90_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ') + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        bbb_2013b_80_90_ = bbb_2013b_80_90_.lower()
                        split = bbb_2013b_80_90_.split()
                        shuffle(split)
                        bbb_2013b_80_90_ = ' '.join(split) # Turn the list back into a string
                        concatenatedBbb2013b_80_90_ =' ' + bbb_2013b_80_90_ + concatenatedBbb2013b_80_90_
                elif data['imd_band'][i] == '70_80_':
                        bbb_2013b_70_80_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ') + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        bbb_2013b_70_80_ = bbb_2013b_70_80_.lower()
                        split = bbb_2013b_70_80_.split()
                        shuffle(split)
                        bbb_2013b_70_80_ = ' '.join(split) # Turn the list back into a string
                        concatenatedBbb2013b_70_80_ =' ' + bbb_2013b_70_80_ + concatenatedBbb2013b_70_80_
                elif data['imd_band'][i] == '29_39_':
                        bbb_2013b_29_39_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ') + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        bbb_2013b_29_39_ = bbb_2013b_29_39_.lower()
                        split = bbb_2013b_29_39_.split()
                        shuffle(split)
                        bbb_2013b_29_39_ = ' '.join(split) # Turn the list back into a string
                        concatenatedBbb2013b_29_39_ =' ' + bbb_2013b_29_39_ + concatenatedBbb2013b_29_39_
                elif data['imd_band'][i] == '60_70_':
                        bbb_2013b_60_70_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ') + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        bbb_2013b_60_70_ = bbb_2013b_60_70_.lower()
                        split = bbb_2013b_60_70_.split()
                        shuffle(split)
                        bbb_2013b_60_70_ = ' '.join(split) # Turn the list back into a string
                        concatenatedBbb2013b_60_70_ =' ' + bbb_2013b_60_70_ + concatenatedBbb2013b_60_70_
                elif data['imd_band'][i] == '40_50_':
                        bbb_2013b_40_50_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ') + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        bbb_2013b_40_50_ = bbb_2013b_40_50_.lower()
                        split = bbb_2013b_40_50_.split()
                        shuffle(split)
                        bbb_2013b_40_50_ = ' '.join(split) # Turn the list back into a string
                        concatenatedBbb2013b_40_50_ =' ' + bbb_2013b_40_50_ + concatenatedBbb2013b_40_50_
                elif data['imd_band'][i] == '41_51_':
                        bbb_2013b_41_51_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ') + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        bbb_2013b_41_51_ = bbb_2013b_41_51_.lower()
                        split = bbb_2013b_41_51_.split()
                        shuffle(split)
                        bbb_2013b_41_51_ = ' '.join(split) # Turn the list back into a string
                        concatenatedBbb2013b_41_51_ =' ' + bbb_2013b_41_51_ + concatenatedBbb2013b_41_51_
                elif data['imd_band'][i] == '10_20_':
                        bbb_2013b_10_20_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ') + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        bbb_2013b_10_20_ = bbb_2013b_10_20_.lower()
                        split = bbb_2013b_10_20_.split()
                        shuffle(split)
                        bbb_2013b_10_20_ = ' '.join(split) # Turn the list back into a string
                        concatenatedBbb2013b_10_20_ =' ' + bbb_2013b_10_20_ + concatenatedBbb2013b_10_20_
                elif data['imd_band'][i] == '0_10_':
                        bbb_2013b_0_10_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ') + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        bbb_2013b_0_10_ = bbb_2013b_0_10_.lower()
                        split = bbb_2013b_0_10_.split()
                        shuffle(split)
                        bbb_2013b_0_10_ = ' '.join(split) # Turn the list back into a string
                        concatenatedBbb2013b_0_10_ =' ' + bbb_2013b_0_10_ + concatenatedBbb2013b_0_10_
                elif data['imd_band'][i] == '33_43_':
                        bbb_2013b_33_43_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ') + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        bbb_2013b_33_43_ = bbb_2013b_33_43_.lower()
                        split = bbb_2013b_33_43_.split()
                        shuffle(split)
                        bbb_2013b_33_43_ = ' '.join(split) # Turn the list back into a string
                        concatenatedBbb2013b_33_43_ =' ' + bbb_2013b_33_43_ + concatenatedBbb2013b_33_43_
                elif data['imd_band'][i] == '59_69_':
                        bbb_2013b_59_69_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ') + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        bbb_2013b_59_69_ = bbb_2013b_59_69_.lower()
                        split = bbb_2013b_59_69_.split()
                        shuffle(split)
                        bbb_2013b_59_69_ = ' '.join(split) # Turn the list back into a string
                        concatenatedBbb2013b_59_69_ =' ' + bbb_2013b_59_69_ + concatenatedBbb2013b_59_69_
                elif data['imd_band'][i] == '45_55_':
                        bbb_2013b_45_55_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ') + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        bbb_2013b_45_55_ = bbb_2013b_45_55_.lower()
                        split = bbb_2013b_45_55_.split()
                        shuffle(split)
                        bbb_2013b_45_55_ = ' '.join(split) # Turn the list back into a string
                        concatenatedBbb2013b_45_55_ =' ' + bbb_2013b_45_55_ + concatenatedBbb2013b_45_55_
                elif data['imd_band'][i] == '46_56_':
                        bbb_2013b_46_56_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ') + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        bbb_2013b_46_56_ = bbb_2013b_46_56_.lower()
                        split = bbb_2013b_46_56_.split()
                        shuffle(split)
                        bbb_2013b_46_56_ = ' '.join(split) # Turn the list back into a string
                        concatenatedBbb2013b_46_56_ =' ' + bbb_2013b_46_56_ + concatenatedBbb2013b_46_56_       
        elif data['courses'][i] == 'BBB-2013J':
                if data['imd_band'][i] == '90_100_':
                        bbb_2013j_90_100_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ') + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        bbb_2013j_90_100_ = bbb_2013j_90_100_.lower()
                        split = bbb_2013j_90_100_.split()
                        shuffle(split)
                        bbb_2013j_90_100_ = ' '.join(split) # Turn the list back into a string
                        concatenatedBbb2013j_90_100_ =' ' + bbb_2013j_90_100_ + concatenatedBbb2013j_90_100_
                elif data['imd_band'][i] == '20_30_':
                        bbb_2013j_20_30_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ') + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        bbb_2013j_20_30_ = bbb_2013j_20_30_.lower()
                        split = bbb_2013j_20_30_.split()
                        shuffle(split)
                        bbb_2013j_20_30_ = ' '.join(split) # Turn the list back into a string
                        concatenatedBbb2013j_20_30_ =' ' + bbb_2013j_20_30_ + concatenatedBbb2013j_20_30_
                elif data['imd_band'][i] == '30_40_':
                        bbb_2013j_30_40_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ') + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        bbb_2013j_30_40_ = bbb_2013j_30_40_.lower()
                        split = bbb_2013j_30_40_.split()
                        shuffle(split)
                        bbb_2013j_30_40_ = ' '.join(split) # Turn the list back into a string
                        concatenatedBbb2013j_30_40_ =' ' + bbb_2013j_30_40_ + concatenatedBbb2013j_30_40_
                elif data['imd_band'][i] == '50_60_':
                        bbb_2013j_50_60_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ') + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        bbb_2013j_50_60_ = bbb_2013j_50_60_.lower()
                        split = bbb_2013j_50_60_.split()
                        shuffle(split)
                        bbb_2013j_50_60_ = ' '.join(split) # Turn the list back into a string
                        concatenatedBbb2013j_50_60_ =' ' + bbb_2013j_50_60_ + concatenatedBbb2013j_50_60_
                elif data['imd_band'][i] == '80_90_':
                        bbb_2013j_80_90_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ') + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        bbb_2013j_80_90_ = bbb_2013j_80_90_.lower()
                        split = bbb_2013j_80_90_.split()
                        shuffle(split)
                        bbb_2013j_80_90_ = ' '.join(split) # Turn the list back into a string
                        concatenatedBbb2013j_80_90_ =' ' + bbb_2013j_80_90_ + concatenatedBbb2013j_80_90_
                elif data['imd_band'][i] == '70_80_':
                        bbb_2013j_70_80_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ') + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        bbb_2013j_70_80_ = bbb_2013j_70_80_.lower()
                        split = bbb_2013j_70_80_.split()
                        shuffle(split)
                        bbb_2013j_70_80_ = ' '.join(split) # Turn the list back into a string
                        concatenatedBbb2013j_70_80_ =' ' + bbb_2013j_70_80_ + concatenatedBbb2013j_70_80_
                elif data['imd_band'][i] == '29_39_':
                        bbb_2013j_29_39_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ') + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        bbb_2013j_29_39_ = bbb_2013j_29_39_.lower()
                        split = bbb_2013j_29_39_.split()
                        shuffle(split)
                        bbb_2013j_29_39_ = ' '.join(split) # Turn the list back into a string
                        concatenatedBbb2013j_29_39_ =' ' + bbb_2013j_29_39_ + concatenatedBbb2013j_29_39_
                elif data['imd_band'][i] == '60_70_':
                        bbb_2013j_60_70_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ') + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        bbb_2013j_60_70_ = bbb_2013j_60_70_.lower()
                        split = bbb_2013j_60_70_.split()
                        shuffle(split)
                        bbb_2013j_60_70_ = ' '.join(split) # Turn the list back into a string
                        concatenatedBbb2013j_60_70_ =' ' + bbb_2013j_60_70_ + concatenatedBbb2013j_60_70_
                elif data['imd_band'][i] == '40_50_':
                        bbb_2013j_40_50_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ') + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        bbb_2013j_40_50_ = bbb_2013j_40_50_.lower()
                        split = bbb_2013j_40_50_.split()
                        shuffle(split)
                        bbb_2013j_40_50_ = ' '.join(split) # Turn the list back into a string
                        concatenatedBbb2013j_40_50_ =' ' + bbb_2013j_40_50_ + concatenatedBbb2013j_40_50_
                elif data['imd_band'][i] == '41_51_':
                        bbb_2013j_41_51_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ') + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        bbb_2013j_41_51_ = bbb_2013j_41_51_.lower()
                        split = bbb_2013j_41_51_.split()
                        shuffle(split)
                        bbb_2013j_41_51_ = ' '.join(split) # Turn the list back into a string
                        concatenatedBbb2013j_41_51_ =' ' + bbb_2013j_41_51_ + concatenatedBbb2013j_41_51_
                elif data['imd_band'][i] == '10_20_':
                        bbb_2013j_10_20_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ') + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        bbb_2013j_10_20_ = bbb_2013j_10_20_.lower()
                        split = bbb_2013j_10_20_.split()
                        shuffle(split)
                        bbb_2013j_10_20_ = ' '.join(split) # Turn the list back into a string
                        concatenatedBbb2013j_10_20_ =' ' + bbb_2013j_10_20_ + concatenatedBbb2013j_10_20_
                elif data['imd_band'][i] == '0_10_':
                        bbb_2013j_0_10_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ') + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        bbb_2013j_0_10_ = bbb_2013j_0_10_.lower()
                        split = bbb_2013j_0_10_.split()
                        shuffle(split)
                        bbb_2013j_0_10_ = ' '.join(split) # Turn the list back into a string
                        concatenatedBbb2013j_0_10_ =' ' + bbb_2013j_0_10_ + concatenatedBbb2013j_0_10_
                elif data['imd_band'][i] == '33_43_':
                        bbb_2013j_33_43_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ') + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        bbb_2013j_33_43_ = bbb_2013j_33_43_.lower()
                        split = bbb_2013j_33_43_.split()
                        shuffle(split)
                        bbb_2013j_33_43_ = ' '.join(split) # Turn the list back into a string
                        concatenatedBbb2013j_33_43_ =' ' + bbb_2013j_33_43_ + concatenatedBbb2013j_33_43_
                elif data['imd_band'][i] == '59_69_':
                        bbb_2013j_59_69_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ') + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        bbb_2013j_59_69_ = bbb_2013j_59_69_.lower()
                        split = bbb_2013j_59_69_.split()
                        shuffle(split)
                        bbb_2013j_59_69_ = ' '.join(split) # Turn the list back into a string
                        concatenatedBbb2013j_59_69_ =' ' + bbb_2013j_59_69_ + concatenatedBbb2013j_59_69_
                elif data['imd_band'][i] == '45_55_':
                        bbb_2013j_45_55_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ') + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        bbb_2013j_45_55_ = bbb_2013j_45_55_.lower()
                        split = bbb_2013j_45_55_.split()
                        shuffle(split)
                        bbb_2013j_45_55_ = ' '.join(split) # Turn the list back into a string
                        concatenatedBbb2013j_45_55_ =' ' + bbb_2013j_45_55_ + concatenatedBbb2013j_45_55_
                elif data['imd_band'][i] == '46_56_':
                        bbb_2013j_46_56_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ') + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        bbb_2013j_46_56_ = bbb_2013j_46_56_.lower()
                        split = bbb_2013j_46_56_.split()
                        shuffle(split)
                        bbb_2013j_46_56_ = ' '.join(split) # Turn the list back into a string
                        concatenatedBbb2013j_46_56_ =' ' + bbb_2013j_46_56_ + concatenatedBbb2013j_46_56_
        elif data['courses'][i] == 'BBB-2014B':
                if data['imd_band'][i] == '90_100_':
                        bbb_2014b_90_100_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ') + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        bbb_2014b_90_100_ = bbb_2014b_90_100_.lower()
                        split = bbb_2014b_90_100_.split()
                        shuffle(split)
                        bbb_2014b_90_100_ = ' '.join(split) # Turn the list back into a string
                        concatenatedBbb2014b_90_100_ =' ' + bbb_2014b_90_100_ + concatenatedBbb2014b_90_100_
                elif data['imd_band'][i] == '20_30_':
                        bbb_2014b_20_30_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ') + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        bbb_2014b_20_30_ = bbb_2014b_20_30_.lower()
                        split = bbb_2014b_20_30_.split()
                        shuffle(split)
                        bbb_2014b_20_30_ = ' '.join(split) # Turn the list back into a string
                        concatenatedBbb2014b_20_30_ =' ' + bbb_2014b_20_30_ + concatenatedBbb2014b_20_30_
                elif data['imd_band'][i] == '30_40_':
                        bbb_2014b_30_40_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ') + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        bbb_2014b_30_40_ = bbb_2014b_30_40_.lower()
                        split = bbb_2014b_30_40_.split()
                        shuffle(split)
                        bbb_2014b_30_40_ = ' '.join(split) # Turn the list back into a string
                        concatenatedBbb2014b_30_40_ =' ' + bbb_2014b_30_40_ + concatenatedBbb2014b_30_40_
                elif data['imd_band'][i] == '50_60_':
                        bbb_2014b_50_60_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ') + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        bbb_2014b_50_60_ = bbb_2014b_50_60_.lower()
                        split = bbb_2014b_50_60_.split()
                        shuffle(split)
                        bbb_2014b_50_60_ = ' '.join(split) # Turn the list back into a string
                        concatenatedBbb2014b_50_60_ =' ' + bbb_2014b_50_60_ + concatenatedBbb2014b_50_60_
                elif data['imd_band'][i] == '80_90_':
                        bbb_2014b_80_90_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ') + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        bbb_2014b_80_90_ = bbb_2014b_80_90_.lower()
                        split = bbb_2014b_80_90_.split()
                        shuffle(split)
                        bbb_2014b_80_90_ = ' '.join(split) # Turn the list back into a string
                        concatenatedBbb2014b_80_90_ =' ' + bbb_2014b_80_90_ + concatenatedBbb2014b_80_90_
                elif data['imd_band'][i] == '70_80_':
                        bbb_2014b_70_80_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ') + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        bbb_2014b_70_80_ = bbb_2014b_70_80_.lower()
                        split = bbb_2014b_70_80_.split()
                        shuffle(split)
                        bbb_2014b_70_80_ = ' '.join(split) # Turn the list back into a string
                        concatenatedBbb2014b_70_80_ =' ' + bbb_2014b_70_80_ + concatenatedBbb2014b_70_80_
                elif data['imd_band'][i] == '29_39_':
                        bbb_2014b_29_39_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ') + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        bbb_2014b_29_39_ = bbb_2014b_29_39_.lower()
                        split = bbb_2014b_29_39_.split()
                        shuffle(split)
                        bbb_2014b_29_39_ = ' '.join(split) # Turn the list back into a string
                        concatenatedBbb2014b_29_39_ =' ' + bbb_2014b_29_39_ + concatenatedBbb2014b_29_39_
                elif data['imd_band'][i] == '60_70_':
                        bbb_2014b_60_70_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ') + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        bbb_2014b_60_70_ = bbb_2014b_60_70_.lower()
                        split = bbb_2014b_60_70_.split()
                        shuffle(split)
                        bbb_2014b_60_70_ = ' '.join(split) # Turn the list back into a string
                        concatenatedBbb2014b_60_70_ =' ' + bbb_2014b_60_70_ + concatenatedBbb2014b_60_70_
                elif data['imd_band'][i] == '40_50_':
                        bbb_2014b_40_50_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ') + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        bbb_2014b_40_50_ = bbb_2014b_40_50_.lower()
                        split = bbb_2014b_40_50_.split()
                        shuffle(split)
                        bbb_2014b_40_50_ = ' '.join(split) # Turn the list back into a string
                        concatenatedBbb2014b_40_50_ =' ' + bbb_2014b_40_50_ + concatenatedBbb2014b_40_50_
                elif data['imd_band'][i] == '41_51_':
                        bbb_2014b_41_51_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ') + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        bbb_2014b_41_51_ = bbb_2014b_41_51_.lower()
                        split = bbb_2014b_41_51_.split()
                        shuffle(split)
                        bbb_2014b_41_51_ = ' '.join(split) # Turn the list back into a string
                        concatenatedBbb2014b_41_51_ =' ' + bbb_2014b_41_51_ + concatenatedBbb2014b_41_51_
                elif data['imd_band'][i] == '10_20_':
                        bbb_2014b_10_20_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ') + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        bbb_2014b_10_20_ = bbb_2014b_10_20_.lower()
                        split = bbb_2014b_10_20_.split()
                        shuffle(split)
                        bbb_2014b_10_20_ = ' '.join(split) # Turn the list back into a string
                        concatenatedBbb2014b_10_20_ =' ' + bbb_2014b_10_20_ + concatenatedBbb2014b_10_20_
                elif data['imd_band'][i] == '0_10_':
                        bbb_2014b_0_10_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ') + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        bbb_2014b_0_10_ = bbb_2014b_0_10_.lower()
                        split = bbb_2014b_0_10_.split()
                        shuffle(split)
                        bbb_2014b_0_10_ = ' '.join(split) # Turn the list back into a string
                        concatenatedBbb2014b_0_10_ =' ' + bbb_2014b_0_10_ + concatenatedBbb2014b_0_10_
                elif data['imd_band'][i] == '33_43_':
                        bbb_2014b_33_43_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ') + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        bbb_2014b_33_43_ = bbb_2014b_33_43_.lower()
                        split = bbb_2014b_33_43_.split()
                        shuffle(split)
                        bbb_2014b_33_43_ = ' '.join(split) # Turn the list back into a string
                        concatenatedBbb2014b_33_43_ =' ' + bbb_2014b_33_43_ + concatenatedBbb2014b_33_43_
                elif data['imd_band'][i] == '59_69_':
                        bbb_2014b_59_69_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ') + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        bbb_2014b_59_69_ = bbb_2014b_59_69_.lower()
                        split = bbb_2014b_59_69_.split()
                        shuffle(split)
                        bbb_2014b_59_69_ = ' '.join(split) # Turn the list back into a string
                        concatenatedBbb2014b_59_69_ =' ' + bbb_2014b_59_69_ + concatenatedBbb2014b_59_69_
                elif data['imd_band'][i] == '45_55_':
                        bbb_2014b_45_55_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ') + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        bbb_2014b_45_55_ = bbb_2014b_45_55_.lower()
                        split = bbb_2014b_45_55_.split()
                        shuffle(split)
                        bbb_2014b_45_55_ = ' '.join(split) # Turn the list back into a string
                        concatenatedBbb2014b_45_55_ =' ' + bbb_2014b_45_55_ + concatenatedBbb2014b_45_55_
                elif data['imd_band'][i] == '46_56_':
                        bbb_2014b_46_56_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ') + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        bbb_2014b_46_56_ = bbb_2014b_46_56_.lower()
                        split = bbb_2014b_46_56_.split()
                        shuffle(split)
                        bbb_2014b_46_56_ = ' '.join(split) # Turn the list back into a string
                        concatenatedBbb2014b_46_56_ =' ' + bbb_2014b_46_56_ + concatenatedBbb2014b_46_56_
        elif data['courses'][i] == 'BBB-2014J':
                if data['imd_band'][i] == '90_100_':
                        bbb_2014j_90_100_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ') + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        bbb_2014j_90_100_ = bbb_2014j_90_100_.lower()
                        split = bbb_2014j_90_100_.split()
                        shuffle(split)
                        bbb_2014j_90_100_ = ' '.join(split) # Turn the list back into a string
                        concatenatedBbb2014j_90_100_ =' ' + bbb_2014j_90_100_ + concatenatedBbb2014j_90_100_
                elif data['imd_band'][i] == '20_30_':
                        bbb_2014j_20_30_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ') + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        bbb_2014j_20_30_ = bbb_2014j_20_30_.lower()
                        split = bbb_2014j_20_30_.split()
                        shuffle(split)
                        bbb_2014j_20_30_ = ' '.join(split) # Turn the list back into a string
                        concatenatedBbb2014j_20_30_ =' ' + bbb_2014j_20_30_ + concatenatedBbb2014j_20_30_
                elif data['imd_band'][i] == '30_40_':
                        bbb_2014j_30_40_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ') + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        bbb_2014j_30_40_ = bbb_2014j_30_40_.lower()
                        split = bbb_2014j_30_40_.split()
                        shuffle(split)
                        bbb_2014j_30_40_ = ' '.join(split) # Turn the list back into a string
                        concatenatedBbb2014j_30_40_ =' ' + bbb_2014j_30_40_ + concatenatedBbb2014j_30_40_
                elif data['imd_band'][i] == '50_60_':
                        bbb_2014j_50_60_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ') + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        bbb_2014j_50_60_ = bbb_2014j_50_60_.lower()
                        split = bbb_2014j_50_60_.split()
                        shuffle(split)
                        bbb_2014j_50_60_ = ' '.join(split) # Turn the list back into a string
                        concatenatedBbb2014j_50_60_ =' ' + bbb_2014j_50_60_ + concatenatedBbb2014j_50_60_
                elif data['imd_band'][i] == '80_90_':
                        bbb_2014j_80_90_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ') + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        bbb_2014j_80_90_ = bbb_2014j_80_90_.lower()
                        split = bbb_2014j_80_90_.split()
                        shuffle(split)
                        bbb_2014j_80_90_ = ' '.join(split) # Turn the list back into a string
                        concatenatedBbb2014j_80_90_ =' ' + bbb_2014j_80_90_ + concatenatedBbb2014j_80_90_
                elif data['imd_band'][i] == '70_80_':
                        bbb_2014j_70_80_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ') + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        bbb_2014j_70_80_ = bbb_2014j_70_80_.lower()
                        split = bbb_2014j_70_80_.split()
                        shuffle(split)
                        bbb_2014j_70_80_ = ' '.join(split) # Turn the list back into a string
                        concatenatedBbb2014j_70_80_ =' ' + bbb_2014j_70_80_ + concatenatedBbb2014j_70_80_
                elif data['imd_band'][i] == '29_39_':
                        bbb_2014j_29_39_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ') + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        bbb_2014j_29_39_ = bbb_2014j_29_39_.lower()
                        split = bbb_2014j_29_39_.split()
                        shuffle(split)
                        bbb_2014j_29_39_ = ' '.join(split) # Turn the list back into a string
                        concatenatedBbb2014j_29_39_ =' ' + bbb_2014j_29_39_ + concatenatedBbb2014j_29_39_
                elif data['imd_band'][i] == '60_70_':
                        bbb_2014j_60_70_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ') + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        bbb_2014j_60_70_ = bbb_2014j_60_70_.lower()
                        split = bbb_2014j_60_70_.split()
                        shuffle(split)
                        bbb_2014j_60_70_ = ' '.join(split) # Turn the list back into a string
                        concatenatedBbb2014j_60_70_ =' ' + bbb_2014j_60_70_ + concatenatedBbb2014j_60_70_
                elif data['imd_band'][i] == '40_50_':
                        bbb_2014j_40_50_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ') + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        bbb_2014j_40_50_ = bbb_2014j_40_50_.lower()
                        split = bbb_2014j_40_50_.split()
                        shuffle(split)
                        bbb_2014j_40_50_ = ' '.join(split) # Turn the list back into a string
                        concatenatedBbb2014j_40_50_ =' ' + bbb_2014j_40_50_ + concatenatedBbb2014j_40_50_
                elif data['imd_band'][i] == '41_51_':
                        bbb_2014j_41_51_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ') + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        bbb_2014j_41_51_ = bbb_2014j_41_51_.lower()
                        split = bbb_2014j_41_51_.split()
                        shuffle(split)
                        bbb_2014j_41_51_ = ' '.join(split) # Turn the list back into a string
                        concatenatedBbb2014j_41_51_ =' ' + bbb_2014j_41_51_ + concatenatedBbb2014j_41_51_
                elif data['imd_band'][i] == '10_20_':
                        bbb_2014j_10_20_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ') + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        bbb_2014j_10_20_ = bbb_2014j_10_20_.lower()
                        split = bbb_2014j_10_20_.split()
                        shuffle(split)
                        bbb_2014j_10_20_ = ' '.join(split) # Turn the list back into a string
                        concatenatedBbb2014j_10_20_ =' ' + bbb_2014j_10_20_ + concatenatedBbb2014j_10_20_
                elif data['imd_band'][i] == '0_10_':
                        bbb_2014j_0_10_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ') + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        bbb_2014j_0_10_ = bbb_2014j_0_10_.lower()
                        split = bbb_2014j_0_10_.split()
                        shuffle(split)
                        bbb_2014j_0_10_ = ' '.join(split) # Turn the list back into a string
                        concatenatedBbb2014j_0_10_ =' ' + bbb_2014j_0_10_ + concatenatedBbb2014j_0_10_
                elif data['imd_band'][i] == '33_43_':
                        bbb_2014j_33_43_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ') + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        bbb_2014j_33_43_ = bbb_2014j_33_43_.lower()
                        split = bbb_2014j_33_43_.split()
                        shuffle(split)
                        bbb_2014j_33_43_ = ' '.join(split) # Turn the list back into a string
                        concatenatedBbb2014j_33_43_ =' ' + bbb_2014j_33_43_ + concatenatedBbb2014j_33_43_
                elif data['imd_band'][i] == '59_69_':
                        bbb_2014j_59_69_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ') + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        bbb_2014j_59_69_ = bbb_2014j_59_69_.lower()
                        split = bbb_2014j_59_69_.split()
                        shuffle(split)
                        bbb_2014j_59_69_ = ' '.join(split) # Turn the list back into a string
                        concatenatedBbb2014j_59_69_ =' ' + bbb_2014j_59_69_ + concatenatedBbb2014j_59_69_
                elif data['imd_band'][i] == '45_55_':
                        bbb_2014j_45_55_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ') + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        bbb_2014j_45_55_ = bbb_2014j_45_55_.lower()
                        split = bbb_2014j_45_55_.split()
                        shuffle(split)
                        bbb_2014j_45_55_ = ' '.join(split) # Turn the list back into a string
                        concatenatedBbb2014j_45_55_ =' ' + bbb_2014j_45_55_ + concatenatedBbb2014j_45_55_
                elif data['imd_band'][i] == '46_56_':
                        bbb_2014j_46_56_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ') + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        bbb_2014j_46_56_ = bbb_2014j_46_56_.lower()
                        split = bbb_2014j_46_56_.split()
                        shuffle(split)
                        bbb_2014j_46_56_ = ' '.join(split) # Turn the list back into a string
                        concatenatedBbb2014j_46_56_ =' ' + bbb_2014j_46_56_ + concatenatedBbb2014j_46_56_
        elif data['courses'][i] == 'CCC-2014B':
                if data['imd_band'][i] == '90_100_':
                        ccc_2014b_90_100_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ') + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        ccc_2014b_90_100_ = ccc_2014b_90_100_.lower()
                        split = ccc_2014b_90_100_.split()
                        shuffle(split)
                        ccc_2014b_90_100_ = ' '.join(split) # Turn the list back into a string
                        concatenatedCcc2014b_90_100_ =' ' + ccc_2014b_90_100_ + concatenatedCcc2014b_90_100_
                elif data['imd_band'][i] == '20_30_':
                        ccc_2014b_20_30_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ') + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        ccc_2014b_20_30_ = ccc_2014b_20_30_.lower()
                        split = ccc_2014b_20_30_.split()
                        shuffle(split)
                        ccc_2014b_20_30_ = ' '.join(split) # Turn the list back into a string
                        concatenatedCcc2014b_20_30_ =' ' + ccc_2014b_20_30_ + concatenatedCcc2014b_20_30_
                elif data['imd_band'][i] == '30_40_':
                        ccc_2014b_30_40_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ') + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        ccc_2014b_30_40_ = ccc_2014b_30_40_.lower()
                        split = ccc_2014b_30_40_.split()
                        shuffle(split)
                        ccc_2014b_30_40_ = ' '.join(split) # Turn the list back into a string
                        concatenatedCcc2014b_30_40_ =' ' + ccc_2014b_30_40_ + concatenatedCcc2014b_30_40_
                elif data['imd_band'][i] == '50_60_':
                        ccc_2014b_50_60_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ') + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        ccc_2014b_50_60_ = ccc_2014b_50_60_.lower()
                        split = ccc_2014b_50_60_.split()
                        shuffle(split)
                        ccc_2014b_50_60_ = ' '.join(split) # Turn the list back into a string
                        concatenatedCcc2014b_50_60_ =' ' + ccc_2014b_50_60_ + concatenatedCcc2014b_50_60_
                elif data['imd_band'][i] == '80_90_':
                        ccc_2014b_80_90_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ') + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        ccc_2014b_80_90_ = ccc_2014b_80_90_.lower()
                        split = ccc_2014b_80_90_.split()
                        shuffle(split)
                        ccc_2014b_80_90_ = ' '.join(split) # Turn the list back into a string
                        concatenatedCcc2014b_80_90_ =' ' + ccc_2014b_80_90_ + concatenatedCcc2014b_80_90_
                elif data['imd_band'][i] == '70_80_':
                        ccc_2014b_70_80_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ') + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        ccc_2014b_70_80_ = ccc_2014b_70_80_.lower()
                        split = ccc_2014b_70_80_.split()
                        shuffle(split)
                        ccc_2014b_70_80_ = ' '.join(split) # Turn the list back into a string
                        concatenatedCcc2014b_70_80_ =' ' + ccc_2014b_70_80_ + concatenatedCcc2014b_70_80_
                elif data['imd_band'][i] == '29_39_':
                        ccc_2014b_29_39_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ') + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        ccc_2014b_29_39_ = ccc_2014b_29_39_.lower()
                        split = ccc_2014b_29_39_.split()
                        shuffle(split)
                        ccc_2014b_29_39_ = ' '.join(split) # Turn the list back into a string
                        concatenatedCcc2014b_29_39_ =' ' + ccc_2014b_29_39_ + concatenatedCcc2014b_29_39_
                elif data['imd_band'][i] == '60_70_':
                        ccc_2014b_60_70_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ') + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        ccc_2014b_60_70_ = ccc_2014b_60_70_.lower()
                        split = ccc_2014b_60_70_.split()
                        shuffle(split)
                        ccc_2014b_60_70_ = ' '.join(split) # Turn the list back into a string
                        concatenatedCcc2014b_60_70_ =' ' + ccc_2014b_60_70_ + concatenatedCcc2014b_60_70_
                elif data['imd_band'][i] == '40_50_':
                        ccc_2014b_40_50_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ') + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        ccc_2014b_40_50_ = ccc_2014b_40_50_.lower()
                        split = ccc_2014b_40_50_.split()
                        shuffle(split)
                        ccc_2014b_40_50_ = ' '.join(split) # Turn the list back into a string
                        concatenatedCcc2014b_40_50_ =' ' + ccc_2014b_40_50_ + concatenatedCcc2014b_40_50_
                elif data['imd_band'][i] == '41_51_':
                        ccc_2014b_41_51_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ') + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        ccc_2014b_41_51_ = ccc_2014b_41_51_.lower()
                        split = ccc_2014b_41_51_.split()
                        shuffle(split)
                        ccc_2014b_41_51_ = ' '.join(split) # Turn the list back into a string
                        concatenatedCcc2014b_41_51_ =' ' + ccc_2014b_41_51_ + concatenatedCcc2014b_41_51_
                elif data['imd_band'][i] == '10_20_':
                        ccc_2014b_10_20_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ') + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        ccc_2014b_10_20_ = ccc_2014b_10_20_.lower()
                        split = ccc_2014b_10_20_.split()
                        shuffle(split)
                        ccc_2014b_10_20_ = ' '.join(split) # Turn the list back into a string
                        concatenatedCcc2014b_10_20_ =' ' + ccc_2014b_10_20_ + concatenatedCcc2014b_10_20_
                elif data['imd_band'][i] == '0_10_':
                        ccc_2014b_0_10_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ') + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        ccc_2014b_0_10_ = ccc_2014b_0_10_.lower()
                        split = ccc_2014b_0_10_.split()
                        shuffle(split)
                        ccc_2014b_0_10_ = ' '.join(split) # Turn the list back into a string
                        concatenatedCcc2014b_0_10_ =' ' + ccc_2014b_0_10_ + concatenatedCcc2014b_0_10_
                elif data['imd_band'][i] == '33_43_':
                        ccc_2014b_33_43_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ') + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        ccc_2014b_33_43_ = ccc_2014b_33_43_.lower()
                        split = ccc_2014b_33_43_.split()
                        shuffle(split)
                        ccc_2014b_33_43_ = ' '.join(split) # Turn the list back into a string
                        concatenatedCcc2014b_33_43_ =' ' + ccc_2014b_33_43_ + concatenatedCcc2014b_33_43_
                elif data['imd_band'][i] == '59_69_':
                        ccc_2014b_59_69_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ') + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        ccc_2014b_59_69_ = ccc_2014b_59_69_.lower()
                        split = ccc_2014b_59_69_.split()
                        shuffle(split)
                        ccc_2014b_59_69_ = ' '.join(split) # Turn the list back into a string
                        concatenatedCcc2014b_59_69_ =' ' + ccc_2014b_59_69_ + concatenatedCcc2014b_59_69_
                elif data['imd_band'][i] == '45_55_':
                        ccc_2014b_45_55_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ') + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        ccc_2014b_45_55_ = ccc_2014b_45_55_.lower()
                        split = ccc_2014b_45_55_.split()
                        shuffle(split)
                        ccc_2014b_45_55_ = ' '.join(split) # Turn the list back into a string
                        concatenatedCcc2014b_45_55_ =' ' + ccc_2014b_45_55_ + concatenatedCcc2014b_45_55_
                elif data['imd_band'][i] == '46_56_':
                        ccc_2014b_46_56_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ') + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        ccc_2014b_46_56_ = ccc_2014b_46_56_.lower()
                        split = ccc_2014b_46_56_.split()
                        shuffle(split)
                        ccc_2014b_46_56_ = ' '.join(split) # Turn the list back into a string
                        concatenatedCcc2014b_46_56_ =' ' + ccc_2014b_46_56_ + concatenatedCcc2014b_46_56_
        elif data['courses'][i] == 'CCC-2014J':
                if data['imd_band'][i] == '90_100_':
                        ccc_2014j_90_100_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ') + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        ccc_2014j_90_100_ = ccc_2014j_90_100_.lower()
                        split = ccc_2014j_90_100_.split()
                        shuffle(split)
                        ccc_2014j_90_100_ = ' '.join(split) # Turn the list back into a string
                        concatenatedCcc2014j_90_100_ =' ' + ccc_2014j_90_100_ + concatenatedCcc2014j_90_100_
                elif data['imd_band'][i] == '20_30_':
                        ccc_2014j_20_30_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ') + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        ccc_2014j_20_30_ = ccc_2014j_20_30_.lower()
                        split = ccc_2014j_20_30_.split()
                        shuffle(split)
                        ccc_2014j_20_30_ = ' '.join(split) # Turn the list back into a string
                        concatenatedCcc2014j_20_30_ =' ' + ccc_2014j_20_30_ + concatenatedCcc2014j_20_30_
                elif data['imd_band'][i] == '30_40_':
                        ccc_2014j_30_40_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ') + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        ccc_2014j_30_40_ = ccc_2014j_30_40_.lower()
                        split = ccc_2014j_30_40_.split()
                        shuffle(split)
                        ccc_2014j_30_40_ = ' '.join(split) # Turn the list back into a string
                        concatenatedCcc2014j_30_40_ =' ' + ccc_2014j_30_40_ + concatenatedCcc2014j_30_40_
                elif data['imd_band'][i] == '50_60_':
                        ccc_2014j_50_60_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ') + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        ccc_2014j_50_60_ = ccc_2014j_50_60_.lower()
                        split = ccc_2014j_50_60_.split()
                        shuffle(split)
                        ccc_2014j_50_60_ = ' '.join(split) # Turn the list back into a string
                        concatenatedCcc2014j_50_60_ =' ' + ccc_2014j_50_60_ + concatenatedCcc2014j_50_60_
                elif data['imd_band'][i] == '80_90_':
                        ccc_2014j_80_90_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ') + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        ccc_2014j_80_90_ = ccc_2014j_80_90_.lower()
                        split = ccc_2014j_80_90_.split()
                        shuffle(split)
                        ccc_2014j_80_90_ = ' '.join(split) # Turn the list back into a string
                        concatenatedCcc2014j_80_90_ =' ' + ccc_2014j_80_90_ + concatenatedCcc2014j_80_90_
                elif data['imd_band'][i] == '70_80_':
                        ccc_2014j_70_80_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ') + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        ccc_2014j_70_80_ = ccc_2014j_70_80_.lower()
                        split = ccc_2014j_70_80_.split()
                        shuffle(split)
                        ccc_2014j_70_80_ = ' '.join(split) # Turn the list back into a string
                        concatenatedCcc2014j_70_80_ =' ' + ccc_2014j_70_80_ + concatenatedCcc2014j_70_80_
                elif data['imd_band'][i] == '29_39_':
                        ccc_2014j_29_39_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ') + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        ccc_2014j_29_39_ = ccc_2014j_29_39_.lower()
                        split = ccc_2014j_29_39_.split()
                        shuffle(split)
                        ccc_2014j_29_39_ = ' '.join(split) # Turn the list back into a string
                        concatenatedCcc2014j_29_39_ =' ' + ccc_2014j_29_39_ + concatenatedCcc2014j_29_39_
                elif data['imd_band'][i] == '60_70_':
                        ccc_2014j_60_70_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ') + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        ccc_2014j_60_70_ = ccc_2014j_60_70_.lower()
                        split = ccc_2014j_60_70_.split()
                        shuffle(split)
                        ccc_2014j_60_70_ = ' '.join(split) # Turn the list back into a string
                        concatenatedCcc2014j_60_70_ =' ' + ccc_2014j_60_70_ + concatenatedCcc2014j_60_70_
                elif data['imd_band'][i] == '40_50_':
                        ccc_2014j_40_50_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ') + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        ccc_2014j_40_50_ = ccc_2014j_40_50_.lower()
                        split = ccc_2014j_40_50_.split()
                        shuffle(split)
                        ccc_2014j_40_50_ = ' '.join(split) # Turn the list back into a string
                        concatenatedCcc2014j_40_50_ =' ' + ccc_2014j_40_50_ + concatenatedCcc2014j_40_50_
                elif data['imd_band'][i] == '41_51_':
                        ccc_2014j_41_51_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ') + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        ccc_2014j_41_51_ = ccc_2014j_41_51_.lower()
                        split = ccc_2014j_41_51_.split()
                        shuffle(split)
                        ccc_2014j_41_51_ = ' '.join(split) # Turn the list back into a string
                        concatenatedCcc2014j_41_51_ =' ' + ccc_2014j_41_51_ + concatenatedCcc2014j_41_51_
                elif data['imd_band'][i] == '10_20_':
                        ccc_2014j_10_20_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ') + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        ccc_2014j_10_20_ = ccc_2014j_10_20_.lower()
                        split = ccc_2014j_10_20_.split()
                        shuffle(split)
                        ccc_2014j_10_20_ = ' '.join(split) # Turn the list back into a string
                        concatenatedCcc2014j_10_20_ =' ' + ccc_2014j_10_20_ + concatenatedCcc2014j_10_20_
                elif data['imd_band'][i] == '0_10_':
                        ccc_2014j_0_10_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ') + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        ccc_2014j_0_10_ = ccc_2014j_0_10_.lower()
                        split = ccc_2014j_0_10_.split()
                        shuffle(split)
                        ccc_2014j_0_10_ = ' '.join(split) # Turn the list back into a string
                        concatenatedCcc2014j_0_10_ =' ' + ccc_2014j_0_10_ + concatenatedCcc2014j_0_10_
                elif data['imd_band'][i] == '33_43_':
                        ccc_2014j_33_43_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ') + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        ccc_2014j_33_43_ = ccc_2014j_33_43_.lower()
                        split = ccc_2014j_33_43_.split()
                        shuffle(split)
                        ccc_2014j_33_43_ = ' '.join(split) # Turn the list back into a string
                        concatenatedCcc2014j_33_43_ =' ' + ccc_2014j_33_43_ + concatenatedCcc2014j_33_43_
                elif data['imd_band'][i] == '59_69_':
                        ccc_2014j_59_69_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ') + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        ccc_2014j_59_69_ = ccc_2014j_59_69_.lower()
                        split = ccc_2014j_59_69_.split()
                        shuffle(split)
                        ccc_2014j_59_69_ = ' '.join(split) # Turn the list back into a string
                        concatenatedCcc2014j_59_69_ =' ' + ccc_2014j_59_69_ + concatenatedCcc2014j_59_69_
                elif data['imd_band'][i] == '45_55_':
                        ccc_2014j_45_55_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ') + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        ccc_2014j_45_55_ = ccc_2014j_45_55_.lower()
                        split = ccc_2014j_45_55_.split()
                        shuffle(split)
                        ccc_2014j_45_55_ = ' '.join(split) # Turn the list back into a string
                        concatenatedCcc2014j_45_55_ =' ' + ccc_2014j_45_55_ + concatenatedCcc2014j_45_55_
                elif data['imd_band'][i] == '46_56_':
                        ccc_2014j_46_56_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ') + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        ccc_2014j_46_56_ = ccc_2014j_46_56_.lower()
                        split = ccc_2014j_46_56_.split()
                        shuffle(split)
                        ccc_2014j_46_56_ = ' '.join(split) # Turn the list back into a string
                        concatenatedCcc2014j_46_56_ =' ' + ccc_2014j_46_56_ + concatenatedCcc2014j_46_56_
        elif data['courses'][i] == 'DDD-2013B':
                if data['imd_band'][i] == '90_100_':
                        ddd_2013b_90_100_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ') + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        ddd_2013b_90_100_ = ddd_2013b_90_100_.lower()
                        split = ddd_2013b_90_100_.split()
                        shuffle(split)
                        ddd_2013b_90_100_ = ' '.join(split) # Turn the list back into a string
                        concatenatedDdd2013b_90_100_ =' ' + ddd_2013b_90_100_ + concatenatedDdd2013b_90_100_
                elif data['imd_band'][i] == '20_30_':
                        ddd_2013b_20_30_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ') + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        ddd_2013b_20_30_ = ddd_2013b_20_30_.lower()
                        split = ddd_2013b_20_30_.split()
                        shuffle(split)
                        ddd_2013b_20_30_ = ' '.join(split) # Turn the list back into a string
                        concatenatedDdd2013b_20_30_ =' ' + ddd_2013b_20_30_ + concatenatedDdd2013b_20_30_
                elif data['imd_band'][i] == '30_40_':
                        ddd_2013b_30_40_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ') + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        ddd_2013b_30_40_ = ddd_2013b_30_40_.lower()
                        split = ddd_2013b_30_40_.split()
                        shuffle(split)
                        ddd_2013b_30_40_ = ' '.join(split) # Turn the list back into a string
                        concatenatedDdd2013b_30_40_ =' ' + ddd_2013b_30_40_ + concatenatedDdd2013b_30_40_
                elif data['imd_band'][i] == '50_60_':
                        ddd_2013b_50_60_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ') + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        ddd_2013b_50_60_ = ddd_2013b_50_60_.lower()
                        split = ddd_2013b_50_60_.split()
                        shuffle(split)
                        ddd_2013b_50_60_ = ' '.join(split) # Turn the list back into a string
                        concatenatedDdd2013b_50_60_ =' ' + ddd_2013b_50_60_ + concatenatedDdd2013b_50_60_
                elif data['imd_band'][i] == '80_90_':
                        ddd_2013b_80_90_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ') + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        ddd_2013b_80_90_ = ddd_2013b_80_90_.lower()
                        split = ddd_2013b_80_90_.split()
                        shuffle(split)
                        ddd_2013b_80_90_ = ' '.join(split) # Turn the list back into a string
                        concatenatedDdd2013b_80_90_ =' ' + ddd_2013b_80_90_ + concatenatedDdd2013b_80_90_
                elif data['imd_band'][i] == '70_80_':
                        ddd_2013b_70_80_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ') + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        ddd_2013b_70_80_ = ddd_2013b_70_80_.lower()
                        split = ddd_2013b_70_80_.split()
                        shuffle(split)
                        ddd_2013b_70_80_ = ' '.join(split) # Turn the list back into a string
                        concatenatedDdd2013b_70_80_ =' ' + ddd_2013b_70_80_ + concatenatedDdd2013b_70_80_
                elif data['imd_band'][i] == '29_39_':
                        ddd_2013b_29_39_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ') + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        ddd_2013b_29_39_ = ddd_2013b_29_39_.lower()
                        split = ddd_2013b_29_39_.split()
                        shuffle(split)
                        ddd_2013b_29_39_ = ' '.join(split) # Turn the list back into a string
                        concatenatedDdd2013b_29_39_ =' ' + ddd_2013b_29_39_ + concatenatedDdd2013b_29_39_
                elif data['imd_band'][i] == '60_70_':
                        ddd_2013b_60_70_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ') + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        ddd_2013b_60_70_ = ddd_2013b_60_70_.lower()
                        split = ddd_2013b_60_70_.split()
                        shuffle(split)
                        ddd_2013b_60_70_ = ' '.join(split) # Turn the list back into a string
                        concatenatedDdd2013b_60_70_ =' ' + ddd_2013b_60_70_ + concatenatedDdd2013b_60_70_
                elif data['imd_band'][i] == '40_50_':
                        ddd_2013b_40_50_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ') + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        ddd_2013b_40_50_ = ddd_2013b_40_50_.lower()
                        split = ddd_2013b_40_50_.split()
                        shuffle(split)
                        ddd_2013b_40_50_ = ' '.join(split) # Turn the list back into a string
                        concatenatedDdd2013b_40_50_ =' ' + ddd_2013b_40_50_ + concatenatedDdd2013b_40_50_
                elif data['imd_band'][i] == '41_51_':
                        ddd_2013b_41_51_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ') + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        ddd_2013b_41_51_ = ddd_2013b_41_51_.lower()
                        split = ddd_2013b_41_51_.split()
                        shuffle(split)
                        ddd_2013b_41_51_ = ' '.join(split) # Turn the list back into a string
                        concatenatedDdd2013b_41_51_ =' ' + ddd_2013b_41_51_ + concatenatedDdd2013b_41_51_
                elif data['imd_band'][i] == '10_20_':
                        ddd_2013b_10_20_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ') + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        ddd_2013b_10_20_ = ddd_2013b_10_20_.lower()
                        split = ddd_2013b_10_20_.split()
                        shuffle(split)
                        ddd_2013b_10_20_ = ' '.join(split) # Turn the list back into a string
                        concatenatedDdd2013b_10_20_ =' ' + ddd_2013b_10_20_ + concatenatedDdd2013b_10_20_
                elif data['imd_band'][i] == '0_10_':
                        ddd_2013b_0_10_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ') + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        ddd_2013b_0_10_ = ddd_2013b_0_10_.lower()
                        split = ddd_2013b_0_10_.split()
                        shuffle(split)
                        ddd_2013b_0_10_ = ' '.join(split) # Turn the list back into a string
                        concatenatedDdd2013b_0_10_ =' ' + ddd_2013b_0_10_ + concatenatedDdd2013b_0_10_
                elif data['imd_band'][i] == '33_43_':
                        ddd_2013b_33_43_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ') + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        ddd_2013b_33_43_ = ddd_2013b_33_43_.lower()
                        split = ddd_2013b_33_43_.split()
                        shuffle(split)
                        ddd_2013b_33_43_ = ' '.join(split) # Turn the list back into a string
                        concatenatedDdd2013b_33_43_ =' ' + ddd_2013b_33_43_ + concatenatedDdd2013b_33_43_
                elif data['imd_band'][i] == '59_69_':
                        ddd_2013b_59_69_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ') + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        ddd_2013b_59_69_ = ddd_2013b_59_69_.lower()
                        split = ddd_2013b_59_69_.split()
                        shuffle(split)
                        ddd_2013b_59_69_ = ' '.join(split) # Turn the list back into a string
                        concatenatedDdd2013b_59_69_ =' ' + ddd_2013b_59_69_ + concatenatedDdd2013b_59_69_
                elif data['imd_band'][i] == '45_55_':
                        ddd_2013b_45_55_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ') + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        ddd_2013b_45_55_ = ddd_2013b_45_55_.lower()
                        split = ddd_2013b_45_55_.split()
                        shuffle(split)
                        ddd_2013b_45_55_ = ' '.join(split) # Turn the list back into a string
                        concatenatedDdd2013b_45_55_ =' ' + ddd_2013b_45_55_ + concatenatedDdd2013b_45_55_
                elif data['imd_band'][i] == '46_56_':
                        ddd_2013b_46_56_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ') + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        ddd_2013b_46_56_ = ddd_2013b_46_56_.lower()
                        split = ddd_2013b_46_56_.split()
                        shuffle(split)
                        ddd_2013b_46_56_ = ' '.join(split) # Turn the list back into a string
                        concatenatedDdd2013b_46_56_ =' ' + ddd_2013b_46_56_ + concatenatedDdd2013b_46_56_
        elif data['courses'][i] == 'DDD-2013J':
                if data['imd_band'][i] == '90_100_':
                        ddd_2013j_90_100_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ') + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        ddd_2013j_90_100_ = ddd_2013j_90_100_.lower()
                        split = ddd_2013j_90_100_.split()
                        shuffle(split)
                        ddd_2013j_90_100_ = ' '.join(split) # Turn the list back into a string
                        concatenatedDdd2013j_90_100_ =' ' + ddd_2013j_90_100_ + concatenatedDdd2013j_90_100_
                elif data['imd_band'][i] == '20_30_':
                        ddd_2013j_20_30_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ') + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        ddd_2013j_20_30_ = ddd_2013j_20_30_.lower()
                        split = ddd_2013j_20_30_.split()
                        shuffle(split)
                        ddd_2013j_20_30_ = ' '.join(split) # Turn the list back into a string
                        concatenatedDdd2013j_20_30_ =' ' + ddd_2013j_20_30_ + concatenatedDdd2013j_20_30_
                elif data['imd_band'][i] == '30_40_':
                        ddd_2013j_30_40_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ') + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        ddd_2013j_30_40_ = ddd_2013j_30_40_.lower()
                        split = ddd_2013j_30_40_.split()
                        shuffle(split)
                        ddd_2013j_30_40_ = ' '.join(split) # Turn the list back into a string
                        concatenatedDdd2013j_30_40_ =' ' + ddd_2013j_30_40_ + concatenatedDdd2013j_30_40_
                elif data['imd_band'][i] == '50_60_':
                        ddd_2013j_50_60_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ') + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        ddd_2013j_50_60_ = ddd_2013j_50_60_.lower()
                        split = ddd_2013j_50_60_.split()
                        shuffle(split)
                        ddd_2013j_50_60_ = ' '.join(split) # Turn the list back into a string
                        concatenatedDdd2013j_50_60_ =' ' + ddd_2013j_50_60_ + concatenatedDdd2013j_50_60_
                elif data['imd_band'][i] == '80_90_':
                        ddd_2013j_80_90_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ') + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        ddd_2013j_80_90_ = ddd_2013j_80_90_.lower()
                        split = ddd_2013j_80_90_.split()
                        shuffle(split)
                        ddd_2013j_80_90_ = ' '.join(split) # Turn the list back into a string
                        concatenatedDdd2013j_80_90_ =' ' + ddd_2013j_80_90_ + concatenatedDdd2013j_80_90_
                elif data['imd_band'][i] == '70_80_':
                        ddd_2013j_70_80_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ') + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        ddd_2013j_70_80_ = ddd_2013j_70_80_.lower()
                        split = ddd_2013j_70_80_.split()
                        shuffle(split)
                        ddd_2013j_70_80_ = ' '.join(split) # Turn the list back into a string
                        concatenatedDdd2013j_70_80_ =' ' + ddd_2013j_70_80_ + concatenatedDdd2013j_70_80_
                elif data['imd_band'][i] == '29_39_':
                        ddd_2013j_29_39_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ') + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        ddd_2013j_29_39_ = ddd_2013j_29_39_.lower()
                        split = ddd_2013j_29_39_.split()
                        shuffle(split)
                        ddd_2013j_29_39_ = ' '.join(split) # Turn the list back into a string
                        concatenatedDdd2013j_29_39_ =' ' + ddd_2013j_29_39_ + concatenatedDdd2013j_29_39_
                elif data['imd_band'][i] == '60_70_':
                        ddd_2013j_60_70_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ') + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        ddd_2013j_60_70_ = ddd_2013j_60_70_.lower()
                        split = ddd_2013j_60_70_.split()
                        shuffle(split)
                        ddd_2013j_60_70_ = ' '.join(split) # Turn the list back into a string
                        concatenatedDdd2013j_60_70_ =' ' + ddd_2013j_60_70_ + concatenatedDdd2013j_60_70_
                elif data['imd_band'][i] == '40_50_':
                        ddd_2013j_40_50_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ') + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        ddd_2013j_40_50_ = ddd_2013j_40_50_.lower()
                        split = ddd_2013j_40_50_.split()
                        shuffle(split)
                        ddd_2013j_40_50_ = ' '.join(split) # Turn the list back into a string
                        concatenatedDdd2013j_40_50_ =' ' + ddd_2013j_40_50_ + concatenatedDdd2013j_40_50_
                elif data['imd_band'][i] == '41_51_':
                        ddd_2013j_41_51_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ') + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        ddd_2013j_41_51_ = ddd_2013j_41_51_.lower()
                        split = ddd_2013j_41_51_.split()
                        shuffle(split)
                        ddd_2013j_41_51_ = ' '.join(split) # Turn the list back into a string
                        concatenatedDdd2013j_41_51_ =' ' + ddd_2013j_41_51_ + concatenatedDdd2013j_41_51_
                elif data['imd_band'][i] == '10_20_':
                        ddd_2013j_10_20_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ') + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        ddd_2013j_10_20_ = ddd_2013j_10_20_.lower()
                        split = ddd_2013j_10_20_.split()
                        shuffle(split)
                        ddd_2013j_10_20_ = ' '.join(split) # Turn the list back into a string
                        concatenatedDdd2013j_10_20_ =' ' + ddd_2013j_10_20_ + concatenatedDdd2013j_10_20_
                elif data['imd_band'][i] == '0_10_':
                        ddd_2013j_0_10_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ') + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        ddd_2013j_0_10_ = ddd_2013j_0_10_.lower()
                        split = ddd_2013j_0_10_.split()
                        shuffle(split)
                        ddd_2013j_0_10_ = ' '.join(split) # Turn the list back into a string
                        concatenatedDdd2013j_0_10_ =' ' + ddd_2013j_0_10_ + concatenatedDdd2013j_0_10_
                elif data['imd_band'][i] == '33_43_':
                        ddd_2013j_33_43_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ') + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        ddd_2013j_33_43_ = ddd_2013j_33_43_.lower()
                        split = ddd_2013j_33_43_.split()
                        shuffle(split)
                        ddd_2013j_33_43_ = ' '.join(split) # Turn the list back into a string
                        concatenatedDdd2013j_33_43_ =' ' + ddd_2013j_33_43_ + concatenatedDdd2013j_33_43_
                elif data['imd_band'][i] == '59_69_':
                        ddd_2013j_59_69_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ') + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        ddd_2013j_59_69_ = ddd_2013j_59_69_.lower()
                        split = ddd_2013j_59_69_.split()
                        shuffle(split)
                        ddd_2013j_59_69_ = ' '.join(split) # Turn the list back into a string
                        concatenatedDdd2013j_59_69_ =' ' + ddd_2013j_59_69_ + concatenatedDdd2013j_59_69_
                elif data['imd_band'][i] == '45_55_':
                        ddd_2013j_45_55_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ') + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        ddd_2013j_45_55_ = ddd_2013j_45_55_.lower()
                        split = ddd_2013j_45_55_.split()
                        shuffle(split)
                        ddd_2013j_45_55_ = ' '.join(split) # Turn the list back into a string
                        concatenatedDdd2013j_45_55_ =' ' + ddd_2013j_45_55_ + concatenatedDdd2013j_45_55_
                elif data['imd_band'][i] == '46_56_':
                        ddd_2013j_46_56_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ') + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        ddd_2013j_46_56_ = ddd_2013j_46_56_.lower()
                        split = ddd_2013j_46_56_.split()
                        shuffle(split)
                        ddd_2013j_46_56_ = ' '.join(split) # Turn the list back into a string
                        concatenatedDdd2013j_46_56_ =' ' + ddd_2013j_46_56_ + concatenatedDdd2013j_46_56_
        elif data['courses'][i] == 'DDD-2014B':
                if data['imd_band'][i] == '90_100_':
                        ddd_2014bb_90_100_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ') + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        ddd_2014b_90_100_ = ddd_2014b_90_100_.lower()
                        split = ddd_2014b_90_100_.split()
                        shuffle(split)
                        ddd_2014b_90_100_ = ' '.join(split) # Turn the list back into a string
                        concatenatedDdd2014b_90_100_ =' ' + ddd_2014b_90_100_ + concatenatedDdd2014b_90_100_
                elif data['imd_band'][i] == '20_30_':
                        ddd_2014b_20_30_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ') + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        ddd_2014b_20_30_ = ddd_2014b_20_30_.lower()
                        split = ddd_2014b_20_30_.split()
                        shuffle(split)
                        ddd_2014b_20_30_ = ' '.join(split) # Turn the list back into a string
                        concatenatedDdd2014b_20_30_ =' ' + ddd_2014b_20_30_ + concatenatedDdd2014b_20_30_
                elif data['imd_band'][i] == '30_40_':
                        ddd_2014b_30_40_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ') + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        ddd_2014b_30_40_ = ddd_2014b_30_40_.lower()
                        split = ddd_2014b_30_40_.split()
                        shuffle(split)
                        ddd_2014b_30_40_ = ' '.join(split) # Turn the list back into a string
                        concatenatedDdd2014b_30_40_ =' ' + ddd_2014b_30_40_ + concatenatedDdd2014b_30_40_
                elif data['imd_band'][i] == '50_60_':
                        ddd_2014b_50_60_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ') + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        ddd_2014b_50_60_ = ddd_2014b_50_60_.lower()
                        split = ddd_2014b_50_60_.split()
                        shuffle(split)
                        ddd_2014b_50_60_ = ' '.join(split) # Turn the list back into a string
                        concatenatedDdd2014b_50_60_ =' ' + ddd_2014b_50_60_ + concatenatedDdd2014b_50_60_
                elif data['imd_band'][i] == '80_90_':
                        ddd_2014b_80_90_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ') + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        ddd_2014b_80_90_ = ddd_2014b_80_90_.lower()
                        split = ddd_2014b_80_90_.split()
                        shuffle(split)
                        ddd_2014b_80_90_ = ' '.join(split) # Turn the list back into a string
                        concatenatedDdd2014b_80_90_ =' ' + ddd_2014b_80_90_ + concatenatedDdd2014b_80_90_
                elif data['imd_band'][i] == '70_80_':
                        ddd_2014b_70_80_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ') + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        ddd_2014b_70_80_ = ddd_2014b_70_80_.lower()
                        split = ddd_2014b_70_80_.split()
                        shuffle(split)
                        ddd_2014b_70_80_ = ' '.join(split) # Turn the list back into a string
                        concatenatedDdd2014b_70_80_ =' ' + ddd_2014b_70_80_ + concatenatedDdd2014b_70_80_
                elif data['imd_band'][i] == '29_39_':
                        ddd_2014b_29_39_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ') + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        ddd_2014b_29_39_ = ddd_2014b_29_39_.lower()
                        split = ddd_2014b_29_39_.split()
                        shuffle(split)
                        ddd_2014b_29_39_ = ' '.join(split) # Turn the list back into a string
                        concatenatedDdd2014b_29_39_ =' ' + ddd_2014b_29_39_ + concatenatedDdd2014b_29_39_
                elif data['imd_band'][i] == '60_70_':
                        ddd_2014b_60_70_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ') + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        ddd_2014b_60_70_ = ddd_2014b_60_70_.lower()
                        split = ddd_2014b_60_70_.split()
                        shuffle(split)
                        ddd_2014b_60_70_ = ' '.join(split) # Turn the list back into a string
                        concatenatedDdd2014b_60_70_ =' ' + ddd_2014b_60_70_ + concatenatedDdd2014b_60_70_
                elif data['imd_band'][i] == '40_50_':
                        ddd_2014b_40_50_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ') + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        ddd_2014b_40_50_ = ddd_2014b_40_50_.lower()
                        split = ddd_2014b_40_50_.split()
                        shuffle(split)
                        ddd_2014b_40_50_ = ' '.join(split) # Turn the list back into a string
                        concatenatedDdd2014b_40_50_ =' ' + ddd_2013j_40_50_ + concatenatedDdd2014b_40_50_
                elif data['imd_band'][i] == '41_51_':
                        ddd_2014b_41_51_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ') + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        ddd_2014b_41_51_ = ddd_2014b_41_51_.lower()
                        split = ddd_2014b_41_51_.split()
                        shuffle(split)
                        ddd_2014b_41_51_ = ' '.join(split) # Turn the list back into a string
                        concatenatedDdd2014b_41_51_ =' ' + ddd_2014b_41_51_ + concatenatedDdd2014b_41_51_
                elif data['imd_band'][i] == '10_20_':
                        ddd_2014b_10_20_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ') + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        ddd_2014b_10_20_ = ddd_2014b_10_20_.lower()
                        split = ddd_2014b_10_20_.split()
                        shuffle(split)
                        ddd_2014b_10_20_ = ' '.join(split) # Turn the list back into a string
                        concatenatedDdd2014b_10_20_ =' ' + ddd_2014b_10_20_ + concatenatedDdd2014b_10_20_
                elif data['imd_band'][i] == '0_10_':
                        ddd_2014b_0_10_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ') + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        ddd_2014b_0_10_ = ddd_2014b_0_10_.lower()
                        split = ddd_2014b_0_10_.split()
                        shuffle(split)
                        ddd_2014b_0_10_ = ' '.join(split) # Turn the list back into a string
                        concatenatedDdd2014b_0_10_ =' ' + ddd_2014b_0_10_ + concatenatedDdd2014b_0_10_
                elif data['imd_band'][i] == '33_43_':
                        ddd_2014b_33_43_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ') + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        ddd_2014b_33_43_ = ddd_2014b_33_43_.lower()
                        split = ddd_2014b_33_43_.split()
                        shuffle(split)
                        ddd_2014b_33_43_ = ' '.join(split) # Turn the list back into a string
                        concatenatedDdd2014b_33_43_ =' ' + ddd_2014b_33_43_ + concatenatedDdd2014b_33_43_
                elif data['imd_band'][i] == '59_69_':
                        ddd_2014b_59_69_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ') + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        ddd_2014b_59_69_ = ddd_2014b_59_69_.lower()
                        split = ddd_2014b_59_69_.split()
                        shuffle(split)
                        ddd_2014b_59_69_ = ' '.join(split) # Turn the list back into a string
                        concatenatedDdd2014b_59_69_ =' ' + ddd_2014b_59_69_ + concatenatedDdd2014b_59_69_
                elif data['imd_band'][i] == '45_55_':
                        ddd_2014b_45_55_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ') + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        ddd_2014b_45_55_ = ddd_2014b_45_55_.lower()
                        split = ddd_2014b_45_55_.split()
                        shuffle(split)
                        ddd_2014b_45_55_ = ' '.join(split) # Turn the list back into a string
                        concatenatedDdd2014b_45_55_ =' ' + ddd_2014b_45_55_ + concatenatedDdd2014b_45_55_
                elif data['imd_band'][i] == '46_56_':
                        ddd_2014b_46_56_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ') + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        ddd_2014b_46_56_ = ddd_2014b_46_56_.lower()
                        split = ddd_2014b_46_56_.split()
                        shuffle(split)
                        ddd_2014b_46_56_ = ' '.join(split) # Turn the list back into a string
                        concatenatedDdd2014b_46_56_ =' ' + ddd_2014b_46_56_ + concatenatedDdd2014b_46_56_
        elif data['courses'][i] == 'DDD-2014J':
                if data['imd_band'][i] == '90_100_':
                        ddd_2014j_90_100_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ') + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        ddd_2014j_90_100_ = ddd_2014j_90_100_.lower()
                        split = ddd_2014j_90_100_.split()
                        shuffle(split)
                        ddd_2014j_90_100_ = ' '.join(split) # Turn the list back into a string
                        concatenatedDdd2014j_90_100_ =' ' + ddd_2014j_90_100_ + concatenatedDdd2014j_90_100_
                elif data['imd_band'][i] == '20_30_':
                        ddd_2014j_20_30_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ') + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        ddd_2014j_20_30_ = ddd_2014j_20_30_.lower()
                        split = ddd_2014j_20_30_.split()
                        shuffle(split)
                        ddd_2014j_20_30_ = ' '.join(split) # Turn the list back into a string
                        concatenatedDdd2014j_20_30_ =' ' + ddd_2014j_20_30_ + concatenatedDdd2014j_20_30_
                elif data['imd_band'][i] == '30_40_':
                        ddd_2014j_30_40_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ') + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        ddd_2014j_30_40_ = ddd_2014j_30_40_.lower()
                        split = ddd_2014j_30_40_.split()
                        shuffle(split)
                        ddd_2014j_30_40_ = ' '.join(split) # Turn the list back into a string
                        concatenatedDdd2014j_30_40_ =' ' + ddd_2014j_30_40_ + concatenatedDdd2014j_30_40_
                elif data['imd_band'][i] == '50_60_':
                        ddd_2014j_50_60_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ') + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        ddd_2014j_50_60_ = ddd_2014j_50_60_.lower()
                        split = ddd_2014j_50_60_.split()
                        shuffle(split)
                        ddd_2014j_50_60_ = ' '.join(split) # Turn the list back into a string
                        concatenatedDdd2014j_50_60_ =' ' + ddd_2014j_50_60_ + concatenatedDdd2014j_50_60_
                elif data['imd_band'][i] == '80_90_':
                        ddd_2014j_80_90_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ') + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        ddd_2014j_80_90_ = ddd_2014j_80_90_.lower()
                        split = ddd_2014j_80_90_.split()
                        shuffle(split)
                        ddd_2014j_80_90_ = ' '.join(split) # Turn the list back into a string
                        concatenatedDdd2014j_80_90_ =' ' + ddd_2014j_80_90_ + concatenatedDdd2014j_80_90_
                elif data['imd_band'][i] == '70_80_':
                        ddd_2014j_70_80_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ') + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        ddd_2014j_70_80_ = ddd_2014j_70_80_.lower()
                        split = ddd_2014j_70_80_.split()
                        shuffle(split)
                        ddd_2014j_70_80_ = ' '.join(split) # Turn the list back into a string
                        concatenatedDdd2014j_70_80_ =' ' + ddd_2014j_70_80_ + concatenatedDdd2014j_70_80_
                elif data['imd_band'][i] == '29_39_':
                        ddd_2014j_29_39_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ') + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        ddd_2014j_29_39_ = ddd_2014j_29_39_.lower()
                        split = ddd_2014j_29_39_.split()
                        shuffle(split)
                        ddd_2014j_29_39_ = ' '.join(split) # Turn the list back into a string
                        concatenatedDdd2014j_29_39_ =' ' + ddd_2014j_29_39_ + concatenatedDdd2014j_29_39_
                elif data['imd_band'][i] == '60_70_':
                        ddd_2014j_60_70_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ') + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        ddd_2014j_60_70_ = ddd_2014j_60_70_.lower()
                        split = ddd_2014j_60_70_.split()
                        shuffle(split)
                        ddd_2014j_60_70_ = ' '.join(split) # Turn the list back into a string
                        concatenatedDdd2014j_60_70_ =' ' + ddd_2014j_60_70_ + concatenatedDdd2014j_60_70_
                elif data['imd_band'][i] == '40_50_':
                        ddd_2014j_40_50_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ') + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        ddd_2014j_40_50_ = ddd_2014j_40_50_.lower()
                        split = ddd_2014j_40_50_.split()
                        shuffle(split)
                        ddd_2014j_40_50_ = ' '.join(split) # Turn the list back into a string
                        concatenatedDdd2014j_40_50_ =' ' + ddd_2014j_40_50_ + concatenatedDdd2014j_40_50_
                elif data['imd_band'][i] == '41_51_':
                        ddd_2014j_41_51_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ') + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        ddd_2014j_41_51_ = ddd_2014j_41_51_.lower()
                        split = ddd_2014j_41_51_.split()
                        shuffle(split)
                        ddd_2014j_41_51_ = ' '.join(split) # Turn the list back into a string
                        concatenatedDdd2014j_41_51_ =' ' + ddd_2014j_41_51_ + concatenatedDdd2014j_41_51_
                elif data['imd_band'][i] == '10_20_':
                        ddd_2014j_10_20_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ') + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        ddd_2014j_10_20_ = ddd_2014j_10_20_.lower()
                        split = ddd_2014j_10_20_.split()
                        shuffle(split)
                        ddd_2014j_10_20_ = ' '.join(split) # Turn the list back into a string
                        concatenatedDdd2014j_10_20_ =' ' + ddd_2014j_10_20_ + concatenatedDdd2014j_10_20_
                elif data['imd_band'][i] == '0_10_':
                        ddd_2014j_0_10_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ') + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        ddd_2014j_0_10_ = ddd_2014j_0_10_.lower()
                        split = ddd_2014j_0_10_.split()
                        shuffle(split)
                        ddd_2014j_0_10_ = ' '.join(split) # Turn the list back into a string
                        concatenatedDdd2014j_0_10_ =' ' + ddd_2014j_0_10_ + concatenatedDdd2014j_0_10_
                elif data['imd_band'][i] == '33_43_':
                        ddd_2014j_33_43_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ') + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        ddd_2014j_33_43_ = ddd_2014j_33_43_.lower()
                        split = ddd_2014j_33_43_.split()
                        shuffle(split)
                        ddd_2014j_33_43_ = ' '.join(split) # Turn the list back into a string
                        concatenatedDdd2014j_33_43_ =' ' + ddd_2014j_33_43_ + concatenatedDdd2014j_33_43_
                elif data['imd_band'][i] == '59_69_':
                        ddd_2014j_59_69_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ') + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        ddd_2014j_59_69_ = ddd_2014j_59_69_.lower()
                        split = ddd_2014j_59_69_.split()
                        shuffle(split)
                        ddd_2014j_59_69_ = ' '.join(split) # Turn the list back into a string
                        concatenatedDdd2014j_59_69_ =' ' + ddd_2014j_59_69_ + concatenatedDdd2014j_59_69_
                elif data['imd_band'][i] == '45_55_':
                        ddd_2014j_45_55_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ') + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        ddd_2014j_45_55_ = ddd_2014j_45_55_.lower()
                        split = ddd_2014j_45_55_.split()
                        shuffle(split)
                        ddd_2014j_45_55_ = ' '.join(split) # Turn the list back into a string
                        concatenatedDdd2014j_45_55_ =' ' + ddd_2014j_45_55_ + concatenatedDdd2014j_45_55_
                elif data['imd_band'][i] == '46_56_':
                        ddd_2014j_46_56_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ') + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        ddd_2014j_46_56_ = ddd_2014j_46_56_.lower()
                        split = ddd_2014j_46_56_.split()
                        shuffle(split)
                        ddd_2014j_46_56_ = ' '.join(split) # Turn the list back into a string
                        concatenatedDdd2014j_46_56_ =' ' + ddd_2014j_46_56_ + concatenatedDdd2014j_46_56_
        elif data['courses'][i] == 'EEE-2013J':
                if data['imd_band'][i] == '90_100_':
                        eee_2013j_90_100_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ')  + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        eee_2013j_90_100_ = eee_2013j_90_100_.lower()
                        split = eee_2013j_90_100_.split()
                        shuffle(split)
                        eee_2013j_90_100_ = ' '.join(split) # Turn the list back into a string
                        concatenatedEee2013j_90_100_ =' ' + eee_2013j_90_100_ + concatenatedEee2013j_90_100_
                elif data['imd_band'][i] == '20_30_':
                        eee_2013j_20_30_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ')  + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        eee_2013j_20_30_ = eee_2013j_20_30_.lower()
                        split = eee_2013j_20_30_.split()
                        shuffle(split)
                        eee_2013j_20_30_ = ' '.join(split) # Turn the list back into a string
                        concatenatedEee2013j_20_30_ =' ' + eee_2013j_20_30_ + concatenatedEee2013j_20_30_
                elif data['imd_band'][i] == '30_40_':
                        eee_2013j_30_40_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ')  + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        eee_2013j_30_40_ = eee_2013j_30_40_.lower()
                        split = eee_2013j_30_40_.split()
                        shuffle(split)
                        eee_2013j_30_40_ = ' '.join(split) # Turn the list back into a string
                        concatenatedEee2013j_30_40_ =' ' + eee_2013j_30_40_ + concatenatedEee2013j_30_40_
                elif data['imd_band'][i] == '50_60_':
                        eee_2013j_50_60_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ')  + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        eee_2013j_50_60_ = eee_2013j_50_60_.lower()
                        split = eee_2013j_50_60_.split()
                        shuffle(split)
                        eee_2013j_50_60_ = ' '.join(split) # Turn the list back into a string
                        concatenatedEee2013j_50_60_ =' ' + eee_2013j_50_60_ + concatenatedEee2013j_50_60_
                elif data['imd_band'][i] == '80_90_':
                        eee_2013j_80_90_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ')  + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        eee_2013j_80_90_ = eee_2013j_80_90_.lower()
                        split = eee_2013j_80_90_.split()
                        shuffle(split)
                        eee_2013j_80_90_ = ' '.join(split) # Turn the list back into a string
                        concatenatedEee2013j_80_90_ =' ' + eee_2013j_80_90_ + concatenatedEee2013j_80_90_
                elif data['imd_band'][i] == '70_80_':
                        eee_2013j_70_80_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ')  + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        eee_2013j_70_80_ = eee_2013j_70_80_.lower()
                        split = eee_2013j_70_80_.split()
                        shuffle(split)
                        eee_2013j_70_80_ = ' '.join(split) # Turn the list back into a string
                        concatenatedEee2013j_70_80_ =' ' + eee_2013j_70_80_ + concatenatedEee2013j_70_80_
                elif data['imd_band'][i] == '29_39_':
                        eee_2013j_29_39_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ')  + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        eee_2013j_29_39_ = eee_2013j_29_39_.lower()
                        split = eee_2013j_29_39_.split()
                        shuffle(split)
                        eee_2013j_29_39_ = ' '.join(split) # Turn the list back into a string
                        concatenatedEee2013j_29_39_ =' ' + eee_2013j_29_39_ + concatenatedEee2013j_29_39_
                elif data['imd_band'][i] == '60_70_':
                        eee_2013j_60_70_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ')  + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        eee_2013j_60_70_ = eee_2013j_60_70_.lower()
                        split = eee_2013j_60_70_.split()
                        shuffle(split)
                        eee_2013j_60_70_ = ' '.join(split) # Turn the list back into a string
                        concatenatedEee2013j_60_70_ =' ' + eee_2013j_60_70_ + concatenatedEee2013j_60_70_
                elif data['imd_band'][i] == '40_50_':
                        eee_2013j_40_50_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ')  + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        eee_2013j_40_50_ = eee_2013j_40_50_.lower()
                        split = eee_2013j_40_50_.split()
                        shuffle(split)
                        eee_2013j_40_50_ = ' '.join(split) # Turn the list back into a string
                        concatenatedEee2013j_40_50_ =' ' + eee_2013j_40_50_ + concatenatedEee2013j_40_50_
                elif data['imd_band'][i] == '41_51_':
                        eee_2013j_41_51_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ')  + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        eee_2013j_41_51_ = eee_2013j_41_51_.lower()
                        split = eee_2013j_41_51_.split()
                        shuffle(split)
                        eee_2013j_41_51_ = ' '.join(split) # Turn the list back into a string
                        concatenatedEee2013j_41_51_ =' ' + eee_2013j_41_51_ + concatenatedEee2013j_41_51_
                elif data['imd_band'][i] == '10_20_':
                        eee_2013j_10_20_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ')  + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        eee_2013j_10_20_ = eee_2013j_10_20_.lower()
                        split = eee_2013j_10_20_.split()
                        shuffle(split)
                        eee_2013j_10_20_ = ' '.join(split) # Turn the list back into a string
                        concatenatedEee2013j_10_20_ =' ' + eee_2013j_10_20_ + concatenatedEee2013j_10_20_
                elif data['imd_band'][i] == '0_10_':
                        eee_2013j_0_10_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ')  + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        eee_2013j_0_10_ = eee_2013j_0_10_.lower()
                        split = eee_2013j_0_10_.split()
                        shuffle(split)
                        eee_2013j_0_10_ = ' '.join(split) # Turn the list back into a string
                        concatenatedEee2013j_0_10_ =' ' + eee_2013j_0_10_ + concatenatedEee2013j_0_10_
                elif data['imd_band'][i] == '33_43_':
                        eee_2013j_33_43_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ')  + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        eee_2013j_33_43_ = eee_2013j_33_43_.lower()
                        split = eee_2013j_33_43_.split()
                        shuffle(split)
                        eee_2013j_33_43_ = ' '.join(split) # Turn the list back into a string
                        concatenatedEee2013j_33_43_ =' ' + eee_2013j_33_43_ + concatenatedEee2013j_33_43_
                elif data['imd_band'][i] == '59_69_':
                        eee_2013j_59_69_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ')  + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        eee_2013j_59_69_ = eee_2013j_59_69_.lower()
                        split = eee_2013j_59_69_.split()
                        shuffle(split)
                        eee_2013j_59_69_ = ' '.join(split) # Turn the list back into a string
                        concatenatedEee2013j_59_69_ =' ' + eee_2013j_59_69_ + concatenatedEee2013j_59_69_
                elif data['imd_band'][i] == '45_55_':
                        eee_2013j_45_55_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ')  + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        eee_2013j_45_55_ = eee_2013j_45_55_.lower()
                        split = eee_2013j_45_55_.split()
                        shuffle(split)
                        eee_2013j_45_55_ = ' '.join(split) # Turn the list back into a string
                        concatenatedEee2013j_45_55_ =' ' + eee_2013j_45_55_ + concatenatedEee2013j_45_55_
                elif data['imd_band'][i] == '46_56_':
                        eee_2013j_46_56_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ')  + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        eee_2013j_46_56_ = eee_2013j_46_56_.lower()
                        split = eee_2013j_46_56_.split()
                        shuffle(split)
                        eee_2013j_46_56_ = ' '.join(split) # Turn the list back into a string
                        concatenatedEee2013j_46_56_ =' ' + eee_2013j_46_56_ + concatenatedEee2013j_46_56_                                                                       
        elif data['courses'][i] == 'EEE-2014B':
                if data['imd_band'][i] == '90_100_':
                        eee_2014b_90_100_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ')  + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        eee_2014b_90_100_ = eee_2014b_90_100_.lower()
                        split = eee_2014b_90_100_.split()
                        shuffle(split)
                        eee_2014b_90_100_ = ' '.join(split) # Turn the list back into a string
                        concatenatedEee2014b_90_100_ =' ' + eee_2014b_90_100_ + concatenatedEee2014b_90_100_
                elif data['imd_band'][i] == '20_30_':
                        eee_2014b_20_30_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ')  + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        eee_2014b_20_30_ = eee_2014b_20_30_.lower()
                        split = eee_2014b_20_30_.split()
                        shuffle(split)
                        eee_2014b_20_30_ = ' '.join(split) # Turn the list back into a string
                        concatenatedEee2014b_20_30_ =' ' + eee_2014b_20_30_ + concatenatedEee2014b_20_30_
                elif data['imd_band'][i] == '30_40_':
                        eee_2014b_30_40_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ')  + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        eee_2014b_30_40_ = eee_2014b_30_40_.lower()
                        split = eee_2014b_30_40_.split()
                        shuffle(split)
                        eee_2014b_30_40_ = ' '.join(split) # Turn the list back into a string
                        concatenatedEee2014b_30_40_ =' ' + eee_2014b_30_40_ + concatenatedEee2014b_30_40_
                elif data['imd_band'][i] == '50_60_':
                        eee_2014b_50_60_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ')  + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        eee_2014b_50_60_ = eee_2014b_50_60_.lower()
                        split = eee_2014b_50_60_.split()
                        shuffle(split)
                        eee_2014b_50_60_ = ' '.join(split) # Turn the list back into a string
                        concatenatedEee2014b_50_60_ =' ' + eee_2014b_50_60_ + concatenatedEee2014b_50_60_
                elif data['imd_band'][i] == '80_90_':
                        eee_2014b_80_90_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ')  + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        eee_2014b_80_90_ = eee_2014b_80_90_.lower()
                        split = eee_2014b_80_90_.split()
                        shuffle(split)
                        eee_2014b_80_90_ = ' '.join(split) # Turn the list back into a string
                        concatenatedEee2014b_80_90_ =' ' + eee_2014b_80_90_ + concatenatedEee2014b_80_90_
                elif data['imd_band'][i] == '70_80_':
                        eee_2014b_70_80_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ')  + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        eee_2014b_70_80_ = eee_2014b_70_80_.lower()
                        split = eee_2014b_70_80_.split()
                        shuffle(split)
                        eee_2014b_70_80_ = ' '.join(split) # Turn the list back into a string
                        concatenatedEee2014b_70_80_ =' ' + eee_2014b_70_80_ + concatenatedEee2014b_70_80_
                elif data['imd_band'][i] == '29_39_':
                        eee_2014b_29_39_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ')  + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        eee_2014b_29_39_ = eee_2014b_29_39_.lower()
                        split = eee_2014b_29_39_.split()
                        shuffle(split)
                        eee_2014b_29_39_ = ' '.join(split) # Turn the list back into a string
                        concatenatedEee2014b_29_39_ =' ' + eee_2014b_29_39_ + concatenatedEee2014b_29_39_
                elif data['imd_band'][i] == '60_70_':
                        eee_2014b_60_70_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ')  + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        eee_2014b_60_70_ = eee_2014b_60_70_.lower()
                        split = eee_2014b_60_70_.split()
                        shuffle(split)
                        eee_2014b_60_70_ = ' '.join(split) # Turn the list back into a string
                        concatenatedEee2014b_60_70_ =' ' + eee_2014b_60_70_ + concatenatedEee2014b_60_70_
                elif data['imd_band'][i] == '40_50_':
                        eee_2014b_40_50_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ')  + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        eee_2014b_40_50_ = eee_2014b_40_50_.lower()
                        split = eee_2014b_40_50_.split()
                        shuffle(split)
                        eee_2014b_40_50_ = ' '.join(split) # Turn the list back into a string
                        concatenatedEee2014b_40_50_ =' ' + eee_2014b_40_50_ + concatenatedEee2014b_40_50_
                elif data['imd_band'][i] == '41_51_':
                        eee_2014b_41_51_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ')  + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        eee_2014b_41_51_ = eee_2014b_41_51_.lower()
                        split = eee_2014b_41_51_.split()
                        shuffle(split)
                        eee_2014b_41_51_ = ' '.join(split) # Turn the list back into a string
                        concatenatedEee2014b_41_51_ =' ' + eee_2014b_41_51_ + concatenatedEee2014b_41_51_
                elif data['imd_band'][i] == '10_20_':
                        eee_2014b_10_20_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ')  + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        eee_2014b_10_20_ = eee_2014b_10_20_.lower()
                        split = eee_2014b_10_20_.split()
                        shuffle(split)
                        eee_2014b_10_20_ = ' '.join(split) # Turn the list back into a string
                        concatenatedEee2014b_10_20_ =' ' + eee_2014b_10_20_ + concatenatedEee2014b_10_20_
                elif data['imd_band'][i] == '0_10_':
                        eee_2014b_0_10_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ')  + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        eee_2014b_0_10_ = eee_2014b_0_10_.lower()
                        split = eee_2014b_0_10_.split()
                        shuffle(split)
                        eee_2014b_0_10_ = ' '.join(split) # Turn the list back into a string
                        concatenatedEee2014b_0_10_ =' ' + eee_2014b_0_10_ + concatenatedEee2014b_0_10_
                elif data['imd_band'][i] == '33_43_':
                        eee_2014b_33_43_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ')  + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        eee_2014b_33_43_ = eee_2014b_33_43_.lower()
                        split = eee_2014b_33_43_.split()
                        shuffle(split)
                        eee_2014b_33_43_ = ' '.join(split) # Turn the list back into a string
                        concatenatedEee2014b_33_43_ =' ' + eee_2014b_33_43_ + concatenatedEee2014b_33_43_
                elif data['imd_band'][i] == '59_69_':
                        eee_2014b_59_69_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ')  + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        eee_2014b_59_69_ = eee_2014b_59_69_.lower()
                        split = eee_2014b_59_69_.split()
                        shuffle(split)
                        eee_2014b_59_69_ = ' '.join(split) # Turn the list back into a string
                        concatenatedEee2014b_59_69_ =' ' + eee_2014b_59_69_ + concatenatedEee2014b_59_69_
                elif data['imd_band'][i] == '45_55_':
                        eee_2014b_45_55_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ')  + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        eee_2014b_45_55_ = eee_2014b_45_55_.lower()
                        split = eee_2014b_45_55_.split()
                        shuffle(split)
                        eee_2014b_45_55_ = ' '.join(split) # Turn the list back into a string
                        concatenatedEee2014b_45_55_ =' ' + eee_2014b_45_55_ + concatenatedEee2014b_45_55_
                elif data['imd_band'][i] == '46_56_':
                        eee_2014b_46_56_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ')  + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        eee_2014b_46_56_ = eee_2014b_46_56_.lower()
                        split = eee_2014b_46_56_.split()
                        shuffle(split)
                        eee_2014b_46_56_ = ' '.join(split) # Turn the list back into a string
                        concatenatedEee2014b_46_56_ =' ' + eee_2014b_46_56_ + concatenatedEee2014b_46_56_           
        elif data['courses'][i] == 'EEE-2014J':
                if data['imd_band'][i] == '90_100_':
                        eee_2014j_90_100_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ')  + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        eee_2014j_90_100_ = eee_2014j_90_100_.lower()
                        split = eee_2014j_90_100_.split()
                        shuffle(split)
                        eee_2014j_90_100_ = ' '.join(split) # Turn the list back into a string
                        concatenatedEee2014j_90_100_ =' ' + eee_2014j_90_100_ + concatenatedEee2014j_90_100_
                elif data['imd_band'][i] == '20_30_':
                        eee_2014j_20_30_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ')  + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        eee_2014j_20_30_ = eee_2014j_20_30_.lower()
                        split = eee_2014j_20_30_.split()
                        shuffle(split)
                        eee_2014j_20_30_ = ' '.join(split) # Turn the list back into a string
                        concatenatedEee2014j_20_30_ =' ' + eee_2014j_20_30_ + concatenatedEee2014j_20_30_
                elif data['imd_band'][i] == '30_40_':
                        eee_2014j_30_40_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ')  + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        eee_2014j_30_40_ = eee_2014j_30_40_.lower()
                        split = eee_2014j_30_40_.split()
                        shuffle(split)
                        eee_2014j_30_40_ = ' '.join(split) # Turn the list back into a string
                        concatenatedEee2014j_30_40_ =' ' + eee_2014j_30_40_ + concatenatedEee2014j_30_40_
                elif data['imd_band'][i] == '50_60_':
                        eee_2014j_50_60_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ')  + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        eee_2014j_50_60_ = eee_2014j_50_60_.lower()
                        split = eee_2014j_50_60_.split()
                        shuffle(split)
                        eee_2014j_50_60_ = ' '.join(split) # Turn the list back into a string
                        concatenatedEee2014j_50_60_ =' ' + eee_2014j_50_60_ + concatenatedEee2014j_50_60_
                elif data['imd_band'][i] == '80_90_':
                        eee_2014j_80_90_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ')  + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        eee_2014j_80_90_ = eee_2014j_80_90_.lower()
                        split = eee_2014j_80_90_.split()
                        shuffle(split)
                        eee_2014j_80_90_ = ' '.join(split) # Turn the list back into a string
                        concatenatedEee2014j_80_90_ =' ' + eee_2014j_80_90_ + concatenatedEee2014j_80_90_
                elif data['imd_band'][i] == '70_80_':
                        eee_2014j_70_80_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ')  + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        eee_2014j_70_80_ = eee_2014j_70_80_.lower()
                        split = eee_2014j_70_80_.split()
                        shuffle(split)
                        eee_2014j_70_80_ = ' '.join(split) # Turn the list back into a string
                        concatenatedEee2014j_70_80_ =' ' + eee_2014j_70_80_ + concatenatedEee2014j_70_80_
                elif data['imd_band'][i] == '29_39_':
                        eee_2014j_29_39_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ')  + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        eee_2014j_29_39_ = eee_2014j_29_39_.lower()
                        split = eee_2014j_29_39_.split()
                        shuffle(split)
                        eee_2014j_29_39_ = ' '.join(split) # Turn the list back into a string
                        concatenatedEee2014j_29_39_ =' ' + eee_2014j_29_39_ + concatenatedEee2014j_29_39_
                elif data['imd_band'][i] == '60_70_':
                        eee_2014j_60_70_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ')  + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        eee_2014j_60_70_ = eee_2014j_60_70_.lower()
                        split = eee_2014j_60_70_.split()
                        shuffle(split)
                        eee_2014j_60_70_ = ' '.join(split) # Turn the list back into a string
                        concatenatedEee2014j_60_70_ =' ' + eee_2014j_60_70_ + concatenatedEee2014j_60_70_
                elif data['imd_band'][i] == '40_50_':
                        eee_2014j_40_50_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ')  + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        eee_2014j_40_50_ = eee_2014j_40_50_.lower()
                        split = eee_2014j_40_50_.split()
                        shuffle(split)
                        eee_2014j_40_50_ = ' '.join(split) # Turn the list back into a string
                        concatenatedEee2014j_40_50_ =' ' + eee_2014j_40_50_ + concatenatedEee2014j_40_50_
                elif data['imd_band'][i] == '41_51_':
                        eee_2014j_41_51_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ')  + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        eee_2014j_41_51_ = eee_2014j_41_51_.lower()
                        split = eee_2014j_41_51_.split()
                        shuffle(split)
                        eee_2014j_41_51_ = ' '.join(split) # Turn the list back into a string
                        concatenatedEee2014j_41_51_ =' ' + eee_2014j_41_51_ + concatenatedEee2014j_41_51_
                elif data['imd_band'][i] == '10_20_':
                        eee_2014j_10_20_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ')  + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        eee_2014j_10_20_ = eee_2014j_10_20_.lower()
                        split = eee_2014j_10_20_.split()
                        shuffle(split)
                        eee_2014j_10_20_ = ' '.join(split) # Turn the list back into a string
                        concatenatedEee2014j_10_20_ =' ' + eee_2014j_10_20_ + concatenatedEee2014j_10_20_
                elif data['imd_band'][i] == '0_10_':
                        eee_2014j_0_10_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ')  + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        eee_2014j_0_10_ = eee_2014j_0_10_.lower()
                        split = eee_2014j_0_10_.split()
                        shuffle(split)
                        eee_2014j_0_10_ = ' '.join(split) # Turn the list back into a string
                        concatenatedEee2014j_0_10_ =' ' + eee_2014j_0_10_ + concatenatedEee2014j_0_10_
                elif data['imd_band'][i] == '33_43_':
                        eee_2014j_33_43_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ')  + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        eee_2014j_33_43_ = eee_2014j_33_43_.lower()
                        split = eee_2014j_33_43_.split()
                        shuffle(split)
                        eee_2014j_33_43_ = ' '.join(split) # Turn the list back into a string
                        concatenatedEee2014j_33_43_ =' ' + eee_2014j_33_43_ + concatenatedEee2014j_33_43_
                elif data['imd_band'][i] == '59_69_':
                        eee_2014j_59_69_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ')  + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        eee_2014j_59_69_ = eee_2014j_59_69_.lower()
                        split = eee_2014j_59_69_.split()
                        shuffle(split)
                        eee_2014j_59_69_ = ' '.join(split) # Turn the list back into a string
                        concatenatedEee2014j_59_69_ =' ' + eee_2014j_59_69_ + concatenatedEee2014j_59_69_
                elif data['imd_band'][i] == '45_55_':
                        eee_2014j_45_55_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ')  + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        eee_2014j_45_55_ = eee_2014j_45_55_.lower()
                        split = eee_2014j_45_55_.split()
                        shuffle(split)
                        eee_2014j_45_55_ = ' '.join(split) # Turn the list back into a string
                        concatenatedEee2014j_45_55_ =' ' + eee_2014j_45_55_ + concatenatedEee2014j_45_55_
                elif data['imd_band'][i] == '46_56_':
                        eee_2014j_46_56_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ')  + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        eee_2014j_46_56_ = eee_2014j_46_56_.lower()
                        split = eee_2014j_46_56_.split()
                        shuffle(split)
                        eee_2014j_46_56_ = ' '.join(split) # Turn the list back into a string
                        concatenatedEee2014j_46_56_ =' ' + eee_2014j_46_56_ + concatenatedEee2014j_46_56_    
        elif data['courses'][i] == 'FFF-2013B':
                if data['imd_band'][i] == '90_100_':
                        fff_2013b_90_100 = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ')  + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        fff_2013b_90_100_ = fff_2013b_90_100.lower()
                        split = fff_2013b_90_100_.split()
                        shuffle(split)
                        fff_2013b_90_100_ = ' '.join(split) # Turn the list back into a string
                        concatenatedFff2013b_90_100_ =' ' + fff_2013b_90_100_ + concatenatedFff2013b_90_100_
                elif data['imd_band'][i] == '20_30_':
                        fff_2013b_20_30_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ')  + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        fff_2013b_20_30_ = fff_2013b_20_30_.lower()
                        split = fff_2013b_20_30_.split()
                        shuffle(split)
                        fff_2013b_20_30_ = ' '.join(split) # Turn the list back into a string
                        concatenatedFff2013b_20_30_ =' ' + fff_2013b_20_30_ + concatenatedFff2013b_20_30_
                elif data['imd_band'][i] == '30_40_':
                        fff_2013b_30_40_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ')  + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        fff_2013b_30_40_ = fff_2013b_30_40_.lower()
                        split = fff_2013b_30_40_.split()
                        shuffle(split)
                        fff_2013b_30_40_ = ' '.join(split) # Turn the list back into a string
                        concatenatedFff2013b_30_40_ =' ' + fff_2013b_30_40_ + concatenatedFff2013b_30_40_
                elif data['imd_band'][i] == '50_60_':
                        fff_2013b_50_60_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ')  + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        fff_2013b_50_60_ = fff_2013b_50_60_.lower()
                        split = fff_2013b_50_60_.split()
                        shuffle(split)
                        fff_2013b_50_60_ = ' '.join(split) # Turn the list back into a string
                        concatenatedFff2013b_50_60_ =' ' + fff_2013b_50_60_ + concatenatedFff2013b_50_60_
                elif data['imd_band'][i] == '80_90_':
                        fff_2013b_80_90_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ')  + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        fff_2013b_80_90_ = fff_2013b_80_90_.lower()
                        split = fff_2013b_80_90_.split()
                        shuffle(split)
                        fff_2013b_80_90_ = ' '.join(split) # Turn the list back into a string
                        concatenatedFff2013b_80_90_ =' ' + fff_2013b_80_90_ + concatenatedFff2013b_80_90_
                elif data['imd_band'][i] == '70_80_':
                        fff_2013b_70_80_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ')  + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        fff_2013b_70_80_ = fff_2013b_70_80_.lower()
                        split = fff_2013b_70_80_.split()
                        shuffle(split)
                        fff_2013b_70_80_ = ' '.join(split) # Turn the list back into a string
                        concatenatedFff2013b_70_80_ =' ' + fff_2013b_70_80_ + concatenatedFff2013b_70_80_
                elif data['imd_band'][i] == '29_39_':
                        fff_2013b_29_39_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ')  + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        fff_2013b_29_39_ = fff_2013b_29_39_.lower()
                        split = fff_2013b_29_39_.split()
                        shuffle(split)
                        fff_2013b_29_39_ = ' '.join(split) # Turn the list back into a string
                        concatenatedFff2013b_29_39_ =' ' + fff_2013b_29_39_ + concatenatedFff2013b_29_39_
                elif data['imd_band'][i] == '60_70_':
                        fff_2013b_60_70_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ')  + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        fff_2013b_60_70_ = fff_2013b_60_70_.lower()
                        split = fff_2013b_60_70_.split()
                        shuffle(split)
                        fff_2013b_60_70_ = ' '.join(split) # Turn the list back into a string
                        concatenatedFff2013b_60_70_ =' ' + fff_2013b_60_70_ + concatenatedFff2013b_60_70_
                elif data['imd_band'][i] == '40_50_':
                        fff_2013b_40_50_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ')  + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        fff_2013b_40_50_ = fff_2013b_40_50_.lower()
                        split = fff_2013b_40_50_.split()
                        shuffle(split)
                        fff_2013b_40_50_ = ' '.join(split) # Turn the list back into a string
                        concatenatedFff2013b_40_50_ =' ' + fff_2013b_40_50_ + concatenatedFff2013b_40_50_
                elif data['imd_band'][i] == '41_51_':
                        fff_2013b_41_51_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ')  + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        fff_2013b_41_51_ = fff_2013b_41_51_.lower()
                        split = fff_2013b_41_51_.split()
                        shuffle(split)
                        fff_2013b_41_51_ = ' '.join(split) # Turn the list back into a string
                        concatenatedFff2013b_41_51_ =' ' + fff_2013b_41_51_ + concatenatedFff2013b_41_51_
                elif data['imd_band'][i] == '10_20_':
                        fff_2013b_10_20_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ')  + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        fff_2013b_10_20_ = fff_2013b_10_20_.lower()
                        split = fff_2013b_10_20_.split()
                        shuffle(split)
                        fff_2013b_10_20_ = ' '.join(split) # Turn the list back into a string
                        concatenatedFff2013b_10_20_ =' ' + fff_2013b_10_20_ + concatenatedFff2013b_10_20_
                elif data['imd_band'][i] == '0_10_':
                        fff_2013b_0_10_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ')  + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        fff_2013b_0_10_ = fff_2013b_0_10_.lower()
                        split = fff_2013b_0_10_.split()
                        shuffle(split)
                        fff_2013b_0_10_ = ' '.join(split) # Turn the list back into a string
                        concatenatedFff2013b_0_10_ =' ' + fff_2013b_0_10_ + concatenatedFff2013b_0_10_
                elif data['imd_band'][i] == '33_43_':
                        fff_2013b_33_43_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ')  + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        fff_2013b_33_43_ = fff_2013b_33_43_.lower()
                        split = fff_2013b_33_43_.split()
                        shuffle(split)
                        fff_2013b_33_43_ = ' '.join(split) # Turn the list back into a string
                        concatenatedFff2013b_33_43_ =' ' + fff_2013b_33_43_ + concatenatedFff2013b_33_43_
                elif data['imd_band'][i] == '59_69_':
                        fff_2013b_59_69_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ')  + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        fff_2013b_59_69_ = fff_2013b_59_69_.lower()
                        split = fff_2013b_59_69_.split()
                        shuffle(split)
                        fff_2013b_59_69_ = ' '.join(split) # Turn the list back into a string
                        concatenatedFff2013b_59_69_ =' ' + fff_2013b_59_69_ + concatenatedFff2013b_59_69_
                elif data['imd_band'][i] == '45_55_':
                        fff_2013b_45_55_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ')  + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        fff_2013b_45_55_ = fff_2013b_45_55_.lower()
                        split = fff_2013b_45_55_.split()
                        shuffle(split)
                        fff_2013b_45_55_ = ' '.join(split) # Turn the list back into a string
                        concatenatedFff2013b_45_55_ =' ' + fff_2013b_45_55_ + concatenatedFff2013b_45_55_
                elif data['imd_band'][i] == '46_56_':
                        fff_2013b_46_56_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ')  + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        fff_2013b_46_56_ = fff_2013b_46_56_.lower()
                        split = fff_2013b_46_56_.split()
                        shuffle(split)
                        fff_2013b_46_56_ = ' '.join(split) # Turn the list back into a string
                        concatenatedFff2013b_46_56_ =' ' + fff_2013b_46_56_ + concatenatedFff2013b_46_56_
        elif data['courses'][i] == 'FFF-2013J':
                if data['imd_band'][i] == '90_100_': 

                        fff_2013j_90_100 = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ')  + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ') 

                        fff_2013j_90_100_ = fff_2013j_90_100.lower() 

                        split = fff_2013j_90_100_.split() 

                        shuffle(split) 

                        fff_2013j_90_100_ = ' '.join(split) # Turn the list back into a string 

                        concatenatedFff2013j_90_100_ =' ' + fff_2013j_90_100_ + concatenatedFff2013j_90_100_ 

                elif data['imd_band'][i] == '20_30_': 

                        fff_2013j_20_30_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ')  + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ') 

                        fff_2013j_20_30_ = fff_2013j_20_30_.lower() 

                        split = fff_2013j_20_30_.split() 

                        shuffle(split) 

                        fff_2013j_20_30_ = ' '.join(split) # Turn the list back into a string 

                        concatenatedFff2013j_20_30_ =' ' + fff_2013j_20_30_ + concatenatedFff2013j_20_30_ 

                elif data['imd_band'][i] == '30_40_': 

                        fff_2013j_30_40_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ')  + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ') 

                        fff_2013j_30_40_ = fff_2013j_30_40_.lower() 

                        split = fff_2013j_30_40_.split() 

                        shuffle(split) 

                        fff_2013j_30_40_ = ' '.join(split) # Turn the list back into a string 

                        concatenatedFff2013j_30_40_ =' ' + fff_2013j_30_40_ + concatenatedFff2013j_30_40_ 

                elif data['imd_band'][i] == '50_60_': 

                        fff_2013j_50_60_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ')  + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ') 

                        fff_2013j_50_60_ = fff_2013j_50_60_.lower() 

                        split = fff_2013j_50_60_.split() 

                        shuffle(split) 

                        fff_2013j_50_60_ = ' '.join(split) # Turn the list back into a string 

                        concatenatedFff2013j_50_60_ =' ' + fff_2013j_50_60_ + concatenatedFff2013j_50_60_ 

                elif data['imd_band'][i] == '80_90_': 

                        fff_2013j_80_90_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ')  + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ') 

                        fff_2013j_80_90_ = fff_2013j_80_90_.lower() 

                        split = fff_2013j_80_90_.split() 

                        shuffle(split) 

                        fff_2013j_80_90_ = ' '.join(split) # Turn the list back into a string 

                        concatenatedFff2013j_80_90_ =' ' + fff_2013j_80_90_ + concatenatedFff2013j_80_90_ 

                elif data['imd_band'][i] == '70_80_': 

                        fff_2013j_70_80_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ')  + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ') 

                        fff_2013j_70_80_ = fff_2013j_70_80_.lower() 

                        split = fff_2013j_70_80_.split() 

                        shuffle(split) 

                        fff_2013j_70_80_ = ' '.join(split) # Turn the list back into a string 

                        concatenatedFff2013j_70_80_ =' ' + fff_2013j_70_80_ + concatenatedFff2013j_70_80_ 

                elif data['imd_band'][i] == '29_39_': 

                        fff_2013j_29_39_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ')  + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ') 

                        fff_2013j_29_39_ = fff_2013j_29_39_.lower() 

                        split = fff_2013j_29_39_.split() 

                        shuffle(split) 

                        fff_2013j_29_39_ = ' '.join(split) # Turn the list back into a string 

                        concatenatedFff2013j_29_39_ =' ' + fff_2013j_29_39_ + concatenatedFff2013j_29_39_ 

                elif data['imd_band'][i] == '60_70_': 

                        fff_2013j_60_70_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ')  + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ') 

                        fff_2013j_60_70_ = fff_2013j_60_70_.lower() 

                        split = fff_2013j_60_70_.split() 

                        shuffle(split) 

                        fff_2013j_60_70_ = ' '.join(split) # Turn the list back into a string 

                        concatenatedFff2013j_60_70_ =' ' + fff_2013j_60_70_ + concatenatedFff2013j_60_70_ 

                elif data['imd_band'][i] == '40_50_': 

                        fff_2013j_40_50_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ')  + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ') 

                        fff_2013j_40_50_ = fff_2013j_40_50_.lower() 

                        split = fff_2013j_40_50_.split() 

                        shuffle(split) 

                        fff_2013j_40_50_ = ' '.join(split) # Turn the list back into a string 

                        concatenatedFff2013j_40_50_ =' ' + fff_2013j_40_50_ + concatenatedFff2013j_40_50_ 

                elif data['imd_band'][i] == '41_51_': 

                        fff_2013j_41_51_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ')  + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ') 

                        fff_2013j_41_51_ = fff_2013j_41_51_.lower() 

                        split = fff_2013j_41_51_.split() 

                        shuffle(split) 

                        fff_2013j_41_51_ = ' '.join(split) # Turn the list back into a string 

                        concatenatedFff2013j_41_51_ =' ' + fff_2013j_41_51_ + concatenatedFff2013j_41_51_ 

                elif data['imd_band'][i] == '10_20_': 

                        fff_2013j_10_20_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ')  + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ') 

                        fff_2013j_10_20_ = fff_2013j_10_20_.lower() 

                        split = fff_2013j_10_20_.split() 

                        shuffle(split) 

                        fff_2013j_10_20_ = ' '.join(split) # Turn the list back into a string 

                        concatenatedFff2013j_10_20_ =' ' + fff_2013j_10_20_ + concatenatedFff2013j_10_20_ 

                elif data['imd_band'][i] == '0_10_': 

                        fff_2013j_0_10_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ')  + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ') 
                        fff_2013j_0_10_ = fff_2013j_0_10_.lower() 
                        split = fff_2013j_0_10_.split() 
                        shuffle(split) 
                        fff_2013j_0_10_ = ' '.join(split) # Turn the list back into a string 
                        concatenatedFff2013j_0_10_ =' ' + fff_2013j_0_10_ + concatenatedFff2013j_0_10_ 

                elif data['imd_band'][i] == '33_43_': 

                        fff_2013j_33_43_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ')  + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ') 
                        fff_2013j_33_43_ = fff_2013j_33_43_.lower() 
                        split = fff_2013j_33_43_.split() 
                        shuffle(split) 
                        fff_2013j_33_43_ = ' '.join(split) # Turn the list back into a string 
                        concatenatedFff2013j_33_43_ =' ' + fff_2013j_33_43_ + concatenatedFff2013j_33_43_ 

                elif data['imd_band'][i] == '59_69_': 

                        fff_2013j_59_69_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ')  + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ') 
                        fff_2013j_59_69_ = fff_2013j_59_69_.lower() 
                        split = fff_2013j_59_69_.split() 
                        shuffle(split) 
                        fff_2013j_59_69_ = ' '.join(split) # Turn the list back into a string 
                        concatenatedFff2013j_59_69_ =' ' + fff_2013j_59_69_ + concatenatedFff2013j_59_69_ 

                elif data['imd_band'][i] == '45_55_': 

                        fff_2013j_45_55_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ')  + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ') 
                        fff_2013j_45_55_ = fff_2013j_45_55_.lower() 
                        split = fff_2013j_45_55_.split() 
                        shuffle(split) 
                        fff_2013j_45_55_ = ' '.join(split) # Turn the list back into a string 
                        concatenatedFff2013j_45_55_ =' ' + fff_2013j_45_55_ + concatenatedFff2013j_45_55_ 

                elif data['imd_band'][i] == '46_56_': 

                        fff_2013j_46_56_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ')  + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ') 
                        fff_2013j_46_56_ = fff_2013j_46_56_.lower() 
                        split = fff_2013j_46_56_.split() 
                        shuffle(split) 
                        fff_2013j_46_56_ = ' '.join(split) # Turn the list back into a string 
                        concatenatedFff2013j_46_56_ =' ' + fff_2013j_46_56_ + concatenatedFff2013j_46_56_
        elif data['courses'][i] == 'FFF-2014B':
                if data['imd_band'][i] == '90_100_': 

                        fff_2014b_90_100 = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ')  + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ') 

                        fff_2014b_90_100_ = fff_2014b_90_100.lower() 

                        split = fff_2014b_90_100_.split() 

                        shuffle(split) 

                        fff_2014b_90_100_ = ' '.join(split) # Turn the list back into a string 

                        concatenatedFff2014b_90_100_ =' ' + fff_2014b_90_100_ + concatenatedFff2014b_90_100_ 

                elif data['imd_band'][i] == '20_30_': 

                        fff_2014b_20_30_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ')  + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ') 

                        fff_2014b_20_30_ = fff_2014b_20_30_.lower() 

                        split = fff_2014b_20_30_.split() 

                        shuffle(split) 

                        fff_2014b_20_30_ = ' '.join(split) # Turn the list back into a string 

                        concatenatedFff2014b_20_30_ =' ' + fff_2014b_20_30_ + concatenatedFff2014b_20_30_ 

                elif data['imd_band'][i] == '30_40_': 

                        fff_2014b_30_40_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ')  + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ') 

                        fff_2014b_30_40_ = fff_2014b_30_40_.lower() 

                        split = fff_2014b_30_40_.split() 

                        shuffle(split) 

                        fff_2014b_30_40_ = ' '.join(split) # Turn the list back into a string 

                        concatenatedFff2014b_30_40_ =' ' + fff_2014b_30_40_ + concatenatedFff2014b_30_40_ 

                elif data['imd_band'][i] == '50_60_': 

                        fff_2014b_50_60_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ')  + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ') 

                        fff_2014b_50_60_ = fff_2014b_50_60_.lower() 

                        split = fff_2014b_50_60_.split() 

                        shuffle(split) 

                        fff_2014b_50_60_ = ' '.join(split) # Turn the list back into a string 

                        concatenatedFff2014b_50_60_ =' ' + fff_2014b_50_60_ + concatenatedFff2014b_50_60_ 

                elif data['imd_band'][i] == '80_90_': 

                        fff_2014b_80_90_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ')  + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ') 

                        fff_2014b_80_90_ = fff_2014b_80_90_.lower() 

                        split = fff_2014b_80_90_.split() 

                        shuffle(split) 

                        fff_2014b_80_90_ = ' '.join(split) # Turn the list back into a string 

                        concatenatedFff2014b_80_90_ =' ' + fff_2014b_80_90_ + concatenatedFff2014b_80_90_ 

                elif data['imd_band'][i] == '70_80_': 

                        fff_2014b_70_80_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ')  + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ') 

                        fff_2014b_70_80_ = fff_2014b_70_80_.lower() 

                        split = fff_2014b_70_80_.split() 

                        shuffle(split) 

                        fff_2014b_70_80_ = ' '.join(split) # Turn the list back into a string 

                        concatenatedFff2014b_70_80_ =' ' + fff_2014b_70_80_ + concatenatedFff2014b_70_80_ 

                elif data['imd_band'][i] == '29_39_': 

                        fff_2014b_29_39_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ')  + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ') 

                        fff_2014b_29_39_ = fff_2014b_29_39_.lower() 

                        split = fff_2014b_29_39_.split() 

                        shuffle(split) 

                        fff_2014b_29_39_ = ' '.join(split) # Turn the list back into a string 

                        concatenatedFff2014b_29_39_ =' ' + fff_2014b_29_39_ + concatenatedFff2014b_29_39_ 

                elif data['imd_band'][i] == '60_70_': 

                        fff_2014b_60_70_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ')  + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ') 

                        fff_2014b_60_70_ = fff_2014b_60_70_.lower() 

                        split = fff_2014b_60_70_.split() 

                        shuffle(split) 

                        fff_2014b_60_70_ = ' '.join(split) # Turn the list back into a string 

                        concatenatedFff2014b_60_70_ =' ' + fff_2014b_60_70_ + concatenatedFff2014b_60_70_ 

                elif data['imd_band'][i] == '40_50_': 

                        fff_2014b_40_50_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ')  + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ') 

                        fff_2014b_40_50_ = fff_2014b_40_50_.lower() 

                        split = fff_2014b_40_50_.split() 

                        shuffle(split) 

                        fff_2014b_40_50_ = ' '.join(split) # Turn the list back into a string 

                        concatenatedFff2014b_40_50_ =' ' + fff_2014b_40_50_ + concatenatedFff2014b_40_50_ 

                elif data['imd_band'][i] == '41_51_': 

                        fff_2014b_41_51_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ')  + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ') 

                        fff_2014b_41_51_ = fff_2014b_41_51_.lower() 

                        split = fff_2014b_41_51_.split() 

                        shuffle(split) 

                        fff_2014b_41_51_ = ' '.join(split) # Turn the list back into a string 

                        concatenatedFff2014b_41_51_ =' ' + fff_2014b_41_51_ + concatenatedFff2014b_41_51_ 

                elif data['imd_band'][i] == '10_20_': 

                        fff_2014b_10_20_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ')  + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ') 

                        fff_2014b_10_20_ = fff_2014b_10_20_.lower() 

                        split = fff_2014b_10_20_.split() 

                        shuffle(split) 

                        fff_2014b_10_20_ = ' '.join(split) # Turn the list back into a string 

                        concatenatedFff2014b_10_20_ =' ' + fff_2014b_10_20_ + concatenatedFff2014b_10_20_ 

                elif data['imd_band'][i] == '0_10_': 

                        fff_2014b_0_10_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ')  + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ') 

                        fff_2014b_0_10_ = fff_2014b_0_10_.lower() 

                        split = fff_2014b_0_10_.split() 

                        shuffle(split) 

                        fff_2014b_0_10_ = ' '.join(split) # Turn the list back into a string 

                        concatenatedFff2014b_0_10_ =' ' + fff_2014b_0_10_ + concatenatedFff2014b_0_10_ 

                elif data['imd_band'][i] == '33_43_': 

                        fff_2014b_33_43_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ')  + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ') 

                        fff_2014b_33_43_ = fff_2014b_33_43_.lower() 

                        split = fff_2014b_33_43_.split() 

                        shuffle(split) 

                        fff_2014b_33_43_ = ' '.join(split) # Turn the list back into a string 

                        concatenatedFff2014b_33_43_ =' ' + fff_2014b_33_43_ + concatenatedFff2014b_33_43_ 

                elif data['imd_band'][i] == '59_69_': 

                        fff_2014b_59_69_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ')  + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ') 

                        fff_2014b_59_69_ = fff_2014b_59_69_.lower() 

                        split = fff_2014b_59_69_.split() 

                        shuffle(split) 

                        fff_2014b_59_69_ = ' '.join(split) # Turn the list back into a string 

                        concatenatedFff2014b_59_69_ =' ' + fff_2014b_59_69_ + concatenatedFff2014b_59_69_ 

                elif data['imd_band'][i] == '45_55_': 

                        fff_2014b_45_55_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ')  + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ') 

                        fff_2014b_45_55_ = fff_2014b_45_55_.lower() 

                        split = fff_2014b_45_55_.split() 

                        shuffle(split) 

                        fff_2014b_45_55_ = ' '.join(split) # Turn the list back into a string 

                        concatenatedFff2014b_45_55_ =' ' + fff_2014b_45_55_ + concatenatedFff2014b_45_55_ 

                elif data['imd_band'][i] == '46_56_': 

                        fff_2014b_46_56_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ')  + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ') 

                        fff_2014b_46_56_ = fff_2014b_46_56_.lower() 

                        split = fff_2014b_46_56_.split() 

                        shuffle(split) 

                        fff_2014b_46_56_ = ' '.join(split) # Turn the list back into a string 

                        concatenatedFff2014b_46_56_ =' ' + fff_2014b_46_56_ + concatenatedFff2014b_46_56_ 

 
        elif data['courses'][i] == 'FFF-2014J':
                if data['imd_band'][i] == '90_100_': 

                        fff_2014j_90_100 = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ')  + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ') 

                        fff_2014j_90_100_ = fff_2014j_90_100.lower() 

                        split = fff_2014j_90_100_.split() 

                        shuffle(split) 

                        fff_2014j_90_100_ = ' '.join(split) # Turn the list back into a string 

                        concatenatedFff2014j_90_100_ =' ' + fff_2014j_90_100_ + concatenatedFff2014j_90_100_ 

                elif data['imd_band'][i] == '20_30_': 

                        fff_2014j_20_30_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ')  + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ') 

                        fff_2014j_20_30_ = fff_2014j_20_30_.lower() 

                        split = fff_2014j_20_30_.split() 

                        shuffle(split) 

                        fff_2014j_20_30_ = ' '.join(split) # Turn the list back into a string 

                        concatenatedFff2014j_20_30_ =' ' + fff_2014j_20_30_ + concatenatedFff2014j_20_30_ 

                elif data['imd_band'][i] == '30_40_': 

                        fff_2014j_30_40_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ')  + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ') 

                        fff_2014j_30_40_ = fff_2014j_30_40_.lower() 

                        split = fff_2014j_30_40_.split() 

                        shuffle(split) 

                        fff_2014j_30_40_ = ' '.join(split) # Turn the list back into a string 

                        concatenatedFff2014j_30_40_ =' ' + fff_2014j_30_40_ + concatenatedFff2014j_30_40_ 

                elif data['imd_band'][i] == '50_60_': 

                        fff_2014j_50_60_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ')  + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ') 

                        fff_2014j_50_60_ = fff_2014j_50_60_.lower() 

                        split = fff_2014j_50_60_.split() 

                        shuffle(split) 

                        fff_2014j_50_60_ = ' '.join(split) # Turn the list back into a string 

                        concatenatedFff2014j_50_60_ =' ' + fff_2014j_50_60_ + concatenatedFff2014j_50_60_ 

                elif data['imd_band'][i] == '80_90_': 

                        fff_2014j_80_90_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ')  + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ') 

                        fff_2014j_80_90_ = fff_2014j_80_90_.lower() 

                        split = fff_2014j_80_90_.split() 

                        shuffle(split) 

                        fff_2014j_80_90_ = ' '.join(split) # Turn the list back into a string 

                        concatenatedFff2014j_80_90_ =' ' + fff_2014j_80_90_ + concatenatedFff2014j_80_90_ 

                elif data['imd_band'][i] == '70_80_': 

                        fff_2014j_70_80_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ')  + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ') 

                        fff_2014j_70_80_ = fff_2014j_70_80_.lower() 

                        split = fff_2014j_70_80_.split() 

                        shuffle(split) 

                        fff_2014j_70_80_ = ' '.join(split) # Turn the list back into a string 

                        concatenatedFff2014j_70_80_ =' ' + fff_2014j_70_80_ + concatenatedFff2014j_70_80_ 

                elif data['imd_band'][i] == '29_39_': 

                        fff_2014j_29_39_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ')  + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ') 

                        fff_2014j_29_39_ = fff_2014j_29_39_.lower() 

                        split = fff_2014j_29_39_.split() 

                        shuffle(split) 

                        fff_2014j_29_39_ = ' '.join(split) # Turn the list back into a string 

                        concatenatedFff2014j_29_39_ =' ' + fff_2014j_29_39_ + concatenatedFff2014j_29_39_ 

                elif data['imd_band'][i] == '60_70_': 

                        fff_2014j_60_70_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ')  + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ') 

                        fff_2014j_60_70_ = fff_2014j_60_70_.lower() 

                        split = fff_2014j_60_70_.split() 

                        shuffle(split) 

                        fff_2014j_60_70_ = ' '.join(split) # Turn the list back into a string 

                        concatenatedFff2014j_60_70_ =' ' + fff_2014j_60_70_ + concatenatedFff2014j_60_70_ 

                elif data['imd_band'][i] == '40_50_': 

                        fff_2014j_40_50_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ')  + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ') 

                        fff_2014j_40_50_ = fff_2014j_40_50_.lower() 

                        split = fff_2014j_40_50_.split() 

                        shuffle(split) 

                        fff_2014j_40_50_ = ' '.join(split) # Turn the list back into a string 

                        concatenatedFff2014j_40_50_ =' ' + fff_2014j_40_50_ + concatenatedFff2014j_40_50_ 

                elif data['imd_band'][i] == '41_51_': 

                        fff_2014j_41_51_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ')  + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ') 

                        fff_2014j_41_51_ = fff_2014j_41_51_.lower() 

                        split = fff_2014j_41_51_.split() 

                        shuffle(split) 

                        fff_2014j_41_51_ = ' '.join(split) # Turn the list back into a string 

                        concatenatedFff2014j_41_51_ =' ' + fff_2014j_41_51_ + concatenatedFff2014j_41_51_ 

                elif data['imd_band'][i] == '10_20_': 

                        fff_2014j_10_20_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ')  + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ') 

                        fff_2014j_10_20_ = fff_2014j_10_20_.lower() 

                        split = fff_2014j_10_20_.split() 

                        shuffle(split) 

                        fff_2014j_10_20_ = ' '.join(split) # Turn the list back into a string 

                        concatenatedFff2014j_10_20_ =' ' + fff_2014j_10_20_ + concatenatedFff2014j_10_20_ 

                elif data['imd_band'][i] == '0_10_': 

                        fff_2014j_0_10_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ')  + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ') 

                        fff_2014j_0_10_ = fff_2014j_0_10_.lower() 

                        split = fff_2014j_0_10_.split() 

                        shuffle(split) 

                        fff_2014j_0_10_ = ' '.join(split) # Turn the list back into a string 

                        concatenatedFff2014j_0_10_ =' ' + fff_2014j_0_10_ + concatenatedFff2014j_0_10_ 

                elif data['imd_band'][i] == '33_43_': 

                        fff_2014j_33_43_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ')  + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ') 

                        fff_2014j_33_43_ = fff_2014j_33_43_.lower() 

                        split = fff_2014j_33_43_.split() 

                        shuffle(split) 

                        fff_2014j_33_43_ = ' '.join(split) # Turn the list back into a string 

                        concatenatedFff2014j_33_43_ =' ' + fff_2014j_33_43_ + concatenatedFff2014j_33_43_ 

                elif data['imd_band'][i] == '59_69_': 

                        fff_2014j_59_69_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ')  + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ') 

                        fff_2014j_59_69_ = fff_2014j_59_69_.lower() 

                        split = fff_2014j_59_69_.split() 

                        shuffle(split) 
                        fff_2014j_59_69_ = ' '.join(split) # Turn the list back into a string 

                        concatenatedFff2014j_59_69_ =' ' + fff_2014j_59_69_ + concatenatedFff2014j_59_69_ 

                elif data['imd_band'][i] == '45_55_': 

                        fff_2014j_45_55_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ')  + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ') 
                        fff_2014j_45_55_ = fff_2014j_45_55_.lower() 
                        split = fff_2014j_45_55_.split() 
                        shuffle(split) 
                        fff_2014j_45_55_ = ' '.join(split) # Turn the list back into a string 
                        concatenatedFff2014j_45_55_ =' ' + fff_2014j_45_55_ + concatenatedFff2014j_45_55_ 
                        
                elif data['imd_band'][i] == '46_56_': 

                        fff_2014j_46_56_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ')  + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ') 
                        fff_2014j_46_56_ = fff_2014j_46_56_.lower() 
                        split = fff_2014j_46_56_.split() 
                        shuffle(split) 
                        fff_2014j_46_56_ = ' '.join(split) # Turn the list back into a string 
                        concatenatedFff2014j_46_56_ =' ' + fff_2014j_46_56_ + concatenatedFff2014j_46_56_ 

 
        elif data['courses'][i] == 'GGG-2013J':
                if data['imd_band'][i] == '90_100_':
                        ggg_2013j_90_100_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ')  + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        ggg_2013j_90_100_ = ggg_2013j_90_100_.lower()
                        split = ggg_2013j_90_100_.split()
                        shuffle(split)
                        ggg_2013j_90_100_ = ' '.join(split) # Turn the list back into a string
                        concatenatedGgg2013j_90_100_ =' ' + ggg_2013j_90_100_ + concatenatedGgg2013j_90_100_
                elif data['imd_band'][i] == '20_30_':
                        ggg_2013j_20_30_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ')  + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        ggg_2013j_20_30_ = ggg_2013j_20_30_.lower()
                        split = ggg_2013j_20_30_.split()
                        shuffle(split)
                        ggg_2013j_20_30_ = ' '.join(split) # Turn the list back into a string
                        concatenatedGgg2013j_20_30_ =' ' + ggg_2013j_20_30_ + concatenatedGgg2013j_20_30_
                elif data['imd_band'][i] == '30_40_':
                        ggg_2013j_30_40_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ')  + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        ggg_2013j_30_40_ = ggg_2013j_30_40_.lower()
                        split = ggg_2013j_30_40_.split()
                        shuffle(split)
                        ggg_2013j_30_40_ = ' '.join(split) # Turn the list back into a string
                        concatenatedGgg2013j_30_40_ =' ' + ggg_2013j_30_40_ + concatenatedGgg2013j_30_40_
                elif data['imd_band'][i] == '50_60_':
                        ggg_2013j_50_60_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ')  + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        ggg_2013j_50_60_ = ggg_2013j_50_60_.lower()
                        split = ggg_2013j_50_60_.split()
                        shuffle(split)
                        ggg_2013j_50_60_ = ' '.join(split) # Turn the list back into a string
                        concatenatedGgg2013j_50_60_ =' ' + ggg_2013j_50_60_ + concatenatedGgg2013j_50_60_
                elif data['imd_band'][i] == '80_90_':
                        ggg_2013j_80_90_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ')  + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        ggg_2013j_80_90_ = ggg_2013j_80_90_.lower()
                        split = ggg_2013j_80_90_.split()
                        shuffle(split)
                        ggg_2013j_80_90_ = ' '.join(split) # Turn the list back into a string
                        concatenatedGgg2013j_80_90_ =' ' + ggg_2013j_80_90_ + concatenatedGgg2013j_80_90_
                elif data['imd_band'][i] == '70_80_':
                        ggg_2013j_70_80_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ')  + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        ggg_2013j_70_80_ = ggg_2013j_70_80_.lower()
                        split = ggg_2013j_70_80_.split()
                        shuffle(split)
                        ggg_2013j_70_80_ = ' '.join(split) # Turn the list back into a string
                        concatenatedGgg2013j_70_80_ =' ' + ggg_2013j_70_80_ + concatenatedGgg2013j_70_80_
                elif data['imd_band'][i] == '29_39_':
                        ggg_2013j_29_39_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ')  + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        ggg_2013j_29_39_ = ggg_2013j_29_39_.lower()
                        split = ggg_2013j_29_39_.split()
                        shuffle(split)
                        ggg_2013j_29_39_ = ' '.join(split) # Turn the list back into a string
                        concatenatedGgg2013j_29_39_ =' ' + ggg_2013j_29_39_ + concatenatedGgg2013j_29_39_
                elif data['imd_band'][i] == '60_70_':
                        ggg_2013j_60_70_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ')  + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        ggg_2013j_60_70_ = ggg_2013j_60_70_.lower()
                        split = ggg_2013j_60_70_.split()
                        shuffle(split)
                        ggg_2013j_60_70_ = ' '.join(split) # Turn the list back into a string
                        concatenatedGgg2013j_60_70_ =' ' + ggg_2013j_60_70_ + concatenatedGgg2013j_60_70_
                elif data['imd_band'][i] == '40_50_':
                        ggg_2013j_40_50_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ')  + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        ggg_2013j_40_50_ = ggg_2013j_40_50_.lower()
                        split = ggg_2013j_40_50_.split()
                        shuffle(split)
                        ggg_2013j_40_50_ = ' '.join(split) # Turn the list back into a string
                        concatenatedGgg2013j_40_50_ =' ' + ggg_2013j_40_50_ + concatenatedGgg2013j_40_50_
                elif data['imd_band'][i] == '41_51_':
                        ggg_2013j_41_51_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ')  + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        ggg_2013j_41_51_ = ggg_2013j_41_51_.lower()
                        split = ggg_2013j_41_51_.split()
                        shuffle(split)
                        ggg_2013j_41_51_ = ' '.join(split) # Turn the list back into a string
                        concatenatedGgg2013j_41_51_ =' ' + ggg_2013j_41_51_ + concatenatedGgg2013j_41_51_
                elif data['imd_band'][i] == '10_20_':
                        ggg_2013j_10_20_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ')  + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        ggg_2013j_10_20_ = ggg_2013j_10_20_.lower()
                        split = ggg_2013j_10_20_.split()
                        shuffle(split)
                        ggg_2013j_10_20_ = ' '.join(split) # Turn the list back into a string
                        concatenatedGgg2013j_10_20_ =' ' + ggg_2013j_10_20_ + concatenatedGgg2013j_10_20_
                elif data['imd_band'][i] == '0_10_':
                        ggg_2013j_0_10_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ')  + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        ggg_2013j_0_10_ = ggg_2013j_0_10_.lower()
                        split = ggg_2013j_0_10_.split()
                        shuffle(split)
                        ggg_2013j_0_10_ = ' '.join(split) # Turn the list back into a string
                        concatenatedGgg2013j_0_10_ =' ' + ggg_2013j_0_10_ + concatenatedGgg2013j_0_10_
                elif data['imd_band'][i] == '33_43_':
                        ggg_2013j_33_43_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ')  + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        ggg_2013j_33_43_ = ggg_2013j_33_43_.lower()
                        split = ggg_2013j_33_43_.split()
                        shuffle(split)
                        ggg_2013j_33_43_ = ' '.join(split) # Turn the list back into a string
                        concatenatedGgg2013j_33_43_ =' ' + ggg_2013j_33_43_ + concatenatedGgg2013j_33_43_
                elif data['imd_band'][i] == '59_69_':
                        ggg_2013j_59_69_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ')  + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        ggg_2013j_59_69_ = ggg_2013j_59_69_.lower()
                        split = ggg_2013j_59_69_.split()
                        shuffle(split)
                        ggg_2013j_59_69_ = ' '.join(split) # Turn the list back into a string
                        concatenatedGgg2013j_59_69_ =' ' + ggg_2013j_59_69_ + concatenatedGgg2013j_59_69_
                elif data['imd_band'][i] == '45_55_':
                        ggg_2013j_45_55_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ')  + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        ggg_2013j_45_55_ = ggg_2013j_45_55_.lower()
                        split = ggg_2013j_45_55_.split()
                        shuffle(split)
                        ggg_2013j_45_55_ = ' '.join(split) # Turn the list back into a string
                        concatenatedGgg2013j_45_55_ =' ' + ggg_2013j_45_55_ + concatenatedGgg2013j_45_55_
                elif data['imd_band'][i] == '46_56_':
                        ggg_2013j_46_56_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ')  + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        ggg_2013j_46_56_ = ggg_2013j_46_56_.lower()
                        split = ggg_2013j_46_56_.split()
                        shuffle(split)
                        ggg_2013j_46_56_ = ' '.join(split) # Turn the list back into a string
                        concatenatedGgg2013j_46_56_ =' ' + ggg_2013j_46_56_ + concatenatedGgg2013j_46_56_
        elif data['courses'][i] == 'GGG-2014B':
                if data['imd_band'][i] == '90_100_':
                        ggg_2014b_90_100_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ')  + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        ggg_2014b_90_100_ = ggg_2014b_90_100_.lower()
                        split = ggg_2014b_90_100_.split()
                        shuffle(split)
                        ggg_2014b_90_100_ = ' '.join(split) # Turn the list back into a string
                        concatenatedGgg2014b_90_100_ =' ' + ggg_2014b_90_100_ + concatenatedGgg2014b_90_100_
                elif data['imd_band'][i] == '20_30_':
                        ggg_2014b_20_30_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ')  + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        ggg_2014b_20_30_ = ggg_2014b_20_30_.lower()
                        split = ggg_2014b_20_30_.split()
                        shuffle(split)
                        ggg_2014b_20_30_ = ' '.join(split) # Turn the list back into a string
                        concatenatedGgg2014b_20_30_ =' ' + ggg_2014b_20_30_ + concatenatedGgg2014b_20_30_
                elif data['imd_band'][i] == '30_40_':
                        ggg_2014b_30_40_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ')  + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        ggg_2014b_30_40_ = ggg_2014b_30_40_.lower()
                        split = ggg_2014b_30_40_.split()
                        shuffle(split)
                        ggg_2014b_30_40_ = ' '.join(split) # Turn the list back into a string
                        concatenatedGgg2014b_30_40_ =' ' + ggg_2014b_30_40_ + concatenatedGgg2014b_30_40_
                elif data['imd_band'][i] == '50_60_':
                        ggg_2014b_50_60_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ')  + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        ggg_2014b_50_60_ = ggg_2014b_50_60_.lower()
                        split = ggg_2014b_50_60_.split()
                        shuffle(split)
                        ggg_2014b_50_60_ = ' '.join(split) # Turn the list back into a string
                        concatenatedGgg2014b_50_60_ =' ' + ggg_2014b_50_60_ + concatenatedGgg2014b_50_60_
                elif data['imd_band'][i] == '80_90_':
                        ggg_2014b_80_90_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ')  + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        ggg_2014b_80_90_ = ggg_2014b_80_90_.lower()
                        split = ggg_2014b_80_90_.split()
                        shuffle(split)
                        ggg_2014b_80_90_ = ' '.join(split) # Turn the list back into a string
                        concatenatedGgg2014b_80_90_ =' ' + ggg_2014b_80_90_ + concatenatedGgg2014b_80_90_
                elif data['imd_band'][i] == '70_80_':
                        ggg_2014b_70_80_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ')  + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        ggg_2014b_70_80_ = ggg_2014b_70_80_.lower()
                        split = ggg_2014b_70_80_.split()
                        shuffle(split)
                        ggg_2014b_70_80_ = ' '.join(split) # Turn the list back into a string
                        concatenatedGgg2014b_70_80_ =' ' + ggg_2014b_70_80_ + concatenatedGgg2014b_70_80_
                elif data['imd_band'][i] == '29_39_':
                        ggg_2014b_29_39_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ')  + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        ggg_2014b_29_39_ = ggg_2014b_29_39_.lower()
                        split = ggg_2014b_29_39_.split()
                        shuffle(split)
                        ggg_2014b_29_39_ = ' '.join(split) # Turn the list back into a string
                        concatenatedGgg2014b_29_39_ =' ' + ggg_2014b_29_39_ + concatenatedGgg2014b_29_39_
                elif data['imd_band'][i] == '60_70_':
                        ggg_2014b_60_70_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ')  + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        ggg_2014b_60_70_ = ggg_2014b_60_70_.lower()
                        split = ggg_2014b_60_70_.split()
                        shuffle(split)
                        ggg_2014b_60_70_ = ' '.join(split) # Turn the list back into a string
                        concatenatedGgg2014b_60_70_ =' ' + ggg_2014b_60_70_ + concatenatedGgg2014b_60_70_
                elif data['imd_band'][i] == '40_50_':
                        ggg_2014b_40_50_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ')  + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        ggg_2014b_40_50_ = ggg_2014b_40_50_.lower()
                        split = ggg_2014b_40_50_.split()
                        shuffle(split)
                        ggg_2014b_40_50_ = ' '.join(split) # Turn the list back into a string
                        concatenatedGgg2014b_40_50_ =' ' + ggg_2014b_40_50_ + concatenatedGgg2014b_40_50_
                elif data['imd_band'][i] == '41_51_':
                        ggg_2014b_41_51_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ')  + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        ggg_2014b_41_51_ = ggg_2014b_41_51_.lower()
                        split = ggg_2014b_41_51_.split()
                        shuffle(split)
                        ggg_2014b_41_51_ = ' '.join(split) # Turn the list back into a string
                        concatenatedGgg2014b_41_51_ =' ' + ggg_2014b_41_51_ + concatenatedGgg2014b_41_51_
                elif data['imd_band'][i] == '10_20_':
                        ggg_2014b_10_20_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ')  + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        ggg_2014b_10_20_ = ggg_2014b_10_20_.lower()
                        split = ggg_2014b_10_20_.split()
                        shuffle(split)
                        ggg_2014b_10_20_ = ' '.join(split) # Turn the list back into a string
                        concatenatedGgg2014b_10_20_ =' ' + ggg_2014b_10_20_ + concatenatedGgg2014b_10_20_
                elif data['imd_band'][i] == '0_10_':
                        ggg_2014b_0_10_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ')  + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        ggg_2014b_0_10_ = ggg_2014b_0_10_.lower()
                        split = ggg_2014b_0_10_.split()
                        shuffle(split)
                        ggg_2014b_0_10_ = ' '.join(split) # Turn the list back into a string
                        concatenatedGgg2014b_0_10_ =' ' + ggg_2014b_0_10_ + concatenatedGgg2014b_0_10_
                elif data['imd_band'][i] == '33_43_':
                        ggg_2014b_33_43_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ')  + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        ggg_2014b_33_43_ = ggg_2014b_33_43_.lower()
                        split = ggg_2014b_33_43_.split()
                        shuffle(split)
                        ggg_2014b_33_43_ = ' '.join(split) # Turn the list back into a string
                        concatenatedGgg2014b_33_43_ =' ' + ggg_2014b_33_43_ + concatenatedGgg2014b_33_43_
                elif data['imd_band'][i] == '59_69_':
                        ggg_2014b_59_69_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ')  + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        ggg_2014b_59_69_ = ggg_2014b_59_69_.lower()
                        split = ggg_2014b_59_69_.split()
                        shuffle(split)
                        ggg_2014b_59_69_ = ' '.join(split) # Turn the list back into a string
                        concatenatedGgg2014b_59_69_ =' ' + ggg_2014b_59_69_ + concatenatedGgg2014b_59_69_
                elif data['imd_band'][i] == '45_55_':
                        ggg_2014b_45_55_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ')  + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        ggg_2014b_45_55_ = ggg_2014b_45_55_.lower()
                        split = ggg_2014b_45_55_.split()
                        shuffle(split)
                        ggg_2014b_45_55_ = ' '.join(split) # Turn the list back into a string
                        concatenatedGgg2014b_45_55_ =' ' + ggg_2014b_45_55_ + concatenatedGgg2014b_45_55_
                elif data['imd_band'][i] == '46_56_':
                        ggg_2014b_46_56_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ')  + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        ggg_2014b_46_56_ = ggg_2014b_46_56_.lower()
                        split = ggg_2014b_46_56_.split()
                        shuffle(split)
                        ggg_2014b_46_56_ = ' '.join(split) # Turn the list back into a string
                        concatenatedGgg2014b_46_56_ =' ' + ggg_2014b_46_56_ + concatenatedGgg2014b_46_56_
        elif data['courses'][i] == 'GGG-2014J':
                if data['imd_band'][i] == '90_100_':
                        ggg_2014j_90_100_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ')  + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        ggg_2014j_90_100_ = ggg_2014j_90_100_.lower()
                        split = ggg_2014j_90_100_.split()
                        shuffle(split)
                        ggg_2014j_90_100_ = ' '.join(split) # Turn the list back into a string
                        concatenatedGgg2014j_90_100_ =' ' + ggg_2014j_90_100_ + concatenatedGgg2014j_90_100_
                elif data['imd_band'][i] == '20_30_':
                        ggg_2014j_20_30_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ')  + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        ggg_2014j_20_30_ = ggg_2014j_20_30_.lower()
                        split = ggg_2014j_20_30_.split()
                        shuffle(split)
                        ggg_2014j_20_30_ = ' '.join(split) # Turn the list back into a string
                        concatenatedGgg2014j_20_30_ =' ' + ggg_2014j_20_30_ + concatenatedGgg2014j_20_30_
                elif data['imd_band'][i] == '30_40_':
                        ggg_2014j_30_40_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ')  + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        ggg_2014j_30_40_ = ggg_2014j_30_40_.lower()
                        split = ggg_2014j_30_40_.split()
                        shuffle(split)
                        ggg_2014j_30_40_ = ' '.join(split) # Turn the list back into a string
                        concatenatedGgg2014j_30_40_ =' ' + ggg_2014j_30_40_ + concatenatedGgg2014j_30_40_
                elif data['imd_band'][i] == '50_60_':
                        ggg_2014j_50_60_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ')  + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        ggg_2014j_50_60_ = ggg_2014j_50_60_.lower()
                        split = ggg_2014j_50_60_.split()
                        shuffle(split)
                        ggg_2014j_50_60_ = ' '.join(split) # Turn the list back into a string
                        concatenatedGgg2014j_50_60_ =' ' + ggg_2014j_50_60_ + concatenatedGgg2014j_50_60_
                elif data['imd_band'][i] == '80_90_':
                        ggg_2014j_80_90_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ')  + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        ggg_2014j_80_90_ = ggg_2014j_80_90_.lower()
                        split = ggg_2014j_80_90_.split()
                        shuffle(split)
                        ggg_2014j_80_90_ = ' '.join(split) # Turn the list back into a string
                        concatenatedGgg2014j_80_90_ =' ' + ggg_2014j_80_90_ + concatenatedGgg2014j_80_90_
                elif data['imd_band'][i] == '70_80_':
                        ggg_2014j_70_80_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ')  + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        ggg_2014j_70_80_ = ggg_2014j_70_80_.lower()
                        split = ggg_2014j_70_80_.split()
                        shuffle(split)
                        ggg_2014j_70_80_ = ' '.join(split) # Turn the list back into a string
                        concatenatedGgg2014j_70_80_ =' ' + ggg_2014j_70_80_ + concatenatedGgg2014j_70_80_
                elif data['imd_band'][i] == '29_39_':
                        ggg_2014j_29_39_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ')  + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        ggg_2014j_29_39_ = ggg_2014j_29_39_.lower()
                        split = ggg_2014j_29_39_.split()
                        shuffle(split)
                        ggg_2014j_29_39_ = ' '.join(split) # Turn the list back into a string
                        concatenatedGgg2014j_29_39_ =' ' + ggg_2014j_29_39_ + concatenatedGgg2014j_29_39_
                elif data['imd_band'][i] == '60_70_':
                        ggg_2014j_60_70_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ')  + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        ggg_2014j_60_70_ = ggg_2014j_60_70_.lower()
                        split = ggg_2014j_60_70_.split()
                        shuffle(split)
                        ggg_2014j_60_70_ = ' '.join(split) # Turn the list back into a string
                        concatenatedGgg2014j_60_70_ =' ' + ggg_2014j_60_70_ + concatenatedGgg2014j_60_70_
                elif data['imd_band'][i] == '40_50_':
                        ggg_2014j_40_50_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ')  + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        ggg_2014j_40_50_ = ggg_2014j_40_50_.lower()
                        split = ggg_2014j_40_50_.split()
                        shuffle(split)
                        ggg_2014j_40_50_ = ' '.join(split) # Turn the list back into a string
                        concatenatedGgg2014j_40_50_ =' ' + ggg_2014j_40_50_ + concatenatedGgg2014j_40_50_
                elif data['imd_band'][i] == '41_51_':
                        ggg_2014j_41_51_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ')  + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        ggg_2014j_41_51_ = ggg_2014j_41_51_.lower()
                        split = ggg_2014j_41_51_.split()
                        shuffle(split)
                        ggg_2014j_41_51_ = ' '.join(split) # Turn the list back into a string
                        concatenatedGgg2014j_41_51_ =' ' + ggg_2014j_41_51_ + concatenatedGgg2014j_41_51_
                elif data['imd_band'][i] == '10_20_':
                        ggg_2014j_10_20_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ')  + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        ggg_2014j_10_20_ = ggg_2014j_10_20_.lower()
                        split = ggg_2014j_10_20_.split()
                        shuffle(split)
                        ggg_2014j_10_20_ = ' '.join(split) # Turn the list back into a string
                        concatenatedGgg2014j_10_20_ =' ' + ggg_2014j_10_20_ + concatenatedGgg2014j_10_20_
                elif data['imd_band'][i] == '0_10_':
                        ggg_2014j_0_10_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ')  + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        ggg_2014j_0_10_ = ggg_2014j_0_10_.lower()
                        split = ggg_2014j_0_10_.split()
                        shuffle(split)
                        ggg_2014j_0_10_ = ' '.join(split) # Turn the list back into a string
                        concatenatedGgg2014j_0_10_ =' ' + ggg_2014j_0_10_ + concatenatedGgg2014j_0_10_
                elif data['imd_band'][i] == '33_43_':
                        ggg_2014j_33_43_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ')  + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        ggg_2014j_33_43_ = ggg_2014j_33_43_.lower()
                        split = ggg_2014j_33_43_.split()
                        shuffle(split)
                        ggg_2014j_33_43_ = ' '.join(split) # Turn the list back into a string
                        concatenatedGgg2014j_33_43_ =' ' + ggg_2014j_33_43_ + concatenatedGgg2014j_33_43_
                elif data['imd_band'][i] == '59_69_':
                        ggg_2014j_59_69_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ')  + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        ggg_2014j_59_69_ = ggg_2014j_59_69_.lower()
                        split = ggg_2014j_59_69_.split()
                        shuffle(split)
                        ggg_2014j_59_69_ = ' '.join(split) # Turn the list back into a string
                        concatenatedGgg2014j_59_69_ =' ' + ggg_2014j_59_69_ + concatenatedGgg2014j_59_69_
                elif data['imd_band'][i] == '45_55_':
                        ggg_2014j_45_55_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ')  + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        ggg_2014j_45_55_ = ggg_2014j_45_55_.lower()
                        split = ggg_2014j_45_55_.split()
                        shuffle(split)
                        ggg_2014j_45_55_ = ' '.join(split) # Turn the list back into a string
                        concatenatedGgg2014j_45_55_ =' ' + ggg_2014j_45_55_ + concatenatedGgg2014j_45_55_
                elif data['imd_band'][i] == '46_56_':
                        ggg_2014j_46_56_ = str(data['gender'][i] + ' ') + str(data['region'][i] + ' ')  + str(data['imd_band'][i] + ' ')  + str(data['final_result'][i] + ' ')
                        ggg_2014j_46_56_ = ggg_2014j_46_56_.lower()
                        split = ggg_2014j_46_56_.split()
                        shuffle(split)
                        ggg_2014j_46_56_ = ' '.join(split) # Turn the list back into a string
                        concatenatedGgg2014j_46_56_ =' ' + ggg_2014j_46_56_ + concatenatedGgg2014j_46_56_
                                                                                

tokenized_data.append(nltk.word_tokenize(concatenatedAaa2013j_90_100_))
tokenized_data.append(nltk.word_tokenize(concatenatedAaa2013j_20_30_))
tokenized_data.append(nltk.word_tokenize(concatenatedAaa2013j_30_40_))
tokenized_data.append(nltk.word_tokenize(concatenatedAaa2013j_50_60_))
tokenized_data.append(nltk.word_tokenize(concatenatedAaa2013j_80_90_))
tokenized_data.append(nltk.word_tokenize(concatenatedAaa2013j_70_80_))
tokenized_data.append(nltk.word_tokenize(concatenatedAaa2013j_29_39_))
tokenized_data.append(nltk.word_tokenize(concatenatedAaa2013j_60_70_))
tokenized_data.append(nltk.word_tokenize(concatenatedAaa2013j_40_50_))
tokenized_data.append(nltk.word_tokenize(concatenatedAaa2013j_41_51_))
tokenized_data.append(nltk.word_tokenize(concatenatedAaa2013j_10_20_))
tokenized_data.append(nltk.word_tokenize(concatenatedAaa2013j_0_10_))
tokenized_data.append(nltk.word_tokenize(concatenatedAaa2013j_33_43_))
tokenized_data.append(nltk.word_tokenize(concatenatedAaa2013j_59_69_))
tokenized_data.append(nltk.word_tokenize(concatenatedAaa2013j_45_55_))
tokenized_data.append(nltk.word_tokenize(concatenatedAaa2013j_46_56_))
tokenized_data.append(nltk.word_tokenize(concatenatedAaa2014j_90_100_)) 
tokenized_data.append(nltk.word_tokenize(concatenatedAaa2014j_20_30_)) 
tokenized_data.append(nltk.word_tokenize(concatenatedAaa2014j_30_40_)) 
tokenized_data.append(nltk.word_tokenize(concatenatedAaa2014j_50_60_)) 
tokenized_data.append(nltk.word_tokenize(concatenatedAaa2014j_80_90_)) 
tokenized_data.append(nltk.word_tokenize(concatenatedAaa2014j_70_80_)) 
tokenized_data.append(nltk.word_tokenize(concatenatedAaa2014j_29_39_)) 
tokenized_data.append(nltk.word_tokenize(concatenatedAaa2014j_60_70_)) 
tokenized_data.append(nltk.word_tokenize(concatenatedAaa2014j_40_50_)) 
tokenized_data.append(nltk.word_tokenize(concatenatedAaa2014j_41_51_)) 
tokenized_data.append(nltk.word_tokenize(concatenatedAaa2014j_10_20_)) 
tokenized_data.append(nltk.word_tokenize(concatenatedAaa2014j_0_10_)) 
tokenized_data.append(nltk.word_tokenize(concatenatedAaa2014j_33_43_)) 
tokenized_data.append(nltk.word_tokenize(concatenatedAaa2014j_59_69_)) 
tokenized_data.append(nltk.word_tokenize(concatenatedAaa2014j_45_55_)) 
tokenized_data.append(nltk.word_tokenize(concatenatedAaa2014j_46_56_)) 
tokenized_data.append(nltk.word_tokenize(concatenatedBbb2013b_90_100_))  
tokenized_data.append(nltk.word_tokenize(concatenatedBbb2013b_20_30_))  
tokenized_data.append(nltk.word_tokenize(concatenatedBbb2013b_30_40_))  
tokenized_data.append(nltk.word_tokenize(concatenatedBbb2013b_50_60_))  
tokenized_data.append(nltk.word_tokenize(concatenatedBbb2013b_80_90_))  
tokenized_data.append(nltk.word_tokenize(concatenatedBbb2013b_70_80_))  
tokenized_data.append(nltk.word_tokenize(concatenatedBbb2013b_29_39_))  
tokenized_data.append(nltk.word_tokenize(concatenatedBbb2013b_60_70_))  
tokenized_data.append(nltk.word_tokenize(concatenatedBbb2013b_40_50_))  
tokenized_data.append(nltk.word_tokenize(concatenatedBbb2013b_41_51_))  
tokenized_data.append(nltk.word_tokenize(concatenatedBbb2013b_10_20_))  
tokenized_data.append(nltk.word_tokenize(concatenatedBbb2013b_0_10_))  
tokenized_data.append(nltk.word_tokenize(concatenatedBbb2013b_33_43_))  
tokenized_data.append(nltk.word_tokenize(concatenatedBbb2013b_59_69_))  
tokenized_data.append(nltk.word_tokenize(concatenatedBbb2013b_45_55_))  
tokenized_data.append(nltk.word_tokenize(concatenatedBbb2013b_46_56_)) 
tokenized_data.append(nltk.word_tokenize(concatenatedBbb2013j_90_100_))  
tokenized_data.append(nltk.word_tokenize(concatenatedBbb2013j_20_30_))  
tokenized_data.append(nltk.word_tokenize(concatenatedBbb2013j_30_40_))  
tokenized_data.append(nltk.word_tokenize(concatenatedBbb2013j_50_60_))  
tokenized_data.append(nltk.word_tokenize(concatenatedBbb2013j_80_90_))  
tokenized_data.append(nltk.word_tokenize(concatenatedBbb2013j_70_80_))  
tokenized_data.append(nltk.word_tokenize(concatenatedBbb2013j_29_39_))  
tokenized_data.append(nltk.word_tokenize(concatenatedBbb2013j_60_70_))  
tokenized_data.append(nltk.word_tokenize(concatenatedBbb2013j_40_50_))  
tokenized_data.append(nltk.word_tokenize(concatenatedBbb2013j_41_51_))  
tokenized_data.append(nltk.word_tokenize(concatenatedBbb2013j_10_20_))  
tokenized_data.append(nltk.word_tokenize(concatenatedBbb2013j_0_10_))  
tokenized_data.append(nltk.word_tokenize(concatenatedBbb2013j_33_43_))  
tokenized_data.append(nltk.word_tokenize(concatenatedBbb2013j_59_69_))  
tokenized_data.append(nltk.word_tokenize(concatenatedBbb2013j_45_55_))  
tokenized_data.append(nltk.word_tokenize(concatenatedBbb2013j_46_56_))
tokenized_data.append(nltk.word_tokenize(concatenatedBbb2014b_90_100_))  

tokenized_data.append(nltk.word_tokenize(concatenatedBbb2014b_20_30_))  

tokenized_data.append(nltk.word_tokenize(concatenatedBbb2014b_30_40_))  

tokenized_data.append(nltk.word_tokenize(concatenatedBbb2014b_50_60_))  

tokenized_data.append(nltk.word_tokenize(concatenatedBbb2014b_80_90_))  

tokenized_data.append(nltk.word_tokenize(concatenatedBbb2014b_70_80_))  

tokenized_data.append(nltk.word_tokenize(concatenatedBbb2014b_29_39_))  

tokenized_data.append(nltk.word_tokenize(concatenatedBbb2014b_60_70_))  

tokenized_data.append(nltk.word_tokenize(concatenatedBbb2014b_40_50_))  

tokenized_data.append(nltk.word_tokenize(concatenatedBbb2014b_41_51_))  

tokenized_data.append(nltk.word_tokenize(concatenatedBbb2014b_10_20_))  

tokenized_data.append(nltk.word_tokenize(concatenatedBbb2014b_0_10_))  

tokenized_data.append(nltk.word_tokenize(concatenatedBbb2014b_33_43_))  

tokenized_data.append(nltk.word_tokenize(concatenatedBbb2014b_59_69_))  

tokenized_data.append(nltk.word_tokenize(concatenatedBbb2014b_45_55_))  

tokenized_data.append(nltk.word_tokenize(concatenatedBbb2014b_46_56_)) 
tokenized_data.append(nltk.word_tokenize(concatenatedBbb2014j_90_100_))  

tokenized_data.append(nltk.word_tokenize(concatenatedBbb2014j_20_30_))  

tokenized_data.append(nltk.word_tokenize(concatenatedBbb2014j_30_40_))  

tokenized_data.append(nltk.word_tokenize(concatenatedBbb2014j_50_60_))  

tokenized_data.append(nltk.word_tokenize(concatenatedBbb2014j_80_90_))  

tokenized_data.append(nltk.word_tokenize(concatenatedBbb2014j_70_80_))  

tokenized_data.append(nltk.word_tokenize(concatenatedBbb2014j_29_39_))  

tokenized_data.append(nltk.word_tokenize(concatenatedBbb2014j_60_70_))  

tokenized_data.append(nltk.word_tokenize(concatenatedBbb2014j_40_50_))  

tokenized_data.append(nltk.word_tokenize(concatenatedBbb2014j_41_51_))  

tokenized_data.append(nltk.word_tokenize(concatenatedBbb2014j_10_20_))  

tokenized_data.append(nltk.word_tokenize(concatenatedBbb2014j_0_10_))  

tokenized_data.append(nltk.word_tokenize(concatenatedBbb2014j_33_43_))  

tokenized_data.append(nltk.word_tokenize(concatenatedBbb2014j_59_69_))  

tokenized_data.append(nltk.word_tokenize(concatenatedBbb2014j_45_55_))  

tokenized_data.append(nltk.word_tokenize(concatenatedBbb2014j_46_56_)) 
tokenized_data.append(nltk.word_tokenize(concatenatedCcc2014j_90_100_))  

tokenized_data.append(nltk.word_tokenize(concatenatedCcc2014b_90_100_))  

tokenized_data.append(nltk.word_tokenize(concatenatedCcc2014b_20_30_))  

tokenized_data.append(nltk.word_tokenize(concatenatedCcc2014b_30_40_))  

tokenized_data.append(nltk.word_tokenize(concatenatedCcc2014b_50_60_))  

tokenized_data.append(nltk.word_tokenize(concatenatedCcc2014b_80_90_))  

tokenized_data.append(nltk.word_tokenize(concatenatedCcc2014b_70_80_))  

tokenized_data.append(nltk.word_tokenize(concatenatedCcc2014b_29_39_))  

tokenized_data.append(nltk.word_tokenize(concatenatedCcc2014b_60_70_))  

tokenized_data.append(nltk.word_tokenize(concatenatedCcc2014b_40_50_))  

tokenized_data.append(nltk.word_tokenize(concatenatedCcc2014b_41_51_))  

tokenized_data.append(nltk.word_tokenize(concatenatedCcc2014b_10_20_))  

tokenized_data.append(nltk.word_tokenize(concatenatedCcc2014b_0_10_))  

tokenized_data.append(nltk.word_tokenize(concatenatedCcc2014b_33_43_))  

tokenized_data.append(nltk.word_tokenize(concatenatedCcc2014b_59_69_))  

tokenized_data.append(nltk.word_tokenize(concatenatedCcc2014b_45_55_))  

tokenized_data.append(nltk.word_tokenize(concatenatedCcc2014b_46_56_))
tokenized_data.append(nltk.word_tokenize(concatenatedCcc2014j_90_100_))  

tokenized_data.append(nltk.word_tokenize(concatenatedCcc2014j_20_30_))  

tokenized_data.append(nltk.word_tokenize(concatenatedCcc2014j_30_40_))  

tokenized_data.append(nltk.word_tokenize(concatenatedCcc2014j_50_60_))  

tokenized_data.append(nltk.word_tokenize(concatenatedCcc2014j_80_90_))  

tokenized_data.append(nltk.word_tokenize(concatenatedCcc2014j_70_80_))  

tokenized_data.append(nltk.word_tokenize(concatenatedCcc2014j_29_39_))  

tokenized_data.append(nltk.word_tokenize(concatenatedCcc2014j_60_70_))  

tokenized_data.append(nltk.word_tokenize(concatenatedCcc2014j_40_50_))  

tokenized_data.append(nltk.word_tokenize(concatenatedCcc2014j_41_51_))  

tokenized_data.append(nltk.word_tokenize(concatenatedCcc2014j_10_20_))  

tokenized_data.append(nltk.word_tokenize(concatenatedCcc2014j_0_10_))  

tokenized_data.append(nltk.word_tokenize(concatenatedCcc2014j_33_43_))  

tokenized_data.append(nltk.word_tokenize(concatenatedCcc2014j_59_69_))  

tokenized_data.append(nltk.word_tokenize(concatenatedCcc2014j_45_55_))  

tokenized_data.append(nltk.word_tokenize(concatenatedCcc2014j_46_56_))
tokenized_data.append(nltk.word_tokenize(concatenatedEee2014b_90_100_))  

tokenized_data.append(nltk.word_tokenize(concatenatedEee2014b_20_30_))  

tokenized_data.append(nltk.word_tokenize(concatenatedEee2014b_30_40_))  

tokenized_data.append(nltk.word_tokenize(concatenatedEee2014b_50_60_))  

tokenized_data.append(nltk.word_tokenize(concatenatedEee2014b_80_90_))  

tokenized_data.append(nltk.word_tokenize(concatenatedEee2014b_70_80_))  

tokenized_data.append(nltk.word_tokenize(concatenatedEee2014b_29_39_))  

tokenized_data.append(nltk.word_tokenize(concatenatedEee2014b_60_70_))  

tokenized_data.append(nltk.word_tokenize(concatenatedEee2014b_40_50_))  

tokenized_data.append(nltk.word_tokenize(concatenatedEee2014b_41_51_))  

tokenized_data.append(nltk.word_tokenize(concatenatedEee2014b_10_20_))  

tokenized_data.append(nltk.word_tokenize(concatenatedEee2014b_0_10_))  

tokenized_data.append(nltk.word_tokenize(concatenatedEee2014b_33_43_))  

tokenized_data.append(nltk.word_tokenize(concatenatedEee2014b_59_69_))  

tokenized_data.append(nltk.word_tokenize(concatenatedEee2014b_45_55_))  

tokenized_data.append(nltk.word_tokenize(concatenatedEee2014b_46_56_))
tokenized_data.append(nltk.word_tokenize(concatenatedEee2014j_90_100_))  

tokenized_data.append(nltk.word_tokenize(concatenatedEee2014j_20_30_))  

tokenized_data.append(nltk.word_tokenize(concatenatedEee2014j_30_40_))  

tokenized_data.append(nltk.word_tokenize(concatenatedEee2014j_50_60_))  

tokenized_data.append(nltk.word_tokenize(concatenatedEee2014j_80_90_))  

tokenized_data.append(nltk.word_tokenize(concatenatedEee2014j_70_80_))  

tokenized_data.append(nltk.word_tokenize(concatenatedEee2014j_29_39_))  

tokenized_data.append(nltk.word_tokenize(concatenatedEee2014j_60_70_))  

tokenized_data.append(nltk.word_tokenize(concatenatedEee2014j_40_50_))  

tokenized_data.append(nltk.word_tokenize(concatenatedEee2014j_41_51_))  

tokenized_data.append(nltk.word_tokenize(concatenatedEee2014j_10_20_))  

tokenized_data.append(nltk.word_tokenize(concatenatedEee2014j_0_10_))  

tokenized_data.append(nltk.word_tokenize(concatenatedEee2014j_33_43_))  

tokenized_data.append(nltk.word_tokenize(concatenatedEee2014j_59_69_))  

tokenized_data.append(nltk.word_tokenize(concatenatedEee2014j_45_55_))  

tokenized_data.append(nltk.word_tokenize(concatenatedEee2014j_46_56_))    
tokenized_data.append(nltk.word_tokenize(concatenatedEee2013j_90_100_))  

tokenized_data.append(nltk.word_tokenize(concatenatedEee2013j_20_30_))  

tokenized_data.append(nltk.word_tokenize(concatenatedEee2013j_30_40_))  

tokenized_data.append(nltk.word_tokenize(concatenatedEee2013j_50_60_))  

tokenized_data.append(nltk.word_tokenize(concatenatedEee2013j_80_90_))  

tokenized_data.append(nltk.word_tokenize(concatenatedEee2013j_70_80_))  

tokenized_data.append(nltk.word_tokenize(concatenatedEee2013j_29_39_))  

tokenized_data.append(nltk.word_tokenize(concatenatedEee2013j_60_70_))  

tokenized_data.append(nltk.word_tokenize(concatenatedEee2013j_40_50_))  

tokenized_data.append(nltk.word_tokenize(concatenatedEee2013j_41_51_))  

tokenized_data.append(nltk.word_tokenize(concatenatedEee2013j_10_20_))  

tokenized_data.append(nltk.word_tokenize(concatenatedEee2013j_0_10_))  

tokenized_data.append(nltk.word_tokenize(concatenatedEee2013j_33_43_))  

tokenized_data.append(nltk.word_tokenize(concatenatedEee2013j_59_69_))  

tokenized_data.append(nltk.word_tokenize(concatenatedEee2013j_45_55_))  

tokenized_data.append(nltk.word_tokenize(concatenatedEee2013j_46_56_)) 

tokenized_data.append(nltk.word_tokenize(concatenatedGgg2013j_90_100_))  

tokenized_data.append(nltk.word_tokenize(concatenatedGgg2013j_20_30_))  

tokenized_data.append(nltk.word_tokenize(concatenatedGgg2013j_30_40_))  

tokenized_data.append(nltk.word_tokenize(concatenatedGgg2013j_50_60_))  

tokenized_data.append(nltk.word_tokenize(concatenatedGgg2013j_80_90_))  

tokenized_data.append(nltk.word_tokenize(concatenatedGgg2013j_70_80_))  

tokenized_data.append(nltk.word_tokenize(concatenatedGgg2013j_29_39_))  

tokenized_data.append(nltk.word_tokenize(concatenatedGgg2013j_60_70_))  

tokenized_data.append(nltk.word_tokenize(concatenatedGgg2013j_40_50_))  

tokenized_data.append(nltk.word_tokenize(concatenatedGgg2013j_41_51_))  

tokenized_data.append(nltk.word_tokenize(concatenatedGgg2013j_10_20_))  

tokenized_data.append(nltk.word_tokenize(concatenatedGgg2013j_0_10_))  

tokenized_data.append(nltk.word_tokenize(concatenatedGgg2013j_33_43_))  

tokenized_data.append(nltk.word_tokenize(concatenatedGgg2013j_59_69_))  

tokenized_data.append(nltk.word_tokenize(concatenatedGgg2013j_45_55_))  

tokenized_data.append(nltk.word_tokenize(concatenatedGgg2013j_46_56_))
tokenized_data.append(nltk.word_tokenize(concatenatedGgg2014b_90_100_))  

tokenized_data.append(nltk.word_tokenize(concatenatedGgg2014b_20_30_))  

tokenized_data.append(nltk.word_tokenize(concatenatedGgg2014b_30_40_))  

tokenized_data.append(nltk.word_tokenize(concatenatedGgg2014b_50_60_))  

tokenized_data.append(nltk.word_tokenize(concatenatedGgg2014b_80_90_))  

tokenized_data.append(nltk.word_tokenize(concatenatedGgg2014b_70_80_))  

tokenized_data.append(nltk.word_tokenize(concatenatedGgg2014b_29_39_))  

tokenized_data.append(nltk.word_tokenize(concatenatedGgg2014b_60_70_))  

tokenized_data.append(nltk.word_tokenize(concatenatedGgg2014b_40_50_))  

tokenized_data.append(nltk.word_tokenize(concatenatedGgg2014b_41_51_))  

tokenized_data.append(nltk.word_tokenize(concatenatedGgg2014b_10_20_))  

tokenized_data.append(nltk.word_tokenize(concatenatedGgg2014b_0_10_))  

tokenized_data.append(nltk.word_tokenize(concatenatedGgg2014b_33_43_))  

tokenized_data.append(nltk.word_tokenize(concatenatedGgg2014b_59_69_))  

tokenized_data.append(nltk.word_tokenize(concatenatedGgg2014b_45_55_))  

tokenized_data.append(nltk.word_tokenize(concatenatedGgg2014b_46_56_))
tokenized_data.append(nltk.word_tokenize(concatenatedGgg2014j_90_100_))  

tokenized_data.append(nltk.word_tokenize(concatenatedGgg2014j_20_30_))  

tokenized_data.append(nltk.word_tokenize(concatenatedGgg2014j_30_40_))  

tokenized_data.append(nltk.word_tokenize(concatenatedGgg2014j_50_60_))  

tokenized_data.append(nltk.word_tokenize(concatenatedGgg2014j_80_90_))  

tokenized_data.append(nltk.word_tokenize(concatenatedGgg2014j_70_80_))  

tokenized_data.append(nltk.word_tokenize(concatenatedGgg2014j_29_39_))  

tokenized_data.append(nltk.word_tokenize(concatenatedGgg2014j_60_70_))  

tokenized_data.append(nltk.word_tokenize(concatenatedGgg2014j_40_50_))  

tokenized_data.append(nltk.word_tokenize(concatenatedGgg2014j_41_51_))  

tokenized_data.append(nltk.word_tokenize(concatenatedGgg2014j_10_20_))  

tokenized_data.append(nltk.word_tokenize(concatenatedGgg2014j_0_10_))  

tokenized_data.append(nltk.word_tokenize(concatenatedGgg2014j_33_43_))  

tokenized_data.append(nltk.word_tokenize(concatenatedGgg2014j_59_69_))  

tokenized_data.append(nltk.word_tokenize(concatenatedGgg2014j_45_55_))  

tokenized_data.append(nltk.word_tokenize(concatenatedGgg2014j_46_56_))
tokenized_data.append(nltk.word_tokenize(concatenatedFff2014j_90_100_))  

tokenized_data.append(nltk.word_tokenize(concatenatedFff2014j_20_30_))  

tokenized_data.append(nltk.word_tokenize(concatenatedFff2014j_30_40_))  

tokenized_data.append(nltk.word_tokenize(concatenatedFff2014j_50_60_))  

tokenized_data.append(nltk.word_tokenize(concatenatedFff2014j_80_90_))  

tokenized_data.append(nltk.word_tokenize(concatenatedFff2014j_70_80_))  

tokenized_data.append(nltk.word_tokenize(concatenatedFff2014j_29_39_))  

tokenized_data.append(nltk.word_tokenize(concatenatedFff2014j_60_70_))  

tokenized_data.append(nltk.word_tokenize(concatenatedFff2014j_40_50_))  

tokenized_data.append(nltk.word_tokenize(concatenatedFff2014j_41_51_))  

tokenized_data.append(nltk.word_tokenize(concatenatedFff2014j_10_20_))  

tokenized_data.append(nltk.word_tokenize(concatenatedFff2014j_0_10_))  

tokenized_data.append(nltk.word_tokenize(concatenatedFff2014j_33_43_))  

tokenized_data.append(nltk.word_tokenize(concatenatedFff2014j_59_69_))  

tokenized_data.append(nltk.word_tokenize(concatenatedFff2014j_45_55_))  

tokenized_data.append(nltk.word_tokenize(concatenatedFff2014j_46_56_))
tokenized_data.append(nltk.word_tokenize(concatenatedFff2013j_90_100_))  

tokenized_data.append(nltk.word_tokenize(concatenatedFff2013j_20_30_))  

tokenized_data.append(nltk.word_tokenize(concatenatedFff2013j_30_40_))  

tokenized_data.append(nltk.word_tokenize(concatenatedFff2013j_50_60_))  

tokenized_data.append(nltk.word_tokenize(concatenatedFff2013j_80_90_))  

tokenized_data.append(nltk.word_tokenize(concatenatedFff2013j_70_80_))  

tokenized_data.append(nltk.word_tokenize(concatenatedFff2013j_29_39_))  

tokenized_data.append(nltk.word_tokenize(concatenatedFff2013j_60_70_))  

tokenized_data.append(nltk.word_tokenize(concatenatedFff2013j_40_50_))  

tokenized_data.append(nltk.word_tokenize(concatenatedFff2013j_41_51_))  

tokenized_data.append(nltk.word_tokenize(concatenatedFff2013j_10_20_))  

tokenized_data.append(nltk.word_tokenize(concatenatedFff2013j_0_10_))  

tokenized_data.append(nltk.word_tokenize(concatenatedFff2013j_33_43_))  

tokenized_data.append(nltk.word_tokenize(concatenatedFff2013j_59_69_))  

tokenized_data.append(nltk.word_tokenize(concatenatedFff2013j_45_55_))  

tokenized_data.append(nltk.word_tokenize(concatenatedFff2013j_46_56_)) 
tokenized_data.append(nltk.word_tokenize(concatenatedFff2013b_90_100_))  

tokenized_data.append(nltk.word_tokenize(concatenatedFff2013b_20_30_))  

tokenized_data.append(nltk.word_tokenize(concatenatedFff2013b_30_40_))  

tokenized_data.append(nltk.word_tokenize(concatenatedFff2013b_50_60_))  

tokenized_data.append(nltk.word_tokenize(concatenatedFff2013b_80_90_))  

tokenized_data.append(nltk.word_tokenize(concatenatedFff2013b_70_80_))  

tokenized_data.append(nltk.word_tokenize(concatenatedFff2013b_29_39_))  

tokenized_data.append(nltk.word_tokenize(concatenatedFff2013b_60_70_))  

tokenized_data.append(nltk.word_tokenize(concatenatedFff2013b_40_50_))  

tokenized_data.append(nltk.word_tokenize(concatenatedFff2013b_41_51_))  

tokenized_data.append(nltk.word_tokenize(concatenatedFff2013b_10_20_))  

tokenized_data.append(nltk.word_tokenize(concatenatedFff2013b_0_10_))  

tokenized_data.append(nltk.word_tokenize(concatenatedFff2013b_33_43_))  

tokenized_data.append(nltk.word_tokenize(concatenatedFff2013b_59_69_))  

tokenized_data.append(nltk.word_tokenize(concatenatedFff2013b_45_55_))  

tokenized_data.append(nltk.word_tokenize(concatenatedFff2013b_46_56_))
tokenized_data.append(nltk.word_tokenize(concatenatedFff2014b_90_100_))  

tokenized_data.append(nltk.word_tokenize(concatenatedFff2014b_20_30_))  

tokenized_data.append(nltk.word_tokenize(concatenatedFff2014b_30_40_))  

tokenized_data.append(nltk.word_tokenize(concatenatedFff2014b_50_60_))  

tokenized_data.append(nltk.word_tokenize(concatenatedFff2014b_80_90_))  

tokenized_data.append(nltk.word_tokenize(concatenatedFff2014b_70_80_))  

tokenized_data.append(nltk.word_tokenize(concatenatedFff2014b_29_39_))  

tokenized_data.append(nltk.word_tokenize(concatenatedFff2014b_60_70_))  

tokenized_data.append(nltk.word_tokenize(concatenatedFff2014b_40_50_))  

tokenized_data.append(nltk.word_tokenize(concatenatedFff2014b_41_51_))  

tokenized_data.append(nltk.word_tokenize(concatenatedFff2014b_10_20_))  

tokenized_data.append(nltk.word_tokenize(concatenatedFff2014b_0_10_))  

tokenized_data.append(nltk.word_tokenize(concatenatedFff2014b_33_43_))  

tokenized_data.append(nltk.word_tokenize(concatenatedFff2014b_59_69_))  

tokenized_data.append(nltk.word_tokenize(concatenatedFff2014b_45_55_))  

tokenized_data.append(nltk.word_tokenize(concatenatedFff2014b_46_56_))  


             

# training the W2V model
model = Word2Vec(sentences=tokenized_data, 
                 window=6,  
                 workers=4)


def reduce_dimensions(model):
    num_components = 2 # number of dimensions to keep after compression
    # extract vocabulary from model and vectors in order to associate them in t
    vectors = np.asarray(model.wv.vectors)
    labels = np.asarray(model.wv.index_to_key)
    # apply TSNE
    tsne = TSNE(n_components=num_components, random_state=0)
    vectors = tsne.fit_transform(vectors)
    x_vals = [v[0] for v in vectors]
    y_vals = [v[1] for v in vectors]
    return x_vals, y_vals, labels

def plot_embeddings(x_vals, y_vals, labels):
 
    fig = go.Figure()
    trace = go.Scatter(x=x_vals, y=y_vals, mode='markers', text=labels)
    fig.add_trace(trace)
    fig.update_layout(title="Word2Vec - Visualizzazione embedding con TSNE")
    fig.show()
    return fig

x_vals, y_vals, labels = reduce_dimensions(model)
plot = plot_embeddings(x_vals, y_vals, labels)

def run_tsne(data, num_dimensions=2, perplexity=30.0, learning_rate=200.0, num_iterations=1000):
        # Create t-SNE object
        tsne = TSNE(n_components=num_dimensions, perplexity=perplexity, learning_rate=learning_rate, n_iter=num_iterations)

        # Run t-SNE on the data
        embedded_data = tsne.fit_transform(data)
    
        return embedded_data




# Generate random data
data = np.asarray(model.wv.vectors)

# Run t-SNE
embedded_data = run_tsne(data)



kmeans = KMeans(n_clusters=4, init='k-means++', n_init=10, max_iter=300)
kmeans.fit(embedded_data)


  
cluster_labels = kmeans.labels_

plt.scatter(embedded_data[:, 0], embedded_data[:, 1], c=cluster_labels)
plt.colorbar()
plt.show()


# Convert the plot to an interactive HTML format
html_graph = mpld3.fig_to_html(fig)
    
with open('kmeans.html', 'w') as file:
    file.write(html_graph)
